# %%
import torch
from transformers import AutoTokenizer, AutoModel

model_name = "vinai/phobert-base"

# Tokenizer hỗ trợ progress_bar
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, progress_bar=False)

# Model **không có progress_bar**
model = AutoModel.from_pretrained(model_name, trust_remote_code=True)
try: 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    print(f"Model đang chạy trên thiết bị: {device}")
except Exception as e:
    print(f"Cảnh báo: Không thể chuyển model sang GPU: {e}")
    model.to("cpu")
# Out:
# Model đang chạy trên thiết bị: cuda

# %%
import psycopg2
from psycopg2 import sql

conn = psycopg2.connect(
    host="localhost", # Bắt buộc kết nối qua mạng TCP/IP
    dbname="postgres", 
    user="postgres", 
    password="khangduong"
)

cur = conn.cursor()

# %%
cur.execute("drop table if exists dbvector;")

# %%
cur.execute("CREATE EXTENSION IF NOT EXISTS vector;")
cur.execute("CREATE TABLE IF NOT EXISTS dbvector1(id SERIAL PRIMARY KEY, EMBEDDING VECTOR(768), document varchar(20));")

# %%
conn.rollback()

# %%
import os
import re

# Khởi tạo thư mục gốc chứa các file .md
base_dir = "training_output"
# Thay đổi cấu trúc dữ liệu thành dictionary: {folder_name: [list_of_heading_lines]}
extracted_data = {}

print(f"Bắt đầu quét thư mục '{base_dir}'...")

for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file == "main.md":
            md_path = os.path.join(root, file)

            # Lấy tên thư mục (folder name) làm key
            # Ví dụ: nếu root là 'training_output/project_a', folder_name sẽ là 'project_a'
            folder_name = os.path.basename(root)
            
            try:
                with open(md_path, "r", encoding="utf-8") as f:
                    lines = f.readlines()
            except FileNotFoundError:
                print(f"Lỗi: Không tìm thấy file tại {md_path}")
                continue
            except Exception as e:
                print(f"Lỗi khi đọc file {md_path}: {e}")
                continue
            
            # --- Logic lọc đã được sửa đổi ---
            # CHỈ lấy các dòng bắt đầu bằng một hoặc nhiều dấu # (headings)
            heading_lines = []
            for line in lines:
                stripped_line = line.strip()
                
                # Kiểm tra xem dòng có bắt đầu bằng '#' và theo sau là một khoảng trắng không.
                # Đã loại bỏ điều kiện kiểm tra dòng bullet list (-)
                if re.match(r"^#+\s", stripped_line):
                    heading_lines.append(stripped_line)
            
            # Lưu trữ dữ liệu vào dictionary
            if heading_lines:
                extracted_data[folder_name] = heading_lines

print(f"✅ Quá trình trích xuất hoàn tất.")
print(f"Tổng cộng có {len(extracted_data)} thư mục đã được xử lý.")

# In ra ví dụ để kiểm tra cấu trúc dictionary
if extracted_data:
    first_key = list(extracted_data.keys())[0]
    print("\n--- Cấu trúc dữ liệu (Ví dụ) ---")
    print(f"Key (Tên thư mục): '{first_key}'")
    print(f"Value (Các dòng Heading):")
    for line in extracted_data[first_key]:
        print(f"  - {line}")
else:
    print("Không tìm thấy dữ liệu hoặc file 'main.md' nào chứa dòng heading.")
# Out:
# Bắt đầu quét thư mục 'training_output'...
# ✅ Quá trình trích xuất hoàn tất.
# Tổng cộng có 100 thư mục đã được xử lý.
#
# --- Cấu trúc dữ liệu (Ví dụ) ---
# Key (Tên thư mục): 'Public001'
# Value (Các dòng Heading):
#   - #  Public001.pdf
#   - # Giới thiệu
#   - # Nhà thông minh trước năm 2010
#   - ### Đo điều kiện nhà
#   - ### Quản lý thiết bị gia dụng
#   - ### Kiểm soát việc ra vào nhà
#   - # Tổng quan về Internet vạn vật
#   - # Điện toán đám mây và đóng góp của nó cho IoT và nhà thông minh
#   - # Nhà thông minh từ sau năm 2010
#   - # Các khía cạnh thực tế và cân nhắc triển khai cho IoT và nhà thông minh
#   - # Ví dụ về nhà thông minh và IoT
#   - # Kết luận

# %%
for document_name, doc_lines in enumerate(extracted_data.items()):
    print(doc_lines)
# Out:
# ('Public001', ['#  Public001.pdf', '# Giới thiệu', '# Nhà thông minh trước năm 2010', '### Đo điều kiện nhà', '### Quản lý thiết bị gia dụng', '### Kiểm soát việc ra vào nhà', '# Tổng quan về Internet vạn vật', '# Điện toán đám mây và đóng góp của nó cho IoT và nhà thông minh', '# Nhà thông minh từ sau năm 2010', '# Các khía cạnh thực tế và cân nhắc triển khai cho IoT và nhà thông minh', '# Ví dụ về nhà thông minh và IoT', '# Kết luận'])
# ('Public002', ['#  Public002.pdf', '# Bộ Môn Hệ Thống Thông Tin', '# Bộ Môn Mạng Máy Tính'])
# ('Public003', ['#  Public003.pdf', '# GIỚI THIỆU', '# CÁC NGHIÊN CỨU LIÊN QUAN', '# PHƯƠNG PHÁP ĐỀ XUẤT', '# THỰC NGHIỆM VÀ KẾT QUẢ', '# câu tiếng Việt.', '# KẾT LUẬN'])
# ('Public004', ['#  Public004.pdf', '# GIỚI THIỆU', '# TỔNG QUAN', '# CÁC CÔNG NGHỆ IN BÊ TÔNG 3D', '### * Công nghệ Contour Crafting', '### * Công nghệ Concrete Printing', '### * Công nghệ Concrete On-Site 3D Printing', '### * Công nghệ in bê tông 3D quy mô lớn sử dụng bê tông cường độ cao', '### * Công nghệ in ba chiều (D-Shape)', '### * Công nghệ đối tượng mới (Emerging Objects)', '### * Công nghệ in bê tông 3D dựa trên kỹ thuật lắng đọng bột sử dụng', '# KẾT LUẬN'])
# ('Public005', ['#  Public005.pdf', '# Đặt vấn đề', '# Cơ sở lý thuyết về công nghệ nhận dạng ký tự quang học', '# Kết quả thử nghiệm công nghệ nhận dạng ký tự quang học cho số hóa tài liệu tại', '## Các giải pháp nhận dạng ký tự quang học tại Việt Nam', '### FPT.AI Reader', '### Viettel OCR', '### Google Vision AI', '### Lựa chọn giải pháp', '## Thử nghiệm với tài liệu tại Học viện Ngân hàng', '### Thu thập tài liệu', '### Cài đặt giải pháp', '### Phương pháp đánh giá', '### Kết quả thực nghiệm', '# Kết luận và hướng phát triển', '## Kết luận', '## Hướng phát triển'])
# ('Public006', ['#  Public006.pdf', '# Giới thiệu', '# Phương pháp nghiên cứu', '# Kết quả và bàn luận', '### Quan niệm về quản trị đại học và công nghệ số', '### Ứng dụng công nghệ số trong quản trị đại học ở Việt Nam hiện nay', '### Những kết quả đạt được', '### Một số hạn chế', '# Kết luận'])
# ('Public007', ['#  Public007.pdf', '# Phạm vi', '# Tài liệu tham khảo', '# Thuật ngữ và định nghĩa', '# Những yêu cầu chung'])
# ('Public008', ['#  Public008.pdf', '# Yêu cầu về cơ cấu và quản trị', '# Giám đốc phòng xét nghiệm', '# Hoạt động của phòng xét nghiệm', '# Cơ cấu và quyền hạn', '# Mục tiêu và chính sách', '# Quản lý rủi ro', '# Yêu cầu về nguồn lực', '### Tổng quát', '### Yêu cầu về năng lực', '### Tổng quát', '### Kiểm soát cơ sở', '### Tiện nghi lưu trữ', '### Tiện nghi cho nhân viên', '### Tiện nghi lấy mẫu bệnh phẩm', '### Tổng quát', '### Yêu cầu về thiết bị', '### Thủ tục nghiệm thu thiết bị', '### Hướng dẫn sử dụng thiết bị', '### Bảo dưỡng và sửa chữa thiết bị', '### Báo cáo sự cố bất lợi của thiết bị', '### Hồ sơ thiết bị', '### Tổng quát', '### Hiệu chuẩn thiết bị', '### Liên kết chuẩn đo lường', '### Tổng quát', '### Thuốc thử và vật tư tiêu hao — Tiếp nhận và bảo quản', '### Thuốc thử và vật tư tiêu hao — Kiểm tra nghiệm thu', '### Thuốc thử và vật tư tiêu hao — Quản lý hàng tồn kho', '### Thuốc thử và vật tư tiêu hao — Hướng dẫn sử dụng', '### Thuốc thử và vật tư tiêu hao — Báo cáo sự cố bất lợi', '### Thuốc thử và vật tư tiêu hao — Hồ sơ', '### Thỏa thuận với người dùng phòng xét nghiệm', '### Thỏa thuận với bộ phận thực hiện POCT', '### Tổng quát', '### Các phòng xét nghiệm và chuyên gia tư vấn bên ngoài', '### Xem xét và phê duyệt các sản phẩm và dịch vụ do bên ngoài cung cấp', '# Yêu cầu về quá trình', '### Tổng quát', '### Thông tin cho bệnh nhân và người dùng'])
# ('Public009', ['#  Public009.pdf', '# A – Phần bắt buộc:'])
# ('Public010', ['#  Public010.pdf', '# Lập kế hoạch liên tục và chuẩn bị cho tình huống khẩn cấp', '# Yêu cầu hệ thống quản lý', '### Tổng quát', '### Đáp ứng các yêu cầu của hệ thống quản lý', '### Nhận thức về hệ thống quản lý', '### Tổng quát', '### Năng lực và chất lượng', '### Bằng chứng cam kết', '### Tài liệu', '### Tiếp cận của nhân viên', '### Tổng quát', '### Kiểm soát tài liệu', '### Tạo hồ sơ', '### Sửa đổi hồ sơ', '### Lưu giữ hồ sơ', '### Xác định rủi ro và cơ hội cải tiến', '### Hành động dựa trên rủi ro và cơ hội cải tiến', '### Cải tiến liên tục', '### Phản hồi của bệnh nhân, người dùng và nhân viên phòng xét nghiệm', '### Các hành động khi xảy ra sự không phù hợp', '### Hiệu quả của hành động khắc phục', '### Hồ sơ về sự không phù hợp và hành động khắc phục', '### Tổng quát', '### Chỉ tiêu chất lượng', '### Đánh giá nội bộ', '### Tổng quát', '### Đầu vào của xem xét', '### Đầu ra của xem xét'])
# ('Public011', ['#  Public011.pdf'])
# ('Public012', ['#  Public012.pdf', '# Khái niệm hệ điều hành', '# Tệp (File)', '# Quản lý tệp của hệ điều hành', '# Sự ra đời và phát triển', '# Khởi động và thoát khỏi Windows XP', '# Một số thuật ngữ và thao tác thường sử dụng'])
# ('Public013', ['#  Public013.pdf', '# Tri thức – Knowledge', '# Lịch sử phát triển của máy tính điện tử', '# Phân loại máy tính điện tử', '# Tin học', '# Công nghệ thông tin (Information Technology - IT)', '# Công nghệ thông tin và truyền thông'])
# ('Public014', ['#  Public014.pdf', '# Biểu diễn số trong các hệ đếm', '### Đổi phần nguyên từ hệ thập phân sang hệ b', '### Đổi phần thập phân từ hệ thập phân sang hệ cơ số b', '# Biểu diễn dữ liệu trong máy tính và đơn vị thông tin', '# Biểu diễn số nguyên', '### Cộng/ trừ số nguyên', '### Nhân/ chia số nguyên'])
# ('Public015', ['#  Public015.pdf'])
# ('Public016', ['#  Public016.pdf', '# Tài liệu viện dẫn', '# Cọc khoan nhồi (Bored pile)', '# Dung dịch khoan (Stabilizing fluids)', '# Thép gia cường (Stiffening rings)', '# Con kê (Spacers)', '# Kiểm tra chất lượng bê tông thân cọc', '# Kiểm tra sức chịu tải của cọc đơn', '# Nghiệm thu cọc khoan nhồi'])
# ('Public017', ['#  Public017.pdf', '# Yêu cầu chung', '# Yêu cầu đối với tính toán cấu kiện bê tông và bê tông cốt thép theo độ bền', '# Tính toán cấu kiện bê tông cốt thép theo độ bền tiết diện thẳng góc', '# Tính toán cấu kiện bê tông cốt thép theo độ bền tiết diện nghiêng', '# Tính toán cấu kiện bê tông cốt thép theo độ bền tiết diện không gian', '# Tính toán cấu kiện bê tông cốt thép chịu tác dụng cục bộ của tải trọng', '# Yêu cầu đối với tính toán cấu kiện bê tông cốt thép theo sự hình thành vết nứt', '# Yêu cầu đối với tính toán cấu kiện bê tông cốt thép theo sự mở rộng vết nứt', '# Vật liệu cho kết cấu bê tông và bê tông cốt thép', '### Các chỉ tiêu chất lượng của bê tông được sử dụng khi thiết kế'])
# ('Public018', ['#  Public018.pdf', '# Thuật ngữ và định nghĩa', '# Ký hiệu', '# Tất cả các loại kết cấu bê tông và bê tông cốt thép cần phải thỏa mãn:', '# Để thỏa mãn các yêu cầu về an toàn thì kết cấu cần phải có các đặc trưng ban', '# Để thỏa mãn các yêu cầu về điều kiện sử dụng bình thường thì kết cấu cần phải', '# Để thỏa mãn các yêu cầu về độ bền lâu thì kết cấu cần phải có các đặc trưng ban', '# Sự an toàn, điều kiện sử dụng, độ bền lâu của kết cấu bê tông và bê tông cốt thép', '# Khi thiết kế kết cấu bê tông và bê tông cốt thép, độ tin cậy của các kết cấu được', '# Yêu cầu chung'])
# ('Public019', ['#  Public019.pdf', '# Sơ lược về chiến lược Trí tuệ nhân tạo quốc gia trên thế giới', '### Nhật Bản', '### Hàn Quốc', '# nhân sự TTNT phổ thông. Xây dựng được 66,7 triệu đơn vị dữ liệu thông', '### . Đài Loan, Singapore và Malaysia', '# Một số trao đổi về một chiến lược Trí tuệ nhân tạo quốc gia của Việt Nam'])
# ('Public020', ['#  Public020.pdf', '# Chiều dày của vật liệu bảo vệ', '### Dầm chịu tải', '### Dầm không chịu tải', '### Cột cao chịu tải', '### Cột ngắn không chịu tải', '# Nhận dạng', '# Nguyên tắc chung', '# Kiểu đầu đo nhiệt', '# Lắp đặt đầu đo nhiệt', '# Lắp đặt dây dẫn cho sợi dây đo nhiệt', '# Kết nối đầu đo nhiệt', '# Hỏng đầu đo nhiệt', '# Giới thiệu', '# Trang thiết bị thử nghiệm'])
# ('Public021', ['#  Public021.pdf'])
# ('Public022', ['#  Public022.pdf', '# Nhiệt độ đặc trưng của thép (characteristic steel temperature)', '# Nhiệt độ thiết kế (design temperature)', '# Bảo vệ chịu lửa', '# Hệ bảo vệ chịu lửa (fire protection system)', '# Chiều dày lớp bảo vệ chịu lửa (fire protection thickness)', '# Cấu kiện chữ H (H section)', '# Cấu kiện chữ I (I section)', '# Vật liệu bảo vệ dạng thụ động (passive fire protection material)', '# Vật liệu bảo vệ dạng phản ứng (reactive fire protection material)', '# Cấu kiện tham chiếu (reference section)', '# Hệ số tiết diện (với cấu kiện không được bọc bảo vệ) (section factor- unprotected', '# Hệ số tiết diện (với hệ bảo vệ dạng định hình) (section factor-profiled fire', '# Hệ số tiết diện (với hệ bảo vệ dạng hộp) (section factor - boxed fire protection', '# Cấu kiện thép (steel member)', '# Nhiệt độ thép (steel temperature)', '# Khả năng bám dính (stickability)', '# Gói thử nghiệm (test package)', '# Mẫu thử nghiệm (test specimen)', '# Yêu cầu chung', '# Lò thử nghiệm', '# Thiết bị gia tải', '# Yêu cầu chung', '# Gối đỡ và điều kiện tải trọng'])
# ('Public023', ['#  Public023.pdf', '# Nguyên tắc chung', '# Chiều dày của vật liệu bảo vệ', '# Lựa chọn mẫu thử nghiệm', '# Dầm chịu tải', '# Dầm không chịu tải', '# Cột chịu tải', '# Cột không chịu tải', '# Bố trí lắp đặt mẫu thử nghiệm'])
# ('Public024', ['#  Public024.pdf', '# Phân loại thực phẩm theo thành phần hóa học', '# Phân loại thực phẩm theo mục đích sử dụng', '# Các mục đích sử dụng khác', '# Theo lĩnh vực khoa học tự nhiên', '### Chất dinh dưỡng', '### Phụ gia và chất hỗ trợ kỹ thuật', '### Các chất khác', '# Theo cơ sở khoa học của phương pháp phân tích', '# An toàn thực phẩm'])
# ('Public025', ['#  Public025.pdf', '# Bảo quản', '# Chuẩn bị', '# Hoàn thiện', '# Vật lý', '# Hóa học', '# Hóa lý', '# Sinh học'])
# ('Public026', ['#  Public026.pdf', '# XƠ DỆT', '# SỢI DỆT', '### Loại sợi thứ nhất: Dạng sợi nhận trực tiếp sau quá trình kéo sợi:', '### Loại sợi thứ hai: Ghép và xoắn các loại sợi thứ nhất thành sợi xe.'])
# ('Public027', ['#  Public027.pdf', '# Xơ xenlulô (Cotton)', '# Xơ protein (Len, Tơ tằm)'])
# ('Public028', ['#  Public028.pdf', '# Cấu tạo', '# Thiết bị đầu cuối của BJT', '# Ký hiệu', '# Nguyên lý làm việc của Transistor NPN', '# Mối nối B- E(Emitter-base junction)'])
# ('Public029', ['#  Public029.pdf', '# Bán dẫn thuần khiết (Pure Semiconducting)', '# Bán dẫn loại N (N-type Semiconductor)', '# Bán dẫn loại P (P-type Semiconductor)', '# Chuyển động của electron và lỗ trống trong chất bán dẫn', '# Mối nối P-N (P-N Junction)'])
# ('Public030', ['#  Public030.pdf', '# Giới thiệu về tụ điện (Introduction to Capacitors)', '# Các tham số chính của tụ điện (Main Parameters of the Capacitor)', '# Các loại tụ điện (Types of Capacitors)', '# Ứng dụng của tụ điện (Applications of Capacitors)', '# Lưu ý khi sử dụng và bảo quản tụ điện (Precautions and Storage)', '# Điện áp làm việc (Working Voltage)', '# × điện áp hiệu dụng. Khi chọn tụ điện, điện áp làm việc nên cao hơn điện áp mạch', '# Nhiệt độ làm việc (Working Temperature)'])
# ('Public031', ['#  Public031.pdf', '# Điện trở là gì? (What is a Resistor)', '# Đơn vị điện trở (Resistor Units)', '# Ω = 4.7 kΩ •', '## Ω = 5.6 MΩ hoặc 5,600 kΩ •', '# Ký hiệu điện trở trong sơ đồ mạch (Resistor Schematic Symbol)', '# Thành phần điện trở (Resistor Composition)', '# Ý nghĩa điện trở trong mạch điện (Resistor in Circuit)', '# Giá trị điện trở của dây dẫn (Resistance of Conductor)', '# Mạch điện trở mắc nối tiếp (Resistor Series Circuits)', '# Mạch điện trở mắc song song (Resistor Parallel Circuits)'])
# ('Public032', ['#  Public032.pdf', '# Định nghĩa (Definition)', '# Định luật Ohm (Ohm’s Law)', '# Ví dụ minh họa', '# Công suất điện (Power Calculation)', '# Định nghĩa (Definition)', '# Dạng sóng (Waveform)', '# Mô tả toán học của sóng sin AC', '# Ứng dụng (Applications)', '# Điện áp hiệu dụng (RMS Voltage)', '# Công suất AC (AC Power)', '# So sánh DC và AC'])
# ('Public033', ['#  Public033.pdf', '# Sơ lược về lịch sử phát triển (A Brief History of Development)', '# Giới thiệu về điện (Introduction to Electricity)', '# Điện áp (Voltage)', '# Trở kháng (Resistance)'])
# ('Public034', ['#  Public034.pdf', '# Ký hiệu Photodiode', '# Mục tiêu và hạn chế của Photodiode', '# Các loại Photodiode', '# Ứng dụng của Photodiode', '# Phototransistor', '# Hoạt động của Phototransistor', '# Ứng dụng Phototransistor', '# Các bộ ghép quang (Opto–Couplers)', '# Hiệu ứng quang điện', '# Các tham số quan trọng của Photodiode', '# Phân cực Photodiode', '# Nguyên lý hoạt động của Phototransistor', '# Nguyên lý cách ly quang của Optocoupler', '# Các thông số quan trọng của Optocoupler'])
# ('Public035', ['#  Public035.pdf', '# 509.248', '# 535.104', '# 551.432', '# 623.418', '# Model', '# Loss function', '# Đạo hàm là gì?', '# Gradient descent', '# Mean Absolute Error, L1 Loss', '# Mean Square Error, L2 Loss'])
# ('Public036', ['#  Public036.pdf', '# Phân loại bài toán image segmentation', '# Ứng dụng bài toán segmentation', '# Kiến trúc mạng U-Net', '# Loss function', '# Transposed convolution'])
# ('Public037', ['#  Public037.pdf', '# Image embedding với Inception', '# Text preprocessing', '# Word embedding', '# Output'])
# ('Public038', ['#  Public038.pdf', '# Motivation', '# Cách hoạt động'])
# ('Public039', ['#  Public039.pdf', '# Generate Photographs of Human Faces', '# Image editing', '# Generate Realistic Photographs', '# Image-to-Image Translation', '# Generator', '# Discriminator'])
# ('Public040', ['#  Public040.pdf', '# Cấu trúc mạng', '# Tips', '# Thực nghiệm', '# Fashion-MNIST', '# Cấu trúc mạng'])
# ('Public041', ['#  Public041.pdf', '# Model', '# Loss function'])
# ('Public042', ['#  Public042.pdf', '# nơ-ron khác.'])
# ('Public043', ['#  Public043.pdf', '# + b * 0.114.'])
# ('Public044', ['#  Public044.pdf'])
# ('Public045', ['#  Public045.pdf', '# Feature extractor', '# Fine tuning', '# Khi nào nên dùng transfer learning'])
# ('Public046', ['#  Public046.pdf', '# -*- coding: utf-8 -*-', '# Phân tích nguyên nhân'])
# ('Public047', ['#  Public047.pdf'])
# ('Public048', ['#  Public048.pdf', '# Cách1 def add_boder(image_path, output_path, low, high):', '# random các kích thước biên trong khoảng (low, high)', '# Cách2 def random_crop(image_path, out_path):', '# crop ra vùng ảnh với kích thước ngẫu nhiên', '# resize ảnh bằng kích thước ảnh ban đầu'])
# ('Public049', ['#  Public049.pdf', '# Kiểu dữ liệu', '# Biến'])
# ('Public050', ['#  Public050.pdf'])
# ('Public051', ['#  Public051.pdf'])
# ('Public052', ['#  Public052.pdf'])
# ('Public053', ['#  Public053.pdf', '# Thuật toán Selection-Sort', '# Thuật toán Insertion Sort'])
# ('Public054', ['#  Public054.pdf', '# Biểu diễn thuật toán', '# Độ phức tạp thuật toán', '# Kiểm nghiệm thuật toán', '# Cài đặt thuật toán', '# Biểu diễn thuật toán', '# Độ phức tạp thuật toán', '# Kiểm nghiệm thuật toán', '# Cài đặt thuật toán', '# Độ phức tạp thuật toán', '# Kiểm nghiệm thuật toán', '# Cài đặt thuật toán'])
# ('Public055', ['#  Public055.pdf', '# Thuật toán tìm kiếm tuyến tính (Sequential Search)', '## Biểu diễn thuật toán', '## Độ phức tạp thuật toán', '## Kiểm nghiệm thuật toán', '## Cài đặt thuật toán', '# Thuật toán tìm kiếm nhị phân', '## Biểu diễn thuật toán', '## Độ phức tạp thuật toán', '## Kiểm nghiệm thuật toán', '## Cài đặt thuật toán', '# Thuật toán tìm kiếm nội suy', '## Biểu diễn thuật toán', '## Độ phức tạp thuật toán', '## Kiểm nghiệm thuật toán', '## Cài đặt thuật toán', '# Thuật toán tìm kiếm Jumping', '## Biểu diễn thuật toán', '## Độ phức tạp thuật toán', '## Kiểm nghiệm thuật toán', '## Cài đặt thuật toán'])
# ('Public056', ['#  Public056.pdf', '# Định nghĩa danh sách liên kết đơn', '# Biểu diễn danh sách liên kết đơn', '# Thao tác trên danh sách liên kết đơn'])
# ('Public057', ['#  Public057.pdf', '# Một số thuật ngữ cơ bản trên đồ thị', '# Một số thuật ngữ trên đồ thị vô hướng', '# Một số thuật ngữ trên đồ thị có hướng', '# Một số loại đồ thị đặc biệt', '# Biểu diễn bằng ma trận kề', '# Biểu diễn đồ thị bằng danh sách cạnh', '# Biểu diễn đồ thị bằng danh sách kề'])
# ('Public058', ['#  Public058.pdf', '# Kiểm thử chức năng', '# Kiểm thử cấu trúc', '# Tranh luận về kiểm thử chức năng so với kiểm thử cấu trúc', '# minh họa một cách phân loại sai [Bor84] dựa trên độ nghiêm trọng của hậu quả mà các lỗi'])
# ('Public059', ['#  Public059.pdf', '# Các loại giao diện và lỗi giao diện', '# include <stdio .h>', '# include <stdio .h> char* str;', '# .h> include <stdio .h> # include <unistd', '# include <sys / types .h>', '# Tích hợp dựa trên cấu trúc mô-đun'])
# ('Public060', ['#  Public060.pdf', '# Phát biểu bài toán', '# Nhận xét', '# Cài đặt truyền thống', '# Cài đặt có cấu trúc', '# Phát biểu bài toán', '# Nhận xét'])
# ('Public061', ['#  Public061.pdf', '# Tiến hành duyệt đặc tả mức cao', '## Hãy là khách hàng của sản phẩm', '## Hãy nghiên cứu các chuẩn và hướng dẫn hiện hành', '## Hãy xem xét và kiểm thử các phần mềm tương tự', '# Các kỹ thuật kiểm thử đặc tả ở mức thấp', '## Danh sách các hạng mục cần thẩm định về các thuộc tính của đặc tả', '## Danh sách các hạng mục cần thẩm định về các thuật ngữ của đặc tả', '# Khảo sát thiết kế và mã nguồn hay là việc kiểm thử hộp trắng tĩnh'])
# ('Public062', ['#  Public062.pdf', '# Giá trị biên', '# Một số dạng kiểm thử giá trị biên'])
# ('Public063', ['#  Public063.pdf', '# Bảng quyết định', '# Ví dụ minh họa'])
# ('Public064', ['#  Public064.pdf', '# chương 7.'])
# ('Public065', ['#  Public065.pdf', '# Ý tưởng về kiểm thử dựa trên lát cắt', '# Ví dụ áp dụng'])
# ('Public066', ['#  Public066.pdf', '# Máy hữu hạn trạng thái', '# Ôtômat đơn định hữu hạn trạng thái', '# Biểu đồ trạng thái', '# Máy trạng thái UML', '# Các phương pháp đặc tả khác'])
# ('Public067', ['#  Public067.pdf'])
# ('Public068', ['#  Public068.pdf'])
# ('Public069', ['#  Public069.pdf'])
# ('Public070', ['#  Public070.pdf'])
# ('Public071', ['#  Public071.pdf'])
# ('Public072', ['#  Public072.pdf', '# Deep Q-Network (DQN)', '# Policy Gradient Methods (ví dụ: REINFORCE, A2C, A3C)', '# Actor-Critic', '# Proximal Policy Optimization (PPO)', '# Mô phỏng trước khi thử nghiệm thực tế', '# Transfer Learning (Chuyển giao học tập)', '# Thiết kế phần thưởng (Reward Shaping)', '# Đảm bảo an toàn và ràng buộc vật lý'])
# ('Public073', ['#  Public073.pdf'])
# ('Public074', ['#  Public074.pdf'])
# ('Public075', ['#  Public075.pdf', '# Pin Thể Rắn (Solid-State Battery)', '# Pin Sodium-Ion (Na-ion)', '# Pin Lưu Lượng (Flow Battery)', '# Pin Lithium-Sulfur (Li-S)'])
# ('Public076', ['#  Public076.pdf', '# Tầng thu thập dữ liệu', '# Tầng phân tích và học máy', '# Tầng phát hiện thời gian thực', '# Tầng phản ứng và tự động hóa', '# Phát hiện xâm nhập thông minh', '# Phòng chống lừa đảo (Anti-Phishing)', '# Phân tích mã độc tự động', '# Bảo vệ IoT', '# Tự động ứng phó sự cố'])
# ('Public077', ['#  Public077.pdf', '# Cấu trúc khối (Block):', '# Chuỗi liên kết (Chain):', '# Cơ chế đồng thuận:', '# Hợp đồng thông minh (Smart Contract):', '# Truy xuất nguồn gốc minh bạch', '# Chống giả mạo và gian lận', '# Tự động hóa thanh toán và hợp đồng', '# Tối ưu vận chuyển và tồn kho', '# Đảm bảo tuân thủ và kiểm toán'])
# ('Public078', ['#  Public078.pdf'])
# ('Public079', ['#  Public079.pdf', '# Trường tiếp nhận cục bộ (local receptive field)', '# Trọng số chia sẻ (shared weight and bias)', '# Lớp tổng hợp (pooling layer)'])
# ('Public080', ['#  Public080.pdf'])
# ('Public081', ['#  Public081.pdf', '# So Sánh GNN và CNN', '# So Sánh GNN và RNN'])
# ('Public082', ['#  Public082.pdf'])
# ('Public083', ['#  Public083.pdf'])
# ('Public084', ['#  Public084.pdf', '# Mạng CNN', '# Recurrent Neural Network'])
# ('Public085', ['#  Public085.pdf', '# Bất kỳ lúc nào A * Thuật toán', '# Thuật toán D *', '# Thuật toán PRM', '# Thuật toán Zero Moment Point (ZMP)', '# Thuật toán điều khiển vi phân tích phân tỷ lệ (PID)'])
# ('Public086', ['#  Public086.pdf', '# Ưu điểm của năng lượng tái tạo', '# Nhược điểm của năng lượng tái tạo'])
# ('Public087', ['#  Public087.pdf'])
# ('Public088', ['#  Public088.pdf'])
# ('Public089', ['#  Public089.pdf'])
# ('Public090', ['#  Public090.pdf'])
# ('Public091', ['#  Public091.pdf'])
# ('Public092', ['#  Public092.pdf', '# Anten siêu vật liệu tái cấu hình:', '# Bề mặt phản xạ thông minh (Reconfigurable Intelligent Surface – RIS):', '# Lọc và bảo mật tín hiệu:', '# Giao tiếp Terahertz (THz):'])
# ('Public093', ['#  Public093.pdf'])
# ('Public094', ['#  Public094.pdf', '# Giới thiệu về Học máy trong Vũ trụ học', '# Ứng dụng của Học máy trong Ước lượng Tham số Vũ trụ học', '# Hướng phát triển trong tương lai cho Học máy trong Vũ trụ học'])
# ('Public095', ['#  Public095.pdf', '# Tăng áp suất khí quyển:', '# Gia nhiệt hành tinh:', '# Tạo từ trường nhân tạo:', '# Sản xuất oxy và nước:', '# Giới thiệu sinh vật quang hợp:'])
# ('Public096', ['#  Public096.pdf', '# Nguồn nhiên liệu dồi dào và an toàn', '# Tokamak:', '# Stellarator:', '# Giam giữ quán tính (Inertial Confinement):', '# Khởi nghiệp thương mại:'])
# ('Public097', ['#  Public097.pdf', '# Xe hơi và xe tải hạng nặng:', '# Tàu biển:', '# Hàng không:', '# Tàu hỏa và xe buýt đô thị:'])
# ('Public098', ['#  Public098.pdf', '# Cơ chế hoạt động', '# Thông số ấn tượng', '# Ứng dụng'])
# ('Public099', ['#  Public099.pdf'])
# ('Public100', ['#  Public100.pdf'])

# %%
import torch
# Cần import thư viện database (ví dụ: psycopg2 cho PostgreSQL)
# import psycopg2
# from psycopg2 import sql

# Lưu ý: Các biến 'tokenizer', 'model', 'device', 'extracted_data'
# được giả định là đã được định nghĩa và khởi tạo trong môi trường của bạn.

# --- 1. Khởi tạo và Tạo Embedding (Tách biệt theo từng dòng) ---
# Danh sách để lưu trữ TẤT CẢ các bản ghi (record), mỗi record là một dòng/segment
all_embedding_records = [] 

# Lặp trực tiếp qua key (tên document) và value (list các dòng Heading) của extracted_data
for document_name, doc_lines in extracted_data.items():
    
    print(f"--- Đang xử lý Document: {document_name} ({len(doc_lines)} segments) ---")
    
    # Lặp qua từng dòng văn bản (segment) trong tài liệu này
    for idx, segment_text in enumerate(doc_lines):
        
        # Bỏ qua các dòng trống (mặc dù đã được xử lý ở bước trước, vẫn giữ để phòng hờ)
        if not segment_text.strip():
            continue

        try:
            # BƯỚC TIỀN XỬ LÝ QUAN TRỌNG: XÓA TẤT CẢ DẤU CÁCH TRƯỚC KHI TOKEN HÓA
            preprocessed_text = segment_text.replace(' ', '')
            
            # 1. Token hóa và chuyển sang PyTorch Tensor cho segment hiện tại
            # Sử dụng văn bản đã được tiền xử lý
            inputs = tokenizer(preprocessed_text, return_tensors="pt", truncation=True, max_length=756)
            
            # 2. Chuyển inputs lên thiết bị GPU (device)
            inputs = {key: value.to(device) for key, value in inputs.items()}
            
            with torch.no_grad():
                # 3. Chạy mô hình để lấy outputs
                outputs = model(**inputs)
                
                # 4. Trích xuất embedding của token [CLS]
                embedding = outputs.last_hidden_state[:, 0, :].squeeze().cpu().numpy()

            # Thêm record vào danh sách
            all_embedding_records.append({
                "document": document_name, # Key của dictionary -> document column
                "embedding": embedding.tolist() # Vector đã tạo -> EMBEDDING column
            })
            
            if idx % 50 == 0:
                 print(f"✅ Đã tạo embedding cho dòng {idx} trong document: {document_name}")
        
        except RuntimeError as cuda_err:
             if 'CUDA error: device-side assert triggered' in str(cuda_err):
                 print(f"--- LỖI CUDA (Bỏ qua segment) ---")
                 print(f"Document: {document_name}, Segment Index: {idx}")
                 print(f"Nội dung đã xử lý gây lỗi: {preprocessed_text[:100]}...")
                 continue
             else:
                 raise # Ném các lỗi RuntimeError khác
        
        except Exception as e:
            print(f"❌ Lỗi không xác định khi xử lý segment {idx} của {document_name}: {e}")
            continue


# In ra kết quả xử lý
print("\n--- Kết quả xử lý Embedding ---")
print(f"Tổng số segments (dòng) đã được nhúng: {len(all_embedding_records)}")

# --- 2. Kết nối và Chèn Dữ liệu vào Database (Chèn theo từng dòng/segment) ---

# Giả định rằng conn, cur, và sql đã được định nghĩa và kết nối.
try:
    print("\n--- Bắt đầu chèn dữ liệu vào Database ---")
    
    # Lặp qua danh sách tất cả các records đã tạo (mỗi record là 1 dòng)
    for record in all_embedding_records:
        # Chèn embedding vào bảng dbvector
        cur.execute(
            sql.SQL("INSERT INTO dbvector1 (EMBEDDING, document) VALUES (%s, %s)"),
            (record['embedding'], record['document'])
        )
    
    # Commit giao dịch một lần duy nhất để tối ưu hiệu suất
    conn.commit()
    print(f"✅ HOÀN TẤT: {len(all_embedding_records)} embeddings đã được lưu trữ vào database.")
    
except NameError:
    print("🚨 LỖI KẾT NỐI: Vui lòng định nghĩa và thiết lập kết nối Database (conn, cur, sql) trước khi chạy phần chèn dữ liệu.")
except Exception as e:
    # conn.rollback() # Cần đảm bảo conn đã được định nghĩa
    print(f"❌ LỖI TRONG QUÁ TRÌNH CHÈN DỮ LIỆU: {e}. Vui lòng kiểm tra lại kết nối và lược đồ bảng.")

# !!! Quan trọng: Đừng quên đóng kết nối Database khi kết thúc chương trình !!!
# Out:
# --- Đang xử lý Document: Public001 (12 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public001
# --- Đang xử lý Document: Public002 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public002
# --- Đang xử lý Document: Public003 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public003
# --- Đang xử lý Document: Public004 (12 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public004
# --- Đang xử lý Document: Public005 (17 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public005
# --- Đang xử lý Document: Public006 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public006
# --- Đang xử lý Document: Public007 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public007
# --- Đang xử lý Document: Public008 (40 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public008
# --- Đang xử lý Document: Public009 (2 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public009
# --- Đang xử lý Document: Public010 (29 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public010
# --- Đang xử lý Document: Public011 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public011
# --- Đang xử lý Document: Public012 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public012
# --- Đang xử lý Document: Public013 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public013
# --- Đang xử lý Document: Public014 (8 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public014
# --- Đang xử lý Document: Public015 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public015
# --- Đang xử lý Document: Public016 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public016
# --- Đang xử lý Document: Public017 (11 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public017
# --- Đang xử lý Document: Public018 (10 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public018
# --- Đang xử lý Document: Public019 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public019
# --- Đang xử lý Document: Public020 (15 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public020
# --- Đang xử lý Document: Public021 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public021
# --- Đang xử lý Document: Public022 (24 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public022
# --- Đang xử lý Document: Public023 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public023
# --- Đang xử lý Document: Public024 (10 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public024
# --- Đang xử lý Document: Public025 (8 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public025
# --- Đang xử lý Document: Public026 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public026
# --- Đang xử lý Document: Public027 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public027
# --- Đang xử lý Document: Public028 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public028
# --- Đang xử lý Document: Public029 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public029
# --- Đang xử lý Document: Public030 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public030
# --- Đang xử lý Document: Public031 (11 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public031
# --- Đang xử lý Document: Public032 (12 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public032
# --- Đang xử lý Document: Public033 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public033
# --- Đang xử lý Document: Public034 (15 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public034
# --- Đang xử lý Document: Public035 (11 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public035
# --- Đang xử lý Document: Public036 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public036
# --- Đang xử lý Document: Public037 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public037
# --- Đang xử lý Document: Public038 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public038
# --- Đang xử lý Document: Public039 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public039
# --- Đang xử lý Document: Public040 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public040
# --- Đang xử lý Document: Public041 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public041
# --- Đang xử lý Document: Public042 (2 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public042
# --- Đang xử lý Document: Public043 (2 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public043
# --- Đang xử lý Document: Public044 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public044
# --- Đang xử lý Document: Public045 (4 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public045
# --- Đang xử lý Document: Public046 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public046
# --- Đang xử lý Document: Public047 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public047
# --- Đang xử lý Document: Public048 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public048
# --- Đang xử lý Document: Public049 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public049
# --- Đang xử lý Document: Public050 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public050
# --- Đang xử lý Document: Public051 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public051
# --- Đang xử lý Document: Public052 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public052
# --- Đang xử lý Document: Public053 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public053
# --- Đang xử lý Document: Public054 (12 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public054
# --- Đang xử lý Document: Public055 (21 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public055
# --- Đang xử lý Document: Public056 (4 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public056
# --- Đang xử lý Document: Public057 (8 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public057
# --- Đang xử lý Document: Public058 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public058
# --- Đang xử lý Document: Public059 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public059
# --- Đang xử lý Document: Public060 (7 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public060
# --- Đang xử lý Document: Public061 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public061
# --- Đang xử lý Document: Public062 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public062
# --- Đang xử lý Document: Public063 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public063
# --- Đang xử lý Document: Public064 (2 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public064
# --- Đang xử lý Document: Public065 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public065
# --- Đang xử lý Document: Public066 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public066
# --- Đang xử lý Document: Public067 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public067
# --- Đang xử lý Document: Public068 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public068
# --- Đang xử lý Document: Public069 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public069
# --- Đang xử lý Document: Public070 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public070
# --- Đang xử lý Document: Public071 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public071
# --- Đang xử lý Document: Public072 (9 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public072
# --- Đang xử lý Document: Public073 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public073
# --- Đang xử lý Document: Public074 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public074
# --- Đang xử lý Document: Public075 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public075
# --- Đang xử lý Document: Public076 (10 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public076
# --- Đang xử lý Document: Public077 (10 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public077
# --- Đang xử lý Document: Public078 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public078
# --- Đang xử lý Document: Public079 (4 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public079
# --- Đang xử lý Document: Public080 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public080
# --- Đang xử lý Document: Public081 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public081
# --- Đang xử lý Document: Public082 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public082
# --- Đang xử lý Document: Public083 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public083
# --- Đang xử lý Document: Public084 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public084
# --- Đang xử lý Document: Public085 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public085
# --- Đang xử lý Document: Public086 (3 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public086
# --- Đang xử lý Document: Public087 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public087
# --- Đang xử lý Document: Public088 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public088
# --- Đang xử lý Document: Public089 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public089
# --- Đang xử lý Document: Public090 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public090
# --- Đang xử lý Document: Public091 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public091
# --- Đang xử lý Document: Public092 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public092
# --- Đang xử lý Document: Public093 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public093
# --- Đang xử lý Document: Public094 (4 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public094
# --- Đang xử lý Document: Public095 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public095
# --- Đang xử lý Document: Public096 (6 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public096
# --- Đang xử lý Document: Public097 (5 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public097
# --- Đang xử lý Document: Public098 (4 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public098
# --- Đang xử lý Document: Public099 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public099
# --- Đang xử lý Document: Public100 (1 segments) ---
# ✅ Đã tạo embedding cho dòng 0 trong document: Public100
#
# --- Kết quả xử lý Embedding ---
# Tổng số segments (dòng) đã được nhúng: 597
#
# --- Bắt đầu chèn dữ liệu vào Database ---
# ✅ HOÀN TẤT: 597 embeddings đã được lưu trữ vào database.

# %%
cur.close()
conn.close()
