# %%
from dotenv import load_dotenv
import os
load_dotenv(".env")
# Out:
# True

# %%
import psycopg2
from psycopg2 import sql
conn = psycopg2.connect(
    host=os.getenv("DB_HOST"), 
    dbname=os.getenv("DB_NAME"), 
    user=os.getenv("DB_USER"), 
    password=os.getenv("DB_PASSWORD"), 
)
cur = conn.cursor()

# %%
import torch
from transformers import AutoModel, AutoTokenizer
from torch.nn.functional import cosine_similarity
import pandas as pd
import re
import os
# Thêm import cần thiết cho tính toán Euclid
import torch.nn.functional as F

# Đặt giới hạn an toàn cho PhoBERT-base
SAFE_MAX_LENGTH = 256 # Giới hạn 256 token là an toàn nhất cho PhoBERT-base
QA_MAX_LENGTH = 256

# Hàm nhúng (đã cập nhật)
def get_embedding(text, model, tokenizer, max_len=512):
    # Đảm bảo tensor luôn ở device của model
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=max_len).to(model.device)
    with torch.no_grad():
        out = model(**inputs)
    return out.last_hidden_state[:, 0, :] # CLS token

# Hàm tính khoảng cách Euclid giữa một vector và nhiều vector
def euclidean_distance(query_emb, context_embeddings):
    # Mở rộng query_emb để có kích thước [n_chunks, hidden_size]
    query_expanded = query_emb.expand_as(context_embeddings)
    
    # Tính hiệu số, sau đó tính chuẩn L2 (Euclidean norm) trên dimension vector (dim=1)
    distances = torch.norm(context_embeddings - query_expanded, p=2, dim=1)
    
    return distances.squeeze() # Trả về tensor 1D chứa các khoảng cách

model_name = "vinai/phobert-base"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False)
phobert = AutoModel.from_pretrained(model_name, trust_remote_code=True)
try: 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    phobert.to(device)
    print(f"Model đang chạy trên thiết bị: {device}")
except Exception as e:
    print(f"Cảnh báo: Không thể chuyển model sang GPU: {e}")
    phobert.to("cpu")

csv_path = "training_input/question.csv"
df = pd.read_csv(csv_path)

for idx, row in df.iterrows():
    question = str(row["Question"]).strip()
    options = [str(row["A"]), str(row["B"]), str(row["C"]), str(row["D"])]
    labels = ["A", "B", "C", "D"]
    
    question_embedding = get_embedding(question, phobert, tokenizer, max_len=512)
    
    if question_embedding is None:
        continue # Bỏ qua câu hỏi rỗng
        
    # Truy vấn DB (không thay đổi)
    cur.execute("""SELECT document FROM dbvector1 
                 Order by embedding  <-> %s :: vector asc
                 LIMIT 1;""", (question_embedding.squeeze().detach().cpu().numpy().tolist(),))
    results = cur.fetchall()
    x = results[0]
    document_name = x[0]
    print(f"\n Câu hỏi: {question}")
   
    # Đọc và chia đoạn tài liệu (logic chia theo 256 ký tự được giữ nguyên)
    md_path = os.path.join("training_output", document_name, "main.md")
    if not os.path.exists(md_path): continue
    
    with open(md_path, "r", encoding="utf-8") as f:
        doc_text = f.read()

    
    processed_text = re.sub(r'\s+', '', doc_text.strip()) 
    doc_chunks = []
    MAX_CHARS = 300 # Giữ 300 ký tự
    for i in range(0, len(processed_text), MAX_CHARS):
        chunk = processed_text[i:i + MAX_CHARS]
        doc_chunks.append(chunk)

    # Tạo embedding cho từng đoạn
    chunk_embeddings = []
    for chunk in doc_chunks:
        # 💥 FIX: Đặt max_length an toàn cho chunk
        emb = get_embedding(chunk, phobert, tokenizer, max_len=300)
        if emb is not None:
            chunk_embeddings.append(emb)

    if not chunk_embeddings:
        print(f"Không tìm thấy chunk hợp lệ trong tài liệu {document_name}. Bỏ qua.")
        continue

    chunk_embeddings = torch.cat(chunk_embeddings, dim=0)  # [n_chunks, hidden_size]

    distances = []
    for i, opt in enumerate(options):
        # *Tối ưu hóa: Nhúng chỉ tùy chọn, so sánh với tất cả các đoạn.*
        qa_text = f"{question} {opt}"
        
       
        qa_emb = get_embedding(qa_text, phobert, tokenizer, max_len=300)

        if qa_emb is None:
            min_dist = float('inf')
        else:
            # THAY ĐỔI LỚN: Tính khoảng cách Euclid (L2 Distance)
            dists = euclidean_distance(qa_emb, chunk_embeddings)
            
            # Tìm khoảng cách NHỎ NHẤT (vì khoảng cách Euclid: Càng nhỏ càng tốt)
            min_simi = dists.min().item()
            
        distances.append(min_simi)
        print(f"  {labels[i]}. {opt}  →  similarity = {min_simi:.4f}")

    # THAY ĐỔI LỚN: Tìm chỉ mục có khoảng cách NHỎ NHẤT (argmin)
    best_idx = torch.argmin(torch.tensor(distances)).item()
    print(f"Đáp án gợi ý: {labels[best_idx]} - {options[best_idx]}")
    print(document_name)
# Out:
# Model đang chạy trên thiết bị: cuda
#
#  Câu hỏi: Trong mô hình nhà thông minh, IoT chủ yếu đóng vai trò gì?
#   A. Lưu trữ dữ liệu trên máy chủ  →  similarity = 9.8516
#   B. Kết nối Internet và quản lý thiết bị từ xa  →  similarity = 9.5775
#   C. Cung cấp dịch vụ phân tích dữ liệu lớn  →  similarity = 10.6536
#   D. Thay thế hoàn toàn điện toán đám mây  →  similarity = 9.8783
# Đáp án gợi ý: B - Kết nối Internet và quản lý thiết bị từ xa
# Public001
#
#  Câu hỏi: Năm 2010, công nghệ nào thường được sử dụng trong kiểm soát ra vào ngôi nhà thông minh?
#   A. Bluetooth Low Energy  →  similarity = 10.9916
#   B. RFID và nhận dạng khuôn mặt/vân tay  →  similarity = 9.3244
#   C. Zigbee  →  similarity = 10.1951
#   D. Blockchain  →  similarity = 10.1562
# Đáp án gợi ý: B - RFID và nhận dạng khuôn mặt/vân tay
# Public001
#
#  Câu hỏi: Bộ cảm biến trong nhà thông minh thực hiện chức năng gì và bộ truyền động có vai trò gì?
#   A. Bộ cảm biến hiển thị dữ liệu, bộ truyền động thu thập dữ liệu  →  similarity = 8.3637
#   B. Bộ cảm biến lưu trữ dữ liệu, bộ truyền động hiển thị dữ liệu  →  similarity = 8.3250
#   C. Bộ cảm biến thu thập dữ liệu, bộ truyền động thực hiện lệnh từ máy chủ hoặc thiết bị điều khiển  →  similarity = 8.4127
#   D. Bộ cảm biến điều khiển thiết bị, bộ truyền động lưu trữ dữ liệu  →  similarity = 8.3850
# Đáp án gợi ý: B - Bộ cảm biến lưu trữ dữ liệu, bộ truyền động hiển thị dữ liệu
# Public019
#
#  Câu hỏi: Nội dung chính của bài báo nghiên cứu Public_001 về IoT trong xây dựng nhà thông minh là gì?
#   A. Giới thiệu các ứng dụng cụ thể của điện toán đám mây  →  similarity = 10.9261
#   B. Phân tích lợi ích và chi phí triển khai hệ thống cảm biến  →  similarity = 11.4108
#   C. Phân loại và đánh giá nghiên cứu IoT ứng dụng nhà thông minh trong 10 năm qua  →  similarity = 11.4527
#   D. Trình bày chi tiết về công nghệ vi mạch trong IoT  →  similarity = 11.5481
# Đáp án gợi ý: A - Giới thiệu các ứng dụng cụ thể của điện toán đám mây
# Public072
#
#  Câu hỏi: Dựa vào thông tin trong tài liệu Public_001, hãy tính số bài báo trung bình mỗi lớp trong nghiên cứu được đề cập.
#   A. 45-50  →  similarity = 10.3552
#   B. 55-60  →  similarity = 10.3300
#   C. 70-80  →  similarity = 11.9169
#   D. 90-100  →  similarity = 10.1353
# Đáp án gợi ý: D - 90-100
# Public072
#
#  Câu hỏi: Theo tài liệu Public_002, học phần Bảo mật Web trang bị kiến thức về bộ rủi ro phổ biến nào?
#   A. OWASP Top 10  →  similarity = 9.0374
#   B. IEEE 802.11  →  similarity = 9.4525
#   C. ISO/IEC 27001  →  similarity = 8.8918
#   D. NIST Cybersecurity Framework  →  similarity = 8.8534
# Đáp án gợi ý: D - NIST Cybersecurity Framework
# Public019
#
#  Câu hỏi: Dựa trên tài liệu Public_002, mô tả học phần Cơ sở dữ liệu nâng cao, hãy liệt kê các loại CSDL không được đề cập trong nội dung học phần này.
#   A. CSDL NoSQL  →  similarity = 10.0470
#   B. CSDL hướng đối tượng  →  similarity = 9.6025
#   C. CSDL bán cấu trúc XML  →  similarity = 9.6373
#   D. CSDL quan hệ truyền thống  →  similarity = 9.5589
# Đáp án gợi ý: D - CSDL quan hệ truyền thống
# Public019
#
#  Câu hỏi: Nêu chi tiết nội dung đào tạo về bảo mật web và bảo mật cơ sở dữ liệu trong tài liệu Public_002.
#   A. OWASP Top 10 / CSDL NoSQL  →  similarity = 10.8811
#   B. IEEE 802.11 / CSDL hướng đối tượng  →  similarity = 10.9088
#   C. DSA / CSDL bán cấu trúc XML  →  similarity = 10.9699
#   D. Toán cao cấp / CSDL quan hệ truyền thống  →  similarity = 11.4299
# Đáp án gợi ý: A - OWASP Top 10 / CSDL NoSQL
# Public033
#
#  Câu hỏi: Nhóm môn học trong tài liệu Public_002 tập trung cung cấp cho sinh viên kiến thức tổng quan về lĩnh vực nào?
#   A. Cơ khí – Điện tử  →  similarity = 9.9277
#   B. Công nghệ thông tin (CSDL, mạng, bảo mật, dữ liệu lớn, IoT, học máy)  →  similarity = 7.5129
#   C. Kinh tế – Quản lý  →  similarity = 9.7331
#   D. Ngôn ngữ học  →  similarity = 9.9574
# Đáp án gợi ý: B - Công nghệ thông tin (CSDL, mạng, bảo mật, dữ liệu lớn, IoT, học máy)
# Public017
#
#  Câu hỏi: Trong tài liệu Public_002, đối với đoạn liệt kê các học phần từ số 47 đến 81, nếu các học phần này được trải đều trên 7 trang, trung bình mỗi trang mô tả bao nhiêu học phần?
#   A. 5  →  similarity = 10.3733
#   B. 6  →  similarity = 10.5861
#   C. 7  →  similarity = 10.0191
#   D. 8  →  similarity = 10.0928
# Đáp án gợi ý: C - 7
# Public019
#
#  Câu hỏi: Điểm BLEU được dùng để đánh giá chất lượng bản dịch trong tài liệu Public_003 là gì?
#   A. Một thuật toán dịch máy  →  similarity = 10.2217
#   B. Một loại dữ liệu song ngữ  →  similarity = 9.9553
#   C. Một phương pháp đánh giá tự động chất lượng dịch máy  →  similarity = 10.1526
#   D. Một hệ dịch mã nguồn mở  →  similarity = 10.3071
# Đáp án gợi ý: B - Một loại dữ liệu song ngữ
# Public031
#
#  Câu hỏi: Công cụ nào được nhóm tác giả của tài liệu Public_003 sử dụng để huấn luyện các hệ dịch nơ ron?
#   A. Moses  →  similarity = 9.7865
#   B. OpenNMT  →  similarity = 11.0836
#   C. TensorFlow  →  similarity = 9.3547
#   D. Fairseq  →  similarity = 9.2159
# Đáp án gợi ý: D - Fairseq
# Public001
#
#  Câu hỏi: Điểm BLEU và công cụ huấn luyện hệ dịch nơ ron trong nghiên cứu này là gì?
#   A. Một thuật toán dịch máy / Moses  →  similarity = 9.9506
#   B. Một loại dữ liệu song ngữ / OpenNMT  →  similarity = 9.8316
#   C. Một phương pháp đánh giá tự động chất lượng dịch máy / TensorFlow  →  similarity = 9.2654
#   D. Một hệ dịch mã nguồn mở / Fairseq  →  similarity = 9.5456
# Đáp án gợi ý: C - Một phương pháp đánh giá tự động chất lượng dịch máy / TensorFlow
# Public001
#
#  Câu hỏi: Nội dung chính của tài liệu Public_003 là gì?
#   A. So sánh dịch máy thống kê và dịch máy ví dụ  →  similarity = 10.1350
#   B. Đề xuất phương pháp thích ứng miền mới cho dịch máy nơ ron Anh – Việt, tận dụng dữ liệu đơn ngữ ngoài miền để cải thiện chất lượng dịch  →  similarity = 9.9033
#   C. Phân tích dữ liệu song ngữ trong lĩnh vực pháp lý  →  similarity = 9.9672
#   D. Trình bày lý thuyết về RNN hai chiều  →  similarity = 10.0892
# Đáp án gợi ý: B - Đề xuất phương pháp thích ứng miền mới cho dịch máy nơ ron Anh – Việt, tận dụng dữ liệu đơn ngữ ngoài miền để cải thiện chất lượng dịch
# Public031
#
#  Câu hỏi: Theo kết quả thử nghiệm, hệ dịch Adapt_System cải thiện bao nhiêu điểm BLEU so với Baseline_G trong miền pháp lý?
#   A. 0.84  →  similarity = 9.2398
#   B. 1.37  →  similarity = 9.1576
#   C. 1.5  →  similarity = 9.5871
#   D. 2.21  →  similarity = 9.3409
# Đáp án gợi ý: B - 1.37
# Public019
#
#  Câu hỏi: Công nghệ in bê tông 3D được thực hiện theo quy trình nào?
#   A. Gia công cắt gọt vật liệu  →  similarity = 9.9964
#   B. Đúc bê tông trong ván khuôn  →  similarity = 9.9613
#   C. Sản xuất bồi đắp bằng cách chồng lớp vật liệu từ mô hình CAD  →  similarity = 10.1750
#   D. Ép nén bê tông truyền thống  →  similarity = 9.6232
# Đáp án gợi ý: D - Ép nén bê tông truyền thống
# Public019
#
#  Câu hỏi: Công nghệ nào được phát triển tại Đại học Loughborough (Anh)?
#   A. Contour Crafting  →  similarity = 10.4377
#   B. Concrete Printing  →  similarity = 10.4895
#   C. D-Shape  →  similarity = 10.4536
#   D. Emerging Objects  →  similarity = 10.7569
# Đáp án gợi ý: A - Contour Crafting
# Public072
#
#  Câu hỏi: Công nghệ in bê tông 3D nào vừa cho phép kiểm soát tốt cấu trúc sản phẩm, vừa sử dụng bê tông cốt liệu sợi tổng hợp cường độ cao?
#   A. Contour Crafting  →  similarity = 10.9373
#   B. Concrete Printing  →  similarity = 10.5955
#   C. Concrete On-Site 3D Printing  →  similarity = 10.7387
#   D. FDM  →  similarity = 10.2050
# Đáp án gợi ý: D - FDM
# Public030
#
#  Câu hỏi: Nội dung chính của bài báo Public_004 là gì?
#   A. Trình bày ứng dụng in 3D trong y tế  →  similarity = 10.8948
#   B. Giới thiệu, phân tích ưu nhược điểm các công nghệ in bê tông 3D trong xây dựng, so sánh tính khả thi áp dụng ở Việt Nam  →  similarity = 10.5447
#   C. Mô tả chi tiết công thức chế tạo bê tông UHPC  →  similarity = 10.6949
#   D. Giới thiệu công nghệ CAD trong xây dựng  →  similarity = 11.5302
# Đáp án gợi ý: B - Giới thiệu, phân tích ưu nhược điểm các công nghệ in bê tông 3D trong xây dựng, so sánh tính khả thi áp dụng ở Việt Nam
# Public095
#
#  Câu hỏi: Trong tài liệu, ưu điểm của công nghệ Contour Crafting so với Concrete Printing là gì?
#   A. Độ mịn bề mặt sản phẩm tốt hơn  →  similarity = 8.5771
#   B. Khả năng chịu lực cao hơn  →  similarity = 8.3139
#   C. Chi phí rẻ hơn  →  similarity = 8.4279
#   D. Quy mô in lớn hơn  →  similarity = 8.1303
# Đáp án gợi ý: D - Quy mô in lớn hơn
# Public001
#
#  Câu hỏi: OCR là viết tắt của gì trong bài báo này?
#   A. Optical Character Recognition  →  similarity = 9.5228
#   B. Optical Code Reader  →  similarity = 11.1212
#   C. Optical Computing Resource  →  similarity = 9.6013
#   D. Optical Capture Recognition  →  similarity = 9.7568
# Đáp án gợi ý: A - Optical Character Recognition
# Public001
#
#  Câu hỏi: Giải pháp thử nghiệm tại Học viện Ngân hàng được lựa chọn là gì, theo tài liệu Public_005?
#   A. Viettel OCR  →  similarity = 9.5103
#   B. FPT.AI Reader  →  similarity = 9.4012
#   C. Google Vision AI  →  similarity = 9.4982
#   D. Tesseract  →  similarity = 9.2668
# Đáp án gợi ý: D - Tesseract
# Public019
#
#  Câu hỏi: Công nghệ nào vừa cho phép máy tính tự động nhận biết ký tự trên hình ảnh, vừa có khả năng đọc hiểu dữ liệu chữ viết tay và chữ in?
#   A. OCR  →  similarity = 9.8458
#   B. ICR  →  similarity = 9.9116
#   C. Faster R-CNN  →  similarity = 9.4998
#   D. TransformerOCR  →  similarity = 9.6202
# Đáp án gợi ý: C - Faster R-CNN
# Public019
#
#  Câu hỏi: Nội dung chính của bài báo là gì?
#   A. Đánh giá chuyển đổi số tại ngân hàng thương mại  →  similarity = 9.4840
#   B. Giới thiệu công nghệ OCR và thử nghiệm FPT.AI Reader cho số hóa tài liệu tại Học viện Ngân hàng  →  similarity = 9.4166
#   C. Xây dựng hệ thống ERP cho giáo dục  →  similarity = 8.8501
#   D. Nghiên cứu ứng dụng AI trong tài chính  →  similarity = 9.2590
# Đáp án gợi ý: C - Xây dựng hệ thống ERP cho giáo dục
# Public001
#
#  Câu hỏi: Theo tài liệu Public_005, tỷ lệ sai số theo đơn vị từ của FPT.AI Reader trong thử nghiệm là bao nhiêu?
#   A. 0.16  →  similarity = 9.5342
#   B. 0.2  →  similarity = 9.3985
#   C. 0.27  →  similarity = 9.2739
#   D. 0.5  →  similarity = 9.5384
# Đáp án gợi ý: C - 0.27
# Public019
#
#  Câu hỏi: Theo tài liệu Public_006, các nhiệm vụ và quyền hạn của các thiết chế quản trị đại học ở Việt Nam được quy định trong luật nào?
#   A. Luật Giáo dục 2015  →  similarity = 11.5990
#   B. Luật Giáo dục đại học sửa đổi số 34/2018  →  similarity = 11.1902
#   C. Luật Công nghệ thông tin 2016  →  similarity = 11.2732
#   D. Luật Khoa học và Công nghệ 2013  →  similarity = 11.4776
# Đáp án gợi ý: B - Luật Giáo dục đại học sửa đổi số 34/2018
# Public033
#
#  Câu hỏi: Theo tài liệu Public_006, cơ quan nào có thẩm quyền cao nhất trong trường đại học?
#   A. Hội đồng trường  →  similarity = 10.2966
#   B. Ban giám hiệu  →  similarity = 10.3689
#   C. Bộ Giáo dục và Đào tạo  →  similarity = 10.5975
#   D. Hiệu trưởng  →  similarity = 10.5401
# Đáp án gợi ý: A - Hội đồng trường
# Public033
#
#  Câu hỏi: Làm thế nào để ứng dụng công nghệ số trong quản trị đại học có thể bao quát toàn bộ hoạt động của nhà trường kịp thời và hỗ trợ ra quyết sách quản lý, điều hành hiệu quả?
#   A. Quản lý sinh viên  →  similarity = 10.8220
#   B. Quản trị đại học số  →  similarity = 10.2006
#   C. Quản lý cơ sở vật chất  →  similarity = 10.5514
#   D. Quản lý tuyển sinh  →  similarity = 11.0311
# Đáp án gợi ý: B - Quản trị đại học số
# Public019
#
#  Câu hỏi: Nội dung chính của bài báo Public_006 là gì?
#   A. Trình bày ứng dụng CNTT trong giảng dạy trực tuyến  →  similarity = 9.9899
#   B. Phân tích thực trạng và đề xuất giải pháp ứng dụng công nghệ số trong công tác quản trị đại học ở Việt Nam, hướng tới đại học số  →  similarity = 10.0488
#   C. Tổng quan về cách mạng công nghiệp 4.0  →  similarity = 11.0834
#   D. Nghiên cứu vai trò của AI trong giáo dục  →  similarity = 9.6385
# Đáp án gợi ý: D - Nghiên cứu vai trò của AI trong giáo dục
# Public031
#
#  Câu hỏi: Theo số liệu trong tài liệu, đến nay ngành giáo dục đã số hóa dữ liệu của khoảng bao nhiêu giáo viên và học sinh?
#   A. 0,5 triệu giáo viên, 10 triệu học sinh  →  similarity = 9.7088
#   B. 0,8 triệu giáo viên, 15 triệu học sinh  →  similarity = 9.5286
#   C. 1,0 triệu giáo viên, 20 triệu học sinh  →  similarity = 9.3560
#   D. 1,4 triệu giáo viên, 23 triệu học sinh  →  similarity = 9.5438
# Đáp án gợi ý: C - 1,0 triệu giáo viên, 20 triệu học sinh
# Public017
#
#  Câu hỏi: ISO 15189:2022 áp dụng cho đối tượng nào?
#   A. Các công ty công nghệ thông tin  →  similarity = 9.9787
#   B. Phòng xét nghiệm y tế  →  similarity = 9.6516
#   C. Bệnh viện tư nhân  →  similarity = 9.6518
#   D. Nhà sản xuất thiết bị y tế  →  similarity = 9.5380
# Đáp án gợi ý: D - Nhà sản xuất thiết bị y tế
# Public033
#
#  Câu hỏi: Theo tiêu chuẩn trong tài liệu Public_007, “khiếu nại” được định nghĩa như thế nào?
#   A. Ý kiến góp ý tích cực về hoạt động xét nghiệm  →  similarity = 8.9834
#   B. Thắc mắc của cơ quan quản lý  →  similarity = 8.9901
#   C. Sự không hài lòng của cá nhân/tổ chức liên quan đến hoạt động hoặc kết quả xét nghiệm, nơi dự kiến có phản hồi  →  similarity = 8.3700
#   D. Báo cáo sự cố thiết bị  →  similarity = 8.7452
# Đáp án gợi ý: C - Sự không hài lòng của cá nhân/tổ chức liên quan đến hoạt động hoặc kết quả xét nghiệm, nơi dự kiến có phản hồi
# Public019
#
#  Câu hỏi: Trong các tiêu chuẩn ISO/IEC liên quan đến đo lường và đánh giá sự phù hợp, tiêu chuẩn nào cung cấp từ vựng quốc tế về đo lường và định nghĩa thuật ngữ độ chệch?
#   A. ISO/IEC 17025  →  similarity = 9.4568
#   B. ISO/IEC Guide 99  →  similarity = 10.0955
#   C. ISO/IEC 17000  →  similarity = 9.6990
#   D. ISO 18113-1  →  similarity = 9.6530
# Đáp án gợi ý: A - ISO/IEC 17025
# Public019
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn ISO 15189:2022 là gì?
#   A. Quy định các yêu cầu về quản lý tài chính của bệnh viện  →  similarity = 10.2539
#   B. Đưa ra yêu cầu về chất lượng và năng lực đối với phòng xét nghiệm y tế, bao gồm hệ thống quản lý, quy trình xét nghiệm và đánh giá công nhận  →  similarity = 9.7643
#   C. Chỉ áp dụng cho thử nghiệm lâm sàng thuốc  →  similarity = 10.1368
#   D. Hướng dẫn thiết kế thiết bị y tế  →  similarity = 10.3692
# Đáp án gợi ý: B - Đưa ra yêu cầu về chất lượng và năng lực đối với phòng xét nghiệm y tế, bao gồm hệ thống quản lý, quy trình xét nghiệm và đánh giá công nhận
# Public022
#
#  Câu hỏi: Theo Public_007, “khoảng tham chiếu sinh học” thường được định nghĩa ở mức bao nhiêu phần trăm giá trị tập trung?
#   A. 0.95  →  similarity = 8.4927
#   B. 0.5  →  similarity = 8.6789
#   C. 0.9  →  similarity = 8.5768
#   D. 0.99  →  similarity = 8.6805
# Đáp án gợi ý: A - 0.95
# Public019
#
#  Câu hỏi: Giám đốc phòng xét nghiệm theo ISO 15189:2022 có thể ủy quyền nhiệm vụ cho ai?
#   A. Bất kỳ cá nhân bên ngoài nào  →  similarity = 9.5705
#   B. Nhân viên có trình độ và năng lực, được lập thành văn bản ủy quyền  →  similarity = 8.6085
#   C. Chỉ ban giám hiệu bệnh viện  →  similarity = 10.2958
#   D. Các cơ quan quản lý  →  similarity = 9.7595
# Đáp án gợi ý: B - Nhân viên có trình độ và năng lực, được lập thành văn bản ủy quyền
# Public019
#
#  Câu hỏi: ISO 15189:2022 yêu cầu thiết lập và theo dõi những chỉ số chất lượng nào?
#   A. Tỷ lệ bác sĩ tham gia hội chẩn  →  similarity = 9.1846
#   B. Số lượng bệnh nhân nhập viện  →  similarity = 8.9486
#   C. Số lượng mẫu bị từ chối, số lỗi khi nhận mẫu, số báo cáo kết quả sửa, tỷ lệ trả kết quả đúng hạn  →  similarity = 7.8928
#   D. Tỷ lệ nhân viên tham gia đào tạo  →  similarity = 9.0238
# Đáp án gợi ý: C - Số lượng mẫu bị từ chối, số lỗi khi nhận mẫu, số báo cáo kết quả sửa, tỷ lệ trả kết quả đúng hạn
# Public017
#
#  Câu hỏi: Theo tài liệu Public_008, các yêu cầu đúng khi lựa chọn, vận hành và bảo dưỡng thiết bị phòng xét nghiệm là gì?
#   A. Thiết bị phải được vận hành bởi nhân viên đào tạo, được ủy quyền, có năng lực; được bảo trì theo hướng dẫn nhà sản xuất; có biện pháp ngăn điều chỉnh ngoài ý muốn; và thiết bị bị lỗi phải được dán nhãn “không hoạt động” cho đến khi xác minh chính xác  →  similarity = 7.2657
#   B. Thiết bị chỉ cần được vận hành theo hướng dẫn nhà sản xuất, không cần đào tạo hay dán nhãn khi lỗi  →  similarity = 8.5089
#   C. Thiết bị không cần bảo trì nếu không ảnh hưởng kết quả xét nghiệm  →  similarity = 9.0888
#   D. Nhân viên có thể điều chỉnh thiết bị bất cứ lúc nào nếu cần để đẩy nhanh công việc  →  similarity = 9.0418
# Đáp án gợi ý: A - Thiết bị phải được vận hành bởi nhân viên đào tạo, được ủy quyền, có năng lực; được bảo trì theo hướng dẫn nhà sản xuất; có biện pháp ngăn điều chỉnh ngoài ý muốn; và thiết bị bị lỗi phải được dán nhãn “không hoạt động” cho đến khi xác minh chính xác
# Public017
#
#  Câu hỏi: Nội dung chính của phần tiêu chuẩn trong tài liệu là gì?
#   A. Quy định quy trình khám chữa bệnh cho bệnh nhân  →  similarity = 10.2721
#   B. Đưa ra yêu cầu về cơ cấu, quản trị, nhân lực, cơ sở vật chất, thiết bị, thuốc thử và quá trình xét nghiệm trong phòng xét nghiệm y tế  →  similarity = 9.0789
#   C. Mô tả chi tiết hệ thống tài chính của bệnh viện  →  similarity = 10.4700
#   D. Hướng dẫn xây dựng nhà máy y tế  →  similarity = 10.3508
# Đáp án gợi ý: B - Đưa ra yêu cầu về cơ cấu, quản trị, nhân lực, cơ sở vật chất, thiết bị, thuốc thử và quá trình xét nghiệm trong phòng xét nghiệm y tế
# Public031
#
#  Câu hỏi: Nếu phòng xét nghiệm có 500 mẫu xét nghiệm trong tháng, trong đó có 25 mẫu bị từ chối, tỷ lệ từ chối mẫu là bao nhiêu?
#   A. 0.05  →  similarity = 8.8824
#   B. 0.025  →  similarity = 8.9573
#   C. 0.1  →  similarity = 8.7339
#   D. 0.075  →  similarity = 8.9632
# Đáp án gợi ý: C - 0.1
# Public019
#
#  Câu hỏi: Học phần Những nguyên lý cơ bản của Chủ nghĩa Mác – Lênin thuộc khối kiến thức nào?
#   A. Giáo dục đại cương  →  similarity = 10.1876
#   B. Tin học cơ sở  →  similarity = 10.3353
#   C. Công nghệ phần mềm  →  similarity = 10.4857
#   D. Hệ thống thông tin  →  similarity = 9.9171
# Đáp án gợi ý: D - Hệ thống thông tin
# Public019
#
#  Câu hỏi: Học phần Nhập môn ngành CNTT trang bị cho sinh viên những kỹ năng nào ngoài kiến thức chuyên ngành?
#   A. Kỹ năng nghiên cứu khoa học nâng cao  →  similarity = 10.1422
#   B. Kỹ năng quản lý dự án phức tạp  →  similarity = 9.7125
#   C. Kỹ năng mềm như làm việc nhóm, thuyết trình, tìm kiếm thông tin, phương pháp học đại học  →  similarity = 8.6723
#   D. Kỹ năng phân tích tài chính  →  similarity = 9.9524
# Đáp án gợi ý: C - Kỹ năng mềm như làm việc nhóm, thuyết trình, tìm kiếm thông tin, phương pháp học đại học
# Public033
#
#  Câu hỏi: Học phần nào vừa giúp sinh viên năm nhất làm quen với môi trường đại học và kiến thức cơ bản ngành CNTT, vừa rèn luyện các kỹ năng mềm và chuẩn mực đạo đức cần thiết để trở thành kỹ sư công nghệ thông tin?
#   A. Toán 1  →  similarity = 11.2113
#   B. Toán 2  →  similarity = 10.8676
#   C. Nhập môn ngành CNTT  →  similarity = 10.0870
#   D. Đại số và cấu trúc đại số  →  similarity = 10.1088
# Đáp án gợi ý: C - Nhập môn ngành CNTT
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu lịch sử phát triển ngành CNTT  →  similarity = 10.8439
#   B. Mô tả vắn tắt nội dung và khối lượng các học phần bắt buộc, cơ sở và chuyên ngành trong chương trình đào tạo CNTT  →  similarity = 10.1246
#   C. Phân tích xu hướng việc làm CNTT  →  similarity = 10.8622
#   D. Đề xuất cải tiến phương pháp giảng dạy CNTT  →  similarity = 10.7168
# Đáp án gợi ý: B - Mô tả vắn tắt nội dung và khối lượng các học phần bắt buộc, cơ sở và chuyên ngành trong chương trình đào tạo CNTT
# Public010
#
#  Câu hỏi: Theo quy định tại tài liệu Public_009, nếu một học phần có cấu trúc 3(2:1:6) thì số tiết lý thuyết, thực hành và tự học lần lượt là bao nhiêu?
#   A. 3 LT, 3 TH, 6 tự học  →  similarity = 9.0670
#   B. 2 LT, 2 TH, 4 tự học  →  similarity = 9.3471
#   C. 2 LT, 1 TH, 6 tự học  →  similarity = 9.1632
#   D. 3 LT, 0 TH, 6 tự học  →  similarity = 8.9912
# Đáp án gợi ý: D - 3 LT, 0 TH, 6 tự học
# Public019
#
#  Câu hỏi: Theo tiêu chuẩn ISO 15189:2022, việc lưu giữ hồ sơ phòng xét nghiệm nhằm mục đích chính nào?
#   A. Đảm bảo nhân viên phòng xét nghiệm có đủ kỹ năng  →  similarity = 8.9282
#   B. Giảm chi phí vận hành  →  similarity = 9.9323
#   C. Truy xuất được kết quả xét nghiệm trong khoảng thời gian cần thiết hoặc theo quy định  →  similarity = 8.6257
#   D. Đình chỉ hoạt động của phòng xét nghiệm  →  similarity = 9.3133
# Đáp án gợi ý: C - Truy xuất được kết quả xét nghiệm trong khoảng thời gian cần thiết hoặc theo quy định
# Public019
#
#  Câu hỏi: Khi xảy ra sự không phù hợp, hành động đầu tiên mà phòng xét nghiệm phải thực hiện theo ISO 15189:2022 là gì?
#   A. Kiểm soát và khắc phục sự không phù hợp  →  similarity = 9.9605
#   B. Đình chỉ hoạt động của phòng xét nghiệm vô thời hạn  →  similarity = 9.6437
#   C. Giảm chi phí vận hành  →  similarity = 10.1505
#   D. Miễn trừ trách nhiệm cho nhân viên gây lỗi  →  similarity = 9.6653
# Đáp án gợi ý: B - Đình chỉ hoạt động của phòng xét nghiệm vô thời hạn
# Public022
#
#  Câu hỏi: Theo hướng dẫn về kiểm soát hồ sơ, phòng xét nghiệm phải đảm bảo điều gì khi sửa đổi hồ sơ?
#   A. Các sửa đổi phải có khả năng truy nguyên đến phiên bản trước hoặc các quan sát ban đầu, bao gồm ngày, giờ, nội dung thay đổi và nhân viên thực hiện  →  similarity = 8.8999
#   B. Chỉ cần lưu trữ phiên bản mới của hồ sơ, không cần lưu dữ liệu gốc  →  similarity = 10.5574
#   C. Chỉ cần lưu ngày và giờ của phiên bản mới, không cần thông tin về thay đổi  →  similarity = 9.9462
#   D. Không cần lưu hồ sơ nếu chỉ là sửa đổi nhỏ  →  similarity = 10.8613
# Đáp án gợi ý: A - Các sửa đổi phải có khả năng truy nguyên đến phiên bản trước hoặc các quan sát ban đầu, bao gồm ngày, giờ, nội dung thay đổi và nhân viên thực hiện
# Public031
#
#  Câu hỏi: Nội dung chính của phần 8 trong tiêu chuẩn ISO 15189:2022 là gì?
#   A. Yêu cầu về cơ sở vật chất và thiết bị  →  similarity = 9.2924
#   B. Quy định về kỹ thuật xét nghiệm  →  similarity = 9.4902
#   C. Yêu cầu hệ thống quản lý, bao gồm tài liệu, hồ sơ, kiểm soát rủi ro, cải tiến, đánh giá và xem xét  →  similarity = 7.6727
#   D. Quy định về đạo đức nghề nghiệp của nhân viên phòng xét nghiệm  →  similarity = 9.2868
# Đáp án gợi ý: C - Yêu cầu hệ thống quản lý, bao gồm tài liệu, hồ sơ, kiểm soát rủi ro, cải tiến, đánh giá và xem xét
# Public001
#
#  Câu hỏi: Theo tài liệu Public_010, nếu một phòng xét nghiệm thiết lập cấu trúc quản lý 5 mục tiêu và mỗi mục tiêu yêu cầu số hành động cải tiến tối thiểu theo quy định của tài liệu, tổng số hành động tối thiểu là bao nhiêu?
#   A. 5  →  similarity = 9.6243
#   B. 10  →  similarity = 9.4671
#   C. 15  →  similarity = 9.3148
#   D. 20  →  similarity = 9.1271
# Đáp án gợi ý: D - 20
# Public019
#
#  Câu hỏi: Mạng GAN (Global Area Network) là gì?
#   A. Mạng cục bộ trong phạm vi nhỏ  →  similarity = 9.3959
#   B. Mạng diện rộng trong một quốc gia  →  similarity = 8.9355
#   C. Mạng toàn cầu, kết hợp nhiều mạng con, ví dụ Internet  →  similarity = 8.6892
#   D. Mạng kết nối 2–3 máy tính  →  similarity = 9.0274
# Đáp án gợi ý: C - Mạng toàn cầu, kết hợp nhiều mạng con, ví dụ Internet
# Public001
#
#  Câu hỏi: Thành phần nào có chức năng giao tiếp giữa máy tính và đường truyền trong mạng máy tính?
#   A. Bộ định tuyến (Router)  →  similarity = 9.9749
#   B. Vỉ mạng (Network Interface Card – NIC)  →  similarity = 9.2609
#   C. Thiết bị đầu cuối (Terminal)  →  similarity = 9.5823
#   D. Phần mềm ứng dụng  →  similarity = 10.2109
# Đáp án gợi ý: B - Vỉ mạng (Network Interface Card – NIC)
# Public019
#
#  Câu hỏi: Mạng máy tính được phân loại theo những tiêu chí nào và Internet ban đầu ra đời từ mục đích gì?
#   A. Mạng được phân loại theo quan hệ giữa các máy và theo quy mô địa lý; Internet ban đầu ra đời từ mục đích quân sự của Bộ Quốc phòng Mỹ  →  similarity = 9.6351
#   B. Mạng được phân loại theo tốc độ và dung lượng; Internet ban đầu ra đời để phục vụ thương mại điện tử  →  similarity = 9.2687
#   C. Mạng được phân loại theo số lượng người dùng và chi phí; Internet ban đầu ra đời để phục vụ cho các công ty công nghệ  →  similarity = 9.4906
#   D. Mạng được phân loại theo loại đường truyền và phần mềm; Internet ban đầu ra đời để phục vụ giáo dục phổ thôngComplete  →  similarity = 8.8974
# Đáp án gợi ý: D - Mạng được phân loại theo loại đường truyền và phần mềm; Internet ban đầu ra đời để phục vụ giáo dục phổ thôngComplete
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu Public_011 là gì?
#   A. Giới thiệu lịch sử Internet toàn cầu  →  similarity = 11.3413
#   B. Trình bày khái niệm, lịch sử phát triển, phân loại, thành phần, kiến trúc mạng máy tính và Internet  →  similarity = 8.0089
#   C. Hướng dẫn cài đặt phần mềm mạng  →  similarity = 10.0608
#   D. Phân tích mô hình OSI chi tiết  →  similarity = 9.9981
# Đáp án gợi ý: B - Trình bày khái niệm, lịch sử phát triển, phân loại, thành phần, kiến trúc mạng máy tính và Internet
# Public031
#
#  Câu hỏi: Với một mạng kết nối 200 máy tính và có bán kính hoạt động 500m trong một tòa nhà, phân loại mạng chính xác nhất của nó là gì?
#   A. LAN (Local Area Network)  →  similarity = 9.7839
#   B. WAN (Wide Area Network)  →  similarity = 9.8124
#   C. GAN (Global Area Network)  →  similarity = 9.8061
#   D. MAN (Metropolitan Area Network)  →  similarity = 10.0516
# Đáp án gợi ý: A - LAN (Local Area Network)
# Public030
#
#  Câu hỏi: Hệ điều hành có nhiệm vụ gì?
#   A. Chỉ lưu trữ dữ liệu cho máy tính  →  similarity = 9.5850
#   B. Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình và cung cấp dịch vụ cho người dùng  →  similarity = 7.9302
#   C. Tạo ra phần cứng mới  →  similarity = 9.6153
#   D. Truyền dữ liệu qua mạng  →  similarity = 9.2074
# Đáp án gợi ý: B - Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình và cung cấp dịch vụ cho người dùng
# Public019
#
#  Câu hỏi: Theo tài liệu, ký hiệu đại diện * trong tên tệp có ý nghĩa gì?
#   A. Đại diện cho một ký tự bất kỳ  →  similarity = 9.2475
#   B. Đại diện cho số bất kỳ  →  similarity = 9.0823
#   C. Đại diện cho một chuỗi ký tự bất kỳ  →  similarity = 9.2415
#   D. Đại diện cho phần mở rộng bắt buộc  →  similarity = 9.5355
# Đáp án gợi ý: B - Đại diện cho số bất kỳ
# Public019
#
#  Câu hỏi: Hệ điều hành có những nhiệm vụ chính nào và phiên bản Windows nào cho phép đặt tên tệp dài tới 255 ký tự?
#   A. Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình, giao tiếp với người dùng; Windows 95  →  similarity = 8.0299
#   B. Chỉ quản lý bộ nhớ và CPU; Windows 3.0 AUTOEXEC.BAT  →  similarity = 9.1555
#   C. Chỉ khởi động máy và tắt máy; Windows NT 4.0  →  similarity = 9.1522
#   D. Quản lý thiết bị ngoại vi nhưng không quản lý tệp; Windows XP  →  similarity = 9.0424
# Đáp án gợi ý: A - Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình, giao tiếp với người dùng; Windows 95
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu lịch sử phát triển phần cứng  →  similarity = 10.7127
#   B. Trình bày khái niệm, quản lý tệp, hệ lệnh, hệ điều hành Windows (từ MS-DOS, Windows 95 đến Windows XP)  →  similarity = 8.3515
#   C. Hướng dẫn cài đặt phần mềm diệt virus  →  similarity = 10.9941
#   D. Phân tích mô hình mạng OSI  →  similarity = 10.4973
# Đáp án gợi ý: B - Trình bày khái niệm, quản lý tệp, hệ lệnh, hệ điều hành Windows (từ MS-DOS, Windows 95 đến Windows XP)
# Public010
#
#  Câu hỏi: Nếu Windows XP quản lý cho phép đặt tên tập tin dài tối đa 255 ký tự, còn MS-DOS chỉ cho phép tối đa 8 ký tự, thì Windows XP dài hơn bao nhiêu ký tự?
#   A. 120 ký tự  →  similarity = 10.0543
#   B. 200 ký tự  →  similarity = 10.0214
#   C. 247 ký tự  →  similarity = 10.0697
#   D. 300 ký tự  →  similarity = 10.0737
# Đáp án gợi ý: B - 200 ký tự
# Public019
#
#  Câu hỏi: Thế hệ máy tính điện tử nào sử dụng bóng đèn điện tử chân không?
#   A. Thế hệ 1 (1950–1958)  →  similarity = 9.5383
#   B. Thế hệ 2 (1958–1964)  →  similarity = 9.4078
#   C. Thế hệ 3 (1965–1974)  →  similarity = 9.4378
#   D. Thế hệ 4 (1974–nay)  →  similarity = 8.9399
# Đáp án gợi ý: D - Thế hệ 4 (1974–nay)
# Public030
#
#  Câu hỏi: Thuật ngữ “Tin học” (Informatics) lần đầu tiên được đề xuất bởi ai?
#   A. Philippe Dreyfus  →  similarity = 8.9012
#   B. Karl Steinbuch  →  similarity = 8.7642
#   C. Walter F. Bauer  →  similarity = 8.7966
#   D. Alan Turing  →  similarity = 8.9564
# Đáp án gợi ý: B - Karl Steinbuch
# Public001
#
#  Câu hỏi: Thông tin khác dữ liệu ở điểm nào và quá trình xử lý thông tin theo máy tính gồm những bước nào?
#   A. Thông tin có ý nghĩa, dữ liệu là sự kiện thô; xử lý gồm Input – Process – Output  →  similarity = 8.4120
#   B. Thông tin và dữ liệu giống nhau; xử lý chỉ có Output  →  similarity = 9.4637
#   C. Dữ liệu có ý nghĩa, thông tin không có; xử lý chỉ có Input  →  similarity = 8.5699
#   D. Thông tin chỉ là dữ liệu lưu trữ; xử lý không cần qua các bước  →  similarity = 10.6555
# Đáp án gợi ý: A - Thông tin có ý nghĩa, dữ liệu là sự kiện thô; xử lý gồm Input – Process – Output
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Trình bày chi tiết về mạng máy tính  →  similarity = 11.1163
#   B. Giới thiệu các khái niệm cơ bản về dữ liệu, thông tin, tri thức; lịch sử phát triển máy tính; khái niệm tin học, CNTT và ICT  →  similarity = 8.5052
#   C. Hướng dẫn cài đặt phần mềm  →  similarity = 11.0708
#   D. Phân tích chi tiết hệ điều hành Windows  →  similarity = 10.6580
# Đáp án gợi ý: B - Giới thiệu các khái niệm cơ bản về dữ liệu, thông tin, tri thức; lịch sử phát triển máy tính; khái niệm tin học, CNTT và ICT
# Public010
#
#  Câu hỏi: Nếu một máy tính thế hệ 2 có tốc độ trung bình 50.000 phép tính/giây, thì nó nhanh gấp bao nhiêu lần so với máy thế hệ 1 tốc độ trung bình 1.000 phép tính/giây?
#   A. 25 lần  →  similarity = 10.1620
#   B. 30 lần  →  similarity = 10.1271
#   C. 50 lần  →  similarity = 10.0243
#   D. 100 lần  →  similarity = 10.0725
# Đáp án gợi ý: C - 50 lần
# Public031
#
#  Câu hỏi: Bit là viết tắt của từ gì?
#   A. Binary digiT  →  similarity = 10.5873
#   B. Basic information type  →  similarity = 11.3052
#   C. Binary integration tool  →  similarity = 10.5933
#   D. Base information token  →  similarity = 11.1976
# Đáp án gợi ý: A - Binary digiT
# Public095
#
#  Câu hỏi: Trong hệ đếm thập lục phân, ký tự “F” biểu diễn giá trị thập phân nào?
#   A. 12  →  similarity = 9.2617
#   B. 14  →  similarity = 9.3544
#   C. 15  →  similarity = 9.3015
#   D. 16  →  similarity = 9.2365
# Đáp án gợi ý: D - 16
# Public058
#
#  Câu hỏi: Trong máy tính, mọi dữ liệu được biểu diễn dưới dạng gì và đơn vị thông tin nhỏ nhất là gì?
#   A. Dưới dạng chữ cái; đơn vị nhỏ nhất là byte  →  similarity = 9.1900
#   B. Dưới dạng nhị phân (chuỗi bit); đơn vị nhỏ nhất là bit  →  similarity = 8.9407
#   C. Dưới dạng số thập phân; đơn vị nhỏ nhất là ký tự  →  similarity = 9.2631
#   D. Dưới dạng tín hiệu tương tự; đơn vị nhỏ nhất là từ  →  similarity = 9.0979
# Đáp án gợi ý: B - Dưới dạng nhị phân (chuỗi bit); đơn vị nhỏ nhất là bit
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu mạng máy tính  →  similarity = 10.6664
#   B. Trình bày biểu diễn dữ liệu trong máy tính: các hệ đếm, số nguyên, số thực, dữ liệu ký tự, số hóa tín hiệu và tính toán số học  →  similarity = 8.2444
#   C. Giới thiệu hệ điều hành Windows  →  similarity = 10.1802
#   D. Hướng dẫn lập trình Pascal  →  similarity = 11.3149
# Đáp án gợi ý: B - Trình bày biểu diễn dữ liệu trong máy tính: các hệ đếm, số nguyên, số thực, dữ liệu ký tự, số hóa tín hiệu và tính toán số học
# Public010
#
#  Câu hỏi: Nếu dùng 8 bit để biểu diễn số nguyên không dấu, giá trị lớn nhất có thể biểu diễn là bao nhiêu?
#   A. 128  →  similarity = 9.8422
#   B. 254  →  similarity = 9.9320
#   C. 255  →  similarity = 9.9848
#   D. 256  →  similarity = 10.0212
# Đáp án gợi ý: A - 128
# Public019
#
#  Câu hỏi: Khối nào trong CPU có nhiệm vụ thực hiện các phép tính số học và logic?
#   A. Khối điều khiển (CU)  →  similarity = 10.2568
#   B. Khối số học và logic (ALU)  →  similarity = 10.2520
#   C. Tập thanh ghi  →  similarity = 10.9464
#   D. Bộ nhớ ngoài  →  similarity = 10.9054
# Đáp án gợi ý: B - Khối số học và logic (ALU)
# Public005
#
#  Câu hỏi: Bộ nhớ nào lưu trữ chương trình hệ thống và không bị mất dữ liệu khi tắt máy?
#   A. ROM  →  similarity = 9.9393
#   B. RAM  →  similarity = 9.3111
#   C. Cache  →  similarity = 9.8082
#   D. Thanh ghi  →  similarity = 9.6401
# Đáp án gợi ý: B - RAM
# Public019
#
#  Câu hỏi: CPU gồm những bộ phận chính nào và bộ nhớ chính của máy tính được chia thành những loại nào?
#   A. Khối điều khiển, bộ nhớ ngoài, bàn phím; chỉ RAM  →  similarity = 9.1570
#   B. Khối điều khiển, khối tính toán số học – logic, các thanh ghi; ROM và RAM  →  similarity = 10.0186
#   C. ALU, ổ đĩa cứng, USB; chỉ ROM  →  similarity = 9.4548
#   D. Bo mạch chủ, cache, màn hình; DVD và CD  →  similarity = 9.1702
# Đáp án gợi ý: A - Khối điều khiển, bộ nhớ ngoài, bàn phím; chỉ RAM
# Public008
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Trình bày chi tiết lịch sử phát triển máy tính  →  similarity = 10.9625
#   B. Giới thiệu cấu trúc và chức năng CPU, các loại bộ nhớ, thiết bị vào-ra và hệ thống bus trong máy tính  →  similarity = 10.0620
#   C. Hướng dẫn cài đặt phần mềm hệ thống  →  similarity = 10.9872
#   D. Phân tích hệ điều hành Windows  →  similarity = 10.5498
# Đáp án gợi ý: B - Giới thiệu cấu trúc và chức năng CPU, các loại bộ nhớ, thiết bị vào-ra và hệ thống bus trong máy tính
# Public010
#
#  Câu hỏi: Nếu một CPU có 36 bit địa chỉ, dung lượng tối đa của bộ nhớ chính mà nó quản lý được là bao nhiêu?
#   A. 64 MB  →  similarity = 9.9540
#   B. 64 KB  →  similarity = 10.0489
#   C. 64 GB  →  similarity = 9.8639
#   D. 64 TB  →  similarity = 10.0562
# Đáp án gợi ý: C - 64 GB
# Public019
#
#  Câu hỏi: Tiêu chuẩn TCVN 9395:2012 áp dụng cho loại cọc nào?
#   A. Cọc đóng bê tông cốt thép có đường kính nhỏ hơn 60 cm  →  similarity = 9.9067
#   B. Cọc khoan nhồi bê tông cốt thép có đường kính ≥ 60 cm (trừ công trình địa chất đặc biệt)  →  similarity = 9.2874
#   C. Cọc thép ống nhồi bê tông  →  similarity = 9.5960
#   D. Tất cả các loại cọc dùng trong xây dựng  →  similarity = 9.3573
# Đáp án gợi ý: B - Cọc khoan nhồi bê tông cốt thép có đường kính ≥ 60 cm (trừ công trình địa chất đặc biệt)
# Public022
#
#  Câu hỏi: Dung dịch khoan bentonite có vai trò chính gì trong thi công cọc khoan nhồi?
#   A. Giữ ổn định thành hố khoan, ngăn sụt lở và đưa mùn khoan ra ngoài  →  similarity = 9.2623
#   B. Tăng khả năng chịu lực của bê tông  →  similarity = 9.5983
#   C. Làm phụ gia thay thế xi măng  →  similarity = 9.7261
#   D. Giảm độ nhớt của bê tông  →  similarity = 9.6118
# Đáp án gợi ý: A - Giữ ổn định thành hố khoan, ngăn sụt lở và đưa mùn khoan ra ngoài
# Public017
#
#  Câu hỏi: Theo TCVN 9395:2012, tiêu chuẩn này áp dụng cho loại cọc nào và từ đường kính bao nhiêu trở lên?
#   A. Cọc ép, từ 20 cm  →  similarity = 9.2211
#   B. Cọc khoan nhồi, từ 30 cm  →  similarity = 8.9610
#   C. Cọc thép, từ 25 cm  →  similarity = 9.0281
#   D. Cọc gỗ, từ 40 cm  →  similarity = 10.1211
# Đáp án gợi ý: B - Cọc khoan nhồi, từ 30 cm
# Public019
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn TCVN 9395:2012 là gì?
#   A. Quy định thiết kế kết cấu móng  →  similarity = 10.1166
#   B. Hướng dẫn phương pháp thí nghiệm tải trọng cọc  →  similarity = 10.3886
#   C. Quy định về thi công, kiểm tra chất lượng, nghiệm thu và an toàn lao động trong xây dựng cọc khoan nhồi  →  similarity = 8.7544
#   D. Chỉ quy định về yêu cầu an toàn trong công tác khoan  →  similarity = 10.2213
# Đáp án gợi ý: C - Quy định về thi công, kiểm tra chất lượng, nghiệm thu và an toàn lao động trong xây dựng cọc khoan nhồi
# Public022
#
#  Câu hỏi: Nếu trong quá trình khoan, cao độ dung dịch khoan phải luôn cao hơn mực nước ngầm ít nhất 1,5 m, giả sử mực nước ngầm ở -10 m thì cao độ dung dịch khoan tối thiểu phải đạt bao nhiêu?
#   A. -11,5 m  →  similarity = 9.4924
#   B. -8,5 m  →  similarity = 9.3112
#   C. -6,0 m  →  similarity = 9.6406
#   D. -5,0 m  →  similarity = 9.6744
# Đáp án gợi ý: B - -8,5 m
# Public030
#
#  Câu hỏi: Theo TCVN 5574:2018, tính toán kết cấu bê tông và bê tông cốt thép cần được thực hiện dựa trên những trạng thái giới hạn nào?
#   A. Chỉ trạng thái giới hạn thứ nhất  →  similarity = 10.0842
#   B. Trạng thái giới hạn thứ nhất và trạng thái giới hạn thứ hai  →  similarity = 10.9406
#   C. Chỉ trạng thái giới hạn thứ hai  →  similarity = 9.8940
#   D. Không yêu cầu xét trạng thái giới hạn  →  similarity = 9.4343
# Đáp án gợi ý: D - Không yêu cầu xét trạng thái giới hạn
# Public019
#
#  Câu hỏi: Các loại bê tông nào được phép sử dụng khi thiết kế kết cấu theo TCVN 5574:2018?
#   A. Bê tông nặng  →  similarity = 11.3672
#   B. Bê tông hạt nhỏ  →  similarity = 11.3037
#   C. Bê tông nhẹ, bê tông tổ ong  →  similarity = 11.2079
#   D. Bê tông tự ứng suất  →  similarity = 10.9152
# Đáp án gợi ý: D - Bê tông tự ứng suất
# Public010
#
#  Câu hỏi: Theo TCVN 9379:2012, tính toán kết cấu bê tông và bê tông cốt thép cần được thực hiện theo những trạng thái giới hạn nào và phải đảm bảo điều gì trong suốt thời hạn sử dụng công trình?
#   A. Trạng thái giới hạn thứ nhất và thứ hai; đảm bảo độ tin cậy của công trình  →  similarity = 8.7971
#   B. Chỉ trạng thái giới hạn thứ nhất; đảm bảo hình thành vết nứt nhỏ  →  similarity = 9.4362
#   C. Trạng thái giới hạn thứ hai và tải trọng tiêu chuẩn; đảm bảo không có biến dạng  →  similarity = 9.0256
#   D. Trạng thái giới hạn về biến dạng; đảm bảo không xuất hiện ứng suất trước  →  similarity = 8.7482
# Đáp án gợi ý: D - Trạng thái giới hạn về biến dạng; đảm bảo không xuất hiện ứng suất trước
# Public019
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn TCVN 5574:2018 là gì?
#   A. Quy định về phương pháp thí nghiệm vật liệu bê tông  →  similarity = 10.6759
#   B. Nguyên tắc thiết kế, tính toán độ bền, ổn định, biến dạng, nứt và quy định về vật liệu cho kết cấu bê tông, bê tông cốt thép  →  similarity = 8.7698
#   C. Chỉ quy định về cấu kiện bê tông dự ứng lực  →  similarity = 10.7198
#   D. Hướng dẫn thi công và nghiệm thu công trình bê tông  →  similarity = 10.8212
# Đáp án gợi ý: B - Nguyên tắc thiết kế, tính toán độ bền, ổn định, biến dạng, nứt và quy định về vật liệu cho kết cấu bê tông, bê tông cốt thép
# Public033
#
#  Câu hỏi: Nếu một dầm bê tông cốt thép có nhịp 6 m, theo TCVN 5574:2018 độ võng tối đa cho phép là 1/150 nhịp, giá trị võng lớn nhất cho phép là bao nhiêu?
#   A. 20 mm  →  similarity = 10.1660
#   B. 30 mm  →  similarity = 10.2344
#   C. 40 mm  →  similarity = 10.3057
#   D. 50 mm  →  similarity = 10.1913
# Đáp án gợi ý: A - 20 mm
# Public017
#
#  Câu hỏi: Tiêu chuẩn TCVN 5574:2018 áp dụng cho những loại bê tông nào?
#   A. Bê tông nặng  →  similarity = 9.9726
#   B. Bê tông hạt nhỏ  →  similarity = 10.1062
#   C. Bê tông nhẹ, bê tông tổ ong  →  similarity = 8.6312
#   D. Bê tông tự ứng suất  →  similarity = 9.8047
# Đáp án gợi ý: C - Bê tông nhẹ, bê tông tổ ong
# Public022
#
#  Câu hỏi: Tiêu chuẩn TCVN 5574:2018 không áp dụng để thiết kế loại kết cấu nào sau đây?
#   A. Kết cấu nhà và công trình chịu nhiệt độ từ -70°C đến +50°C  →  similarity = 9.3163
#   B. Kết cấu bê tông cốt thép nhà dân dụng thông thường  →  similarity = 9.4980
#   C. Kết cấu liên hợp thép – bê tông, bê tông cốt sợi, công trình thủy công, cầu…  →  similarity = 7.7102
#   D. Các công trình không xâm thực thông thường  →  similarity = 10.0910
# Đáp án gợi ý: C - Kết cấu liên hợp thép – bê tông, bê tông cốt sợi, công trình thủy công, cầu…
# Public022
#
#  Câu hỏi: Theo TCVN 9379:2012, tính toán kết cấu bê tông và bê tông cốt thép cần được tiến hành theo những trạng thái giới hạn nào và phải đảm bảo điều gì trong suốt thời hạn sử dụng công trình?
#   A. Trạng thái giới hạn thứ nhất và thứ hai; đảm bảo độ tin cậy của công trình  →  similarity = 8.9008
#   B. Chỉ trạng thái giới hạn thứ nhất; đảm bảo không xuất hiện vết nứt  →  similarity = 9.5976
#   C. Trạng thái giới hạn thứ hai; đảm bảo công trình không có biến dạng  →  similarity = 8.4575
#   D. Trạng thái giới hạn ổn định vị trí; đảm bảo không trượt, không lật  →  similarity = 8.3628
# Đáp án gợi ý: D - Trạng thái giới hạn ổn định vị trí; đảm bảo không trượt, không lật
# Public019
#
#  Câu hỏi: Nội dung chính của phần yêu cầu chung đối với kết cấu bê tông và bê tông cốt thép trong TCVN 5574:2018 là gì?
#   A. Hướng dẫn chi tiết về phương pháp thí nghiệm cường độ bê tông  →  similarity = 9.9915
#   B. Quy định các yêu cầu về an toàn, điều kiện sử dụng, độ bền lâu, yêu cầu cấu tạo và tính toán  →  similarity = 8.2152
#   C. Chỉ quy định về cốt thép dự ứng lực  →  similarity = 10.4423
#   D. Các yêu cầu bảo trì công trình sau khi hoàn thành  →  similarity = 10.0575
# Đáp án gợi ý: B - Quy định các yêu cầu về an toàn, điều kiện sử dụng, độ bền lâu, yêu cầu cấu tạo và tính toán
# Public001
#
#  Câu hỏi: Nếu một cấu kiện bê tông làm việc trong môi trường xâm thực, theo TCVN 5574:2018, cần đảm bảo thêm yêu cầu gì ngoài an toàn và sử dụng bình thường?
#   A. Không cần bổ sung yêu cầu nào  →  similarity = 8.7755
#   B. Giảm kích thước tiết diện để tiết kiệm vật liệu  →  similarity = 8.4982
#   C. Yêu cầu về độ bền lâu và bảo vệ chống xâm thực  →  similarity = 8.7195
#   D. Chỉ cần tăng cường số lượng cốt thép  →  similarity = 8.5329
# Đáp án gợi ý: B - Giảm kích thước tiết diện để tiết kiệm vật liệu
# Public019
#
#  Câu hỏi: Hệ thống chống sét theo TCVN 9385:2012 bao gồm mấy phần chính?
#   A. 2  →  similarity = 10.5239
#   B. 3  →  similarity = 9.9853
#   C. 4  →  similarity = 10.1630
#   D. 5  →  similarity = 10.2500
# Đáp án gợi ý: B - 3
# Public019
#
#  Câu hỏi: Bộ phận nào trong hệ thống chống sét có nhiệm vụ thu sét trực tiếp?
#   A. Hệ thống thu sét (kim thu sét, dây dẫn trên mái…)  →  similarity = 8.6392
#   B. Hệ thống nối đất  →  similarity = 9.8746
#   C. Hệ thống dây dẫn sét  →  similarity = 9.8976
#   D. Hệ thống cân bằng điện thế  →  similarity = 9.7253
# Đáp án gợi ý: A - Hệ thống thu sét (kim thu sét, dây dẫn trên mái…)
# Public019
#
#  Câu hỏi: Quốc gia nào là nước đầu tiên công bố Kế hoạch chiến lược trí tuệ nhân tạo quốc gia và vào năm nào?
#   A. Trung Quốc, năm 2017  →  similarity = 9.5518
#   B. Mỹ, năm 2016  →  similarity = 9.7856
#   C. Pháp, năm 2018  →  similarity = 9.5427
#   D. Nhật Bản, năm 2019  →  similarity = 9.3119
# Đáp án gợi ý: D - Nhật Bản, năm 2019
# Public018
#
#  Câu hỏi: Nội dung chính của TCVN 9385:2012 là gì?
#   A. Quy định về tính toán tải trọng gió  →  similarity = 10.0209
#   B. Quy định thiết kế, thi công, kiểm tra, bảo trì hệ thống chống sét cho công trình  →  similarity = 8.9165
#   C. Chỉ hướng dẫn cách lắp đặt kim thu sét  →  similarity = 10.4535
#   D. Hướng dẫn vận hành thiết bị điện cao thế  →  similarity = 10.3623
# Đáp án gợi ý: B - Quy định thiết kế, thi công, kiểm tra, bảo trì hệ thống chống sét cho công trình
# Public010
#
#  Câu hỏi: Một công trình cao 30 m cần bảo vệ chống sét trực tiếp. Theo bán kính bảo vệ của kim thu sét (r = 1,5h), bán kính bảo vệ tối đa là bao nhiêu?
#   A. 30 m  →  similarity = 9.1712
#   B. 40 m  →  similarity = 9.1314
#   C. 45 m  →  similarity = 9.0927
#   D. 45 m  →  similarity = 9.0927
# Đáp án gợi ý: C - 45 m
# Public017
#
#  Câu hỏi: Chiều dày màng khô của lớp phủ chống cháy được xác định bằng cách nào?
#   A. Quan sát trực quan sau khi phủ  →  similarity = 9.6752
#   B. Đo trực tiếp trên mẫu thử nghiệm bằng dụng cụ cảm ứng điện từ hoặc dòng điện xoáy  →  similarity = 9.8232
#   C. Dùng cân xác định khối lượng riêng  →  similarity = 9.7196
#   D. So sánh với mẫu chuẩn  →  similarity = 10.0652
# Đáp án gợi ý: A - Quan sát trực quan sau khi phủ
# Public030
#
#  Câu hỏi: Loại đầu đo nhiệt nào được ưu tiên sử dụng trong thử nghiệm cấu kiện thép?
#   A. Loại “J” trần không bọc  →  similarity = 9.4245
#   B. Loại “N” bọc nhựa  →  similarity = 9.4499
#   C. Loại “T”, “N”, “K”, “J” có vỏ bọc thép không gỉ cách nhiệt bằng sợi khoáng  →  similarity = 9.7298
#   D. Loại dây dẫn thường bọc nhựa PVC  →  similarity = 10.2134
# Đáp án gợi ý: A - Loại “J” trần không bọc
# Public030
#
#  Câu hỏi: Theo quy định, chiều dày màng khô của vật liệu bảo vệ được đo bằng nguyên tắc nào và loại đầu đo nhiệt nào được ưu tiên sử dụng khi thử nghiệm trên cấu kiện thép?
#   A. Nguyên tắc cơ học; đầu đo nhiệt loại J  →  similarity = 9.1363
#   B. Nguyên tắc quang học; đầu đo nhiệt loại N  →  similarity = 9.0851
#   C. Nguyên tắc cảm ứng điện từ hoặc dòng điện xoáy; đầu đo nhiệt loại T trong vỏ thép không gỉ cách nhiệt  →  similarity = 9.1247
#   D. Nguyên tắc thủy lực; đầu đo nhiệt loại K không cần cách nhiệt  →  similarity = 9.0897
# Đáp án gợi ý: B - Nguyên tắc quang học; đầu đo nhiệt loại N
# Public030
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu thiết bị thử nhiệt trong công nghiệp luyện kim  →  similarity = 10.6550
#   B. Hướng dẫn quy trình đo chiều dày, lắp đặt đầu đo nhiệt và thử nghiệm khả năng chịu lửa của vật liệu chống cháy cho cấu kiện thép  →  similarity = 10.2088
#   C. Quy chuẩn thiết kế hệ thống điện  →  similarity = 10.4253
#   D. Tiêu chuẩn quản lý an toàn phòng cháy chữa cháy tại công trường  →  similarity = 10.4960
# Đáp án gợi ý: B - Hướng dẫn quy trình đo chiều dày, lắp đặt đầu đo nhiệt và thử nghiệm khả năng chịu lửa của vật liệu chống cháy cho cấu kiện thép
# Public010
#
#  Câu hỏi: Theo quy định, cần bao nhiêu phép đo chiều dày tối thiểu trên dầm chịu tải?
#   A. 24 phép đo  →  similarity = 9.1428
#   B. 50 phép đo  →  similarity = 9.2746
#   C. 88 phép đo  →  similarity = 9.0782
#   D. 100 phép đo  →  similarity = 9.3080
# Đáp án gợi ý: C - 88 phép đo
# Public019
#
#  Câu hỏi: Bộ mã chuẩn nào đã được chọn cho tiếng Việt trong CNTT?
#   A. ASCII  →  similarity = 10.3460
#   B. Unicode  →  similarity = 10.7865
#   C. TCVN 6909  →  similarity = 10.7714
#   D. UTF-16  →  similarity = 10.2343
# Đáp án gợi ý: D - UTF-16
# Public005
#
#  Câu hỏi: Trong xử lý ngôn ngữ, bài toán nào có mục tiêu chuyển văn bản thành tiếng nói?
#   A. Nhận dạng tiếng nói (speech recognition)  →  similarity = 9.6223
#   B. Trích chọn thông tin (information extraction)  →  similarity = 9.5983
#   C. Tổng hợp tiếng nói (speech synthesis)  →  similarity = 9.0429
#   D. Phát hiện tri thức (knowledge discovery)  →  similarity = 9.7847
# Đáp án gợi ý: C - Tổng hợp tiếng nói (speech synthesis)
# Public013
#
#  Câu hỏi: Theo tài liệu Public_021, khi đo chiều dày màng khô của vật liệu bảo vệ, nguyên tắc nào được áp dụng và liệu có yêu cầu về đường kính vỏ bọc tối thiểu ưu tiên của đầu đo nhiệt liên quan đến quy trình này không?
#   A. Nguyên tắc cơ học; đường kính vỏ bọc tối thiểu 0,5 mm  →  similarity = 8.8294
#   B. Nguyên tắc quang học; đường kính vỏ bọc tối thiểu 1,0 mm  →  similarity = 8.9331
#   C. Nguyên tắc cảm ứng điện từ hoặc dòng điện xoáy; đường kính vỏ bọc tối thiểu 1,5 mm  →  similarity = 8.8230
#   D. Nguyên tắc thủy lực; đường kính vỏ bọc tối thiểu 2,0 mm  →  similarity = 8.6722
# Đáp án gợi ý: D - Nguyên tắc thủy lực; đường kính vỏ bọc tối thiểu 2,0 mm
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu lịch sử phát triển CNTT ở Việt Nam  →  similarity = 10.8793
#   B. Trình bày khái niệm, tình hình nghiên cứu, thách thức và hướng phát triển của xử lý tiếng Việt trong CNTT  →  similarity = 8.7421
#   C. Đề xuất các thuật toán xử lý ngôn ngữ mới  →  similarity = 10.1980
#   D. Phân tích hệ thống mạng viễn thông  →  similarity = 10.1591
# Đáp án gợi ý: B - Trình bày khái niệm, tình hình nghiên cứu, thách thức và hướng phát triển của xử lý tiếng Việt trong CNTT
# Public010
#
#  Câu hỏi: Theo đánh giá, hiện có bao nhiêu phần trăm dữ liệu không cấu trúc trong tổng lượng dữ liệu của loài người?
#   A. 0.5  →  similarity = 8.9835
#   B. 0.7  →  similarity = 8.9778
#   C. 0.8  →  similarity = 9.0246
#   D. 0.9  →  similarity = 9.0170
# Đáp án gợi ý: B - 0.7
# Public017
#
#  Câu hỏi: Tiêu chuẩn TCVN xxxx:202x được xây dựng dựa trên tiêu chuẩn quốc tế nào?
#   A. EN 13501-1  →  similarity = 10.3591
#   B. ISO 834-10  →  similarity = 10.0269
#   C. ISO 1716  →  similarity = 10.5716
#   D. IEC 584-1  →  similarity = 9.8007
# Đáp án gợi ý: D - IEC 584-1
# Public022
#
#  Câu hỏi: Chiều dày lớp bảo vệ chịu lửa được định nghĩa như thế nào?
#   A. Tổng chiều dày của hệ đỡ và lớp phủ bảo vệ  →  similarity = 10.1766
#   B. Độ dày phần bề mặt cấu kiện thép tiếp xúc với lửa  →  similarity = 10.3942
#   C. Chiều dày khô của lớp phủ hoặc tổng các lớp trong hệ bảo vệ (không tính sơn lót, sơn phủ, hệ đỡ)  →  similarity = 8.8596
#   D. Độ dày phần thép lõi bên trong  →  similarity = 10.3745
# Đáp án gợi ý: C - Chiều dày khô của lớp phủ hoặc tổng các lớp trong hệ bảo vệ (không tính sơn lót, sơn phủ, hệ đỡ)
# Public005
#
#  Câu hỏi: Theo tài liệu Public_022, các thử nghiệm chịu lửa được áp dụng cho những loại tiết diện thép nào và không áp dụng cho loại nào?
#   A. Áp dụng cho thanh/que đặc; không áp dụng cho tiết diện rỗng nhồi bê tông  →  similarity = 9.3830
#   B. Áp dụng cho tiết diện có lỗ hở; không áp dụng cho tiết diện chữ I  →  similarity = 10.0253
#   C. Áp dụng cho tiết diện chữ I, H, C, T, rỗng; không áp dụng cho thanh/que đặc hoặc tiết diện rỗng nhồi bê tông  →  similarity = 8.7384
#   D. Áp dụng cho tất cả tiết diện thép; không có ngoại lệ  →  similarity = 9.2982
# Đáp án gợi ý: C - Áp dụng cho tiết diện chữ I, H, C, T, rỗng; không áp dụng cho thanh/que đặc hoặc tiết diện rỗng nhồi bê tông
# Public019
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn TCVN xxxx:202x là gì?
# ...
#   D. 1 - 1/(1 + exp(z))  →  similarity = 8.1918
# Đáp án gợi ý: C - 1/(1 + exp(-z))
# Public003
#
#  Câu hỏi: Hàm mất mát Cross-Entropy biến thiên ra sao khi nhãn thực y_i lần lượt là 1 và 0, ứng với các giá trị xác suất dự đoán p_i?
#   A. Đều đơn điệu giảm  →  similarity = 10.5201
#   B. Đều đơn điệu tăng  →  similarity = 10.5148
#   C. Đơn điệu tăng và đơn điệu giảm  →  similarity = 10.4478
#   D. Đơn điệu giảm và đơn điệu tăng  →  similarity = 10.4188
# Đáp án gợi ý: D - Đơn điệu giảm và đơn điệu tăng
# Public030
#
#  Câu hỏi: Điểm giống nhau cơ bản của logistic regression và linear regression là gì
#   A. Đưa ra kết quả dựa trên tổ hợp tuyến tính các đặc trưng đầu vào  →  similarity = 11.6807
#   B. Dự đoán bằng tổng trọng số các đặc trưng đầu vào  →  similarity = 10.7445
#   C. Sử dụng chung một loss function  →  similarity = 9.9219
#   D. Đều bắt buộc phải giải bằng gradient descent  →  similarity = 10.8671
# Đáp án gợi ý: C - Sử dụng chung một loss function
# Public039
#
#  Câu hỏi: Theo nguyên lý xác suất được trình bày trong tài liệu Public_041, đâu không phải là một khẳng định hợp lý?
#   A. Sự kiện có 70% xác suất sẽ chắc chắn hơn sự kiện có 50% xác suất  →  similarity = 10.7496
#   B. Tổng xác suất của sự kiện "tôi là nam" và "tôi là nữ" là 100%  →  similarity = 9.2906
#   C. Xác suất tôi đi về sẽ gặp trời mưa là 150%  →  similarity = 10.8018
#   D. Với một đồng xu cân đối đồng chất, xác suất ra mặt ngửa và mặt sấp là như nhau  →  similarity = 10.4080
# Đáp án gợi ý: B - Tổng xác suất của sự kiện "tôi là nam" và "tôi là nữ" là 100%
# Public031
#
#  Câu hỏi: Mô hình neural network lấy cảm hứng từ?
#   A. Cơ chế thụ cảm của con người  →  similarity = 9.2477
#   B. Hoạt động của nơ-ron trong hệ thần kinh  →  similarity = 9.6397
#   C. Khả năng tư duy của con người  →  similarity = 9.8259
#   D. Khả năng điều khiển cơ thể của các loài động vật  →  similarity = 9.2650
# Đáp án gợi ý: A - Cơ chế thụ cảm của con người
# Public001
#
#  Câu hỏi: Neural network bắt chước toàn bộ cơ chế hoạt động của hệ thần kinh, đúng hay sai?
#   A. Sai  →  similarity = 10.2622
#   B. Đúng  →  similarity = 11.1151
#   C. nan  →  similarity = 9.2818
#   D. nan  →  similarity = 9.2818
# Đáp án gợi ý: C - nan
# Public001
#
#  Câu hỏi: Ký hiệu phổ biến cho số đặc trưng trong một điểm dữ liệu và số điểm dữ liệu lần lượt là?
#   A. N và M  →  similarity = 10.1956
#   B. N và D  →  similarity = 9.9954
#   C. D và M  →  similarity = 10.0540
#   D. D và N  →  similarity = 9.9348
# Đáp án gợi ý: D - D và N
# Public030
#
#  Câu hỏi: Bài toán về toán tử bit nào là minh chứng cho việc cần xây dựng nhiều hơn một lớp ẩn?
#   A. AND  →  similarity = 9.8370
#   B. OR  →  similarity = 10.2835
#   C. XOR  →  similarity = 10.1007
#   D. NOT  →  similarity = 9.9583
# Đáp án gợi ý: A - AND
# Public017
#
#  Câu hỏi: Theo tài liệu Public_042, vì sao lại nên dùng hàm kích hoạt phi tuyến (non-linear activation)?
#   A. Vì nếu mô hình phức tạp hơn, kết quả chắc chắn sẽ tốt hơn  →  similarity = 9.6127
#   B. Vì tổ hợp của các lớp ẩn và hàm kích hoạt tuyến tính tương đương một lớp tuyến tính  →  similarity = 10.0736
#   C. Vì đây là xu hướng, thói quen của cộng đồng  →  similarity = 9.1840
#   D. Vì nó hiệu quả trên thực tế dù chưa có lời giải thích xác đáng  →  similarity = 10.1346
# Đáp án gợi ý: C - Vì đây là xu hướng, thói quen của cộng đồng
# Public055
#
#  Câu hỏi: Hệ màu RGB biểu diễn tất cả các màu khả kiến dưới dạng tổ hợp của ba màu gì?
#   A. Đỏ, xanh lục, xanh lam  →  similarity = 7.9768
#   B. Đỏ, vàng, xanh lam  →  similarity = 8.2327
#   C. Xanh lục, cam, tím  →  similarity = 7.8574
#   D. Vàng, xanh biển, tím đỏ  →  similarity = 7.6380
# Đáp án gợi ý: D - Vàng, xanh biển, tím đỏ
# Public001
#
#  Câu hỏi: Tensor được chuyên dùng để mô tả dữ liệu theo mấy chiều
#   A. Một  →  similarity = 12.0884
#   B. Hai  →  similarity = 11.6904
#   C. Nhiều hơn hai  →  similarity = 11.1805
#   D. nan  →  similarity = 11.6097
# Đáp án gợi ý: C - Nhiều hơn hai
# Public036
#
#  Câu hỏi: Một pixel của ảnh xám có thể nhận giá trị tối thiểu và tối đa lần lượt là?
#   A. 0 và 127  →  similarity = 9.0509
#   B. -127 và 127  →  similarity = 9.8991
#   C. 0 và 255  →  similarity = 8.9799
#   D. 0 và 1048576  →  similarity = 9.1222
# Đáp án gợi ý: C - 0 và 255
# Public019
#
#  Câu hỏi: Phép tích chập (convolution) gồm ba yếu tố chính là kernel và hai thành phần nào?
#   A. Strike và patting  →  similarity = 9.2143
#   B. Stride và padding  →  similarity = 9.2409
#   C. Strike và padding  →  similarity = 9.2459
#   D. Stride và patting  →  similarity = 9.2453
# Đáp án gợi ý: A - Strike và patting
# Public058
#
#  Câu hỏi: Sử dụng công thức quy đổi RGB sang ảnh xám (p = 0.299 * r + 0.587 * g + 0.114 * b, làm tròn tới hàng đơn vị) được đề cập trong tài liệu Public_043, hãy xác định giá trị pixel ảnh xám ứng với pixel ảnh RGB (100, 10, 1).
#   A. 36  →  similarity = 9.7862
#   B. 35  →  similarity = 9.8635
#   C. 37  →  similarity = 9.7636
#   D. 34  →  similarity = 9.7176
# Đáp án gợi ý: D - 34
# Public019
#
#  Câu hỏi: Đâu là vấn đề trong xử lý ảnh mà CNN giải quyết tốt hơn so với các mạng nơ-ron truyền thống?
#   A. Lưu trữ tham số  →  similarity = 9.7542
#   B. Xử lý dữ liệu hai chiều  →  similarity = 9.9319
#   C. Thời gian tính toán  →  similarity = 10.5504
#   D. Cả ba vấn đề đã nêu  →  similarity = 10.5634
# Đáp án gợi ý: A - Lưu trữ tham số
# Public022
#
#  Câu hỏi: Pooling layer được thiết kế để?
#   A. Giảm kích thước dữ liệu, bất luận mất mát thông tin  →  similarity = 8.3023
#   B. Giảm chiều nhưng vẫn giữ lại thông tin  →  similarity = 9.9814
#   C. Tăng kích thước dữ liệu  →  similarity = 9.0912
#   D. Sinh ra giá trị trung gian dựa trên một vùng của dữ liệu  →  similarity = 9.1178
# Đáp án gợi ý: A - Giảm kích thước dữ liệu, bất luận mất mát thông tin
# Public019
#
#  Câu hỏi: Pooling layer của VGG16 có kích thước ra sao và hàm pool là?
#   A. 2 x 2, avg  →  similarity = 9.3275
#   B. 3 x 3, max  →  similarity = 9.7037
#   C. 2 x 2, max  →  similarity = 9.6108
#   D. 3 x 3, avg  →  similarity = 9.4245
# Đáp án gợi ý: A - 2 x 2, avg
# Public019
#
#  Câu hỏi: Tổng quát một CNN sẽ gồm hai phần chính nào sau đây?
#   A. Các lớp tích chập và các lớp truyền thống  →  similarity = 9.0888
#   B. Các kernel tích chập và hàm pool  →  similarity = 9.6776
#   C. Các lớp tích chập giảm kích thước và các lớp tích chập tăng kích thước  →  similarity = 8.9768
#   D. Các thông số padding và stride  →  similarity = 9.1928
# Đáp án gợi ý: C - Các lớp tích chập giảm kích thước và các lớp tích chập tăng kích thước
# Public017
#
#  Câu hỏi: Kết quả average pooling của hình vuông gồm 4 giá trị 15, 20, 30, 45 là?
#   A. 30  →  similarity = 9.5193
#   B. 27.5  →  similarity = 10.1270
#   C. 25  →  similarity = 9.2857
#   D. 32.5  →  similarity = 9.0685
# Đáp án gợi ý: D - 32.5
# Public019
#
#  Câu hỏi: Theo tài liệu Public_045, điểm chung của Transfer learning và data augmentation là gì?
#   A. Tận dụng mô hình có sẵn  →  similarity = 10.3096
#   B. Áp dụng cho tình trạng khan hiếm dữ liệu  →  similarity = 10.0906
#   C. Chi phí đắt đỏ  →  similarity = 10.9867
#   D. Không có điểm chung, là hai phương án độc lập rời rạc  →  similarity = 10.2128
# Đáp án gợi ý: B - Áp dụng cho tình trạng khan hiếm dữ liệu
# Public072
#
#  Câu hỏi: Theo tài liệu Public_045, đâu không phải là một hình thức data augmentation cho ảnh?
#   A. Cắt và phóng to (crop and resize)  →  similarity = 9.5864
#   B. Lật ảnh (flip)  →  similarity = 10.2948
#   C. Xoay ảnh (rotate)  →  similarity = 10.2058
#   D. Chuyển ảnh xám  →  similarity = 10.3541
# Đáp án gợi ý: A - Cắt và phóng to (crop and resize)
# Public017
#
#  Câu hỏi: Theo tài liệu Public_045, khi tiến hành phân lớp với nhiều hơn hai lớp, có bao nhiêu chiến lược tiếp cận? Hình thức của chúng là gì?
#   A. Hai. Một model phân M lớp và M model phân biệt từng lớp  →  similarity = 8.9455
#   B. Một. Một model phân M lớp  →  similarity = 9.1400
#   C. Một. M model phân biệt từng lớp  →  similarity = 9.4445
#   D. Không thể tiến hành  →  similarity = 9.5177
# Đáp án gợi ý: A - Hai. Một model phân M lớp và M model phân biệt từng lớp
# Public033
#
#  Câu hỏi: Trường hợp nào sau đây được đề xuất sử dụng Finetuning hơn là Feature extractor?
# I. Dữ liệu lớn, khác dữ liệu pretrain
# II. Dữ liệu nhỏ, khác dữ liệu pretrain
# III. Dữ liệu nhỏ, giống dữ liệu pretrain
# IV. Dữ liệu lớn, giống dữ liệu pretrain
#   A. I  →  similarity = 9.5724
#   B. II và III  →  similarity = 9.7323
#   C. I và IV  →  similarity = 9.6338
#   D. IV  →  similarity = 9.7257
# Đáp án gợi ý: A - I
# Public033
#
#  Câu hỏi: Theo tài liệu Public_045, đâu không phải là khẳng định đúng giữa Finetuning và Feature extractor?
#   A. Finetuning hiệu quả thấp hơn feature extractor  →  similarity = 11.0314
#   B. Finetuning chỉ phù hợp khi có bộ dữ liệu đủ lớn  →  similarity = 11.4958
#   C. Feature extractor phù hợp khi dữ liệu thích nghi tương đối giống với dữ liệu của mô hình pretrained  →  similarity = 10.8957
#   D. Finetuning cần nhiều tài nguyên để tiến hành hơn so với feature extractor  →  similarity = 10.9207
# Đáp án gợi ý: C - Feature extractor phù hợp khi dữ liệu thích nghi tương đối giống với dữ liệu của mô hình pretrained
# Public072
#
#  Câu hỏi: Lợi ích chính của vectorization là gì
#   A. Tiết kiệm thời gian  →  similarity = 9.6132
#   B. Tiết kiệm bộ nhớ  →  similarity = 8.9604
#   C. Giảm overfitting  →  similarity = 11.0603
#   D. Giảm underfitting  →  similarity = 11.5353
# Đáp án gợi ý: B - Tiết kiệm bộ nhớ
# Public039
#
#  Câu hỏi: Theo tài liệu Public_046, giá trị p trong dropout thể hiện điều gì?
#   A. Tỉ lệ giữ node của layer  →  similarity = 9.3812
#   B. Xác suất giữ một layer  →  similarity = 9.3154
#   C. Tỉ lệ bỏ node của layer  →  similarity = 9.3694
#   D. Xác suất bỏ một layer  →  similarity = 9.6626
# Đáp án gợi ý: B - Xác suất giữ một layer
# Public019
#
#  Câu hỏi: Theo tài liệu Public_046, khái niệm tiếng Việt cho bias và variance là gì?
#   A. Phương sai, độ lệch chuẩn  →  similarity = 8.9321
#   B. Độ lệch, độ lệch chuẩn  →  similarity = 9.5476
#   C. Độ lệch, phương sai  →  similarity = 9.4157
#   D. Độ lệch chuẩn, phương sai  →  similarity = 9.1934
# Đáp án gợi ý: A - Phương sai, độ lệch chuẩn
# Public031
#
#  Câu hỏi: Đâu là mục tiêu chính của các phương pháp trong tài liệu Public_046?
#   A. Tăng thời gian chạy  →  similarity = 10.3467
#   B. Tránh các hiện tượng như overfitting và underfitting  →  similarity = 10.2904
#   C. Tăng khả năng khái quát hóa của mô hình  →  similarity = 10.4674
#   D. Cả ba mục tiêu  →  similarity = 10.3425
# Đáp án gợi ý: B - Tránh các hiện tượng như overfitting và underfitting
# Public031
#
#  Câu hỏi: Một thuật toán gradient descent lấy ra 32 dữ liệu điểm mỗi lần tính đạo hàm thì thuộc loại gradient descent nào?
#   A. Batch GD  →  similarity = 11.2714
#   B. Mini-batch GD  →  similarity = 11.1604
#   C. Stochastic GD  →  similarity = 12.0199
#   D. Không phải loại GD nào nêu trên  →  similarity = 11.4631
# Đáp án gợi ý: B - Mini-batch GD
# Public022
#
#  Câu hỏi: Input của bài toán object detection là?
#   A. Âm thanh  →  similarity = 9.3633
#   B. Hình ảnh  →  similarity = 9.6756
#   C. Văn bản  →  similarity = 8.9652
#   D. Hỗn hợp  →  similarity = 10.0163
# Đáp án gợi ý: C - Văn bản
# Public001
#
#  Câu hỏi: Vấn đề chính của R-CNN là?
#   A. Thời gian infer lâu  →  similarity = 9.0042
#   B. Thời gian train lâu  →  similarity = 8.9311
#   C. Cả hai vấn đề đã nêu  →  similarity = 10.2039
#   D. Không phải hai vấn đề đã nêu  →  similarity = 10.2307
# Đáp án gợi ý: B - Thời gian train lâu
# Public001
#
#  Câu hỏi: IoU phụ thuộc vào hai toán tử tập hợp nào và công thức là gì?
#   A. Intersection và Union. I/U  →  similarity = 10.3640
#   B. Intersection và Negation. I/(I + N)  →  similarity = 9.8062
#   C. Negation và Union. (U + N)/N  →  similarity = 9.8922
#   D. Intersection và Union. U/(U + I)  →  similarity = 10.0236
# Đáp án gợi ý: B - Intersection và Negation. I/(I + N)
# Public001
#
#  Câu hỏi: Các nguyên tắc cốt lõi và thành phần chính của các cách tiếp cận object detection là gì?
#   A. Hồi quy  →  similarity = 10.2439
#   B. Region proposal  →  similarity = 9.9846
#   C. Phân cụm  →  similarity = 10.3529
#   D. Phân lớp  →  similarity = 10.1662
# Đáp án gợi ý: B - Region proposal
# Public001
#
#  Câu hỏi: Trong ROI pooling, để tạo ra output có kích thước 4x4, mỗi vùng quan tâm (ROI) được chia thành bao nhiêu phân vùng con để thực hiện pooling?
#   A. 1  →  similarity = 9.6936
#   B. 2  →  similarity = 10.1571
#   C. 3  →  similarity = 9.9461
#   D. 4  →  similarity = 10.2206
# Đáp án gợi ý: A - 1
# Public072
#
#  Câu hỏi: Bộ dữ liệu được sử dụng trong tài liệu Public_048 có bao nhiêu ảnh?
#   A. 1750  →  similarity = 10.3755
#   B. 1024  →  similarity = 10.3347
#   C. 2048  →  similarity = 10.2974
#   D. 3500  →  similarity = 10.0917
# Đáp án gợi ý: D - 3500
# Public001
#
#  Câu hỏi: Mô hình được sử dụng để huấn luyện trong tài liệu Public_048 là gì?
#   A. YOLOv5  →  similarity = 10.0678
#   B. YOLOv4  →  similarity = 10.0492
#   C. YOLO-TinyV5  →  similarity = 9.6637
#   D. YOLO-Tinyv4  →  similarity = 9.5624
# Đáp án gợi ý: D - YOLO-Tinyv4
# Public031
#
#  Câu hỏi: Trong tài liệu Public_048, có bao nhiêu phương pháp tăng cường dữ liệu đã được dùng và gồm những thao tác nào?
#   A. Hai. Thu nhỏ, phóng to  →  similarity = 10.3495
#   B. Ba. Thu phóng, tăng sáng, xoay  →  similarity = 10.1927
#   C. Hai. Thêm nhiễu, tăng sáng  →  similarity = 10.6827
#   D. Một. Lật  →  similarity = 10.0190
# Đáp án gợi ý: D - Một. Lật
# Public019
#
#  Câu hỏi: Cách tiếp cận đã nêu trong tài liệu Public_048 có tiến hành đọc biển số hay không?
#   A. Không  →  similarity = 11.5483
#   B. Có  →  similarity = 10.8511
#   C. nan  →  similarity = 10.9514
#   D. nan  →  similarity = 10.9514
# Đáp án gợi ý: B - Có
# Public019
#
#  Câu hỏi: Phân loại của bài toán được mô tả trong tài liệu Public_048 là gì?
#   A. Image segmentation  →  similarity = 11.4795
#   B. Object segmentation  →  similarity = 11.0986
#   C. Object detection  →  similarity = 11.1190
#   D. Image classification  →  similarity = 11.2564
# Đáp án gợi ý: B - Object segmentation
# Public010
#
#  Câu hỏi: Theo tài liệu Public_049, khái niệm được dùng để đại diện tập xác định của một biến là gì?
#   A. Kiểu dữ liệu  →  similarity = 9.7772
#   B. Tên dữ liệu  →  similarity = 9.8912
#   C. Loại dữ liệu  →  similarity = 9.6727
#   D. Lớp dữ liệu  →  similarity = 11.8444
# Đáp án gợi ý: C - Loại dữ liệu
# Public031
#
#  Câu hỏi: Theo tài liệu Public_049, thành phần nào không thuộc phạm vi quản lý của biến?
#   A. Kiểu dữ liệu  →  similarity = 9.7369
#   B. Tên biến  →  similarity = 9.7767
#   C. Giá trị biến  →  similarity = 9.2827
#   D. Địa chỉ lưu biến  →  similarity = 9.5019
# Đáp án gợi ý: C - Giá trị biến
# Public017
#
#  Câu hỏi: Tên kiểu dữ liệu của ký tự ASCII và ký tự Unicode lần lượt là?
#   A. char và wchar  →  similarity = 9.4309
#   B. char_t và wchar_t  →  similarity = 10.0476
#   C. char và wchar_t  →  similarity = 9.7339
#   D. char_t và wchar  →  similarity = 10.2400
# Đáp án gợi ý: A - char và wchar
# Public001
#
#  Câu hỏi: Đâu không phải khẳng định đúng về các đặc tính của thuật toán được đề cập trong tài liệu Public_049?
#   A. Thuật toán phải rõ ràng, không nhập nhằng  →  similarity = 9.9263
#   B. Thuật toán không được chạy vô hạn  →  similarity = 11.3267
#   C. Thuật toán phải được thiết kế đặc thù, chuyên sâu thay vì tổng quát  →  similarity = 11.0183
#   D. Thuật toán nên dễ hiểu, dễ cài đặt  →  similarity = 10.1237
# Đáp án gợi ý: A - Thuật toán phải rõ ràng, không nhập nhằng
# Public010
#
#  Câu hỏi: Phương trình toán học 3x + 4y + 5z = 6 có mấy biến?
#   A. Ba  →  similarity = 9.9000
#   B. Hai  →  similarity = 9.8333
#   C. Một  →  similarity = 9.9561
#   D. Bốn  →  similarity = 9.8555
# Đáp án gợi ý: B - Hai
# Public030
#
#  Câu hỏi: Dựa vào tài liệu Public_050, từ nào điền vào chỗ trống sau: nếu hàm số f(x) bị ... bởi hằng số C nhân với g(x), ta nói f(x) có độ phức tạp O(g(x))?
#   A. Chặn dưới   →  similarity = 10.1293
#   B. Chặn trên  →  similarity = 9.8845
#   C. Chặn trên và dưới  →  similarity = 9.8085
#   D. Lớn hơn  →  similarity = 9.8204
# Đáp án gợi ý: C - Chặn trên và dưới
# Public019
#
#  Câu hỏi: Theo nguyên tắc tổng, f1(x) + f2(x) có độ phức tạp là?
#   A. O(max(g1(x), g2(x))  →  similarity = 7.2454
#   B. O(min(g1(x), g2(x))  →  similarity = 7.1773
#   C. O(g1(x) + g2(x))  →  similarity = 7.7639
#   D. O(|g1(x) - g2(x)|)  →  similarity = 7.7472
# Đáp án gợi ý: B - O(min(g1(x), g2(x))
# Public030
#
#  Câu hỏi: Độ phức tạp tuyến tính và giai thừa lần lượt có ký hiệu là?

# %%
# ...existing code...
import torch
from transformers import AutoModel, AutoTokenizer
from torch.nn.functional import cosine_similarity
import pandas as pd
import re
import os
# Thêm import cần thiết cho tính toán Euclid
import torch.nn.functional as F

# Đặt giới hạn an toàn cho PhoBERT-base
SAFE_MAX_LENGTH = 256 # Giới hạn 256 token là an toàn nhất cho PhoBERT-base
QA_MAX_LENGTH = 256

# Hàm nhúng (đã cập nhật)
def get_embedding(text, model, tokenizer, max_len=512):
    # Đảm bảo tensor luôn ở device của model
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=max_len).to(model.device)
    with torch.no_grad():
        out = model(**inputs)
    return out.last_hidden_state[:, 0, :] # CLS token

# Hàm tính khoảng cách Euclid giữa một vector và nhiều vector
def euclidean_distance(query_emb, context_embeddings):
    # Mở rộng query_emb để có kích thước [n_chunks, hidden_size]
    query_expanded = query_emb.expand_as(context_embeddings)
    
    # Tính hiệu số, sau đó tính chuẩn L2 (Euclidean norm) trên dimension vector (dim=1)
    distances = torch.norm(context_embeddings - query_expanded, p=2, dim=1)
    
    return distances.squeeze() # Trả về tensor 1D chứa các khoảng cách

# Hàm shingle theo từ: tạo các cửa sổ trượt theo số từ, mỗi shingle <= max_chars ký tự
def k_shingles(text, k=10, max_chars=300):
    """
    Tạo k-shingles (cửa sổ trượt theo số từ cố định k).
    Nếu tổng số từ < k thì trả về toàn bộ câu như 1 shingle.
    Bỏ qua shingle có độ dài ký tự > max_chars (nếu cần giới hạn).
    """
    words = text.split()
    n = len(words)
    if n == 0:
        return []
    if n < k:
        sh = " ".join(words)
        return [sh] if len(sh) <= max_chars else []
    shingles = []
    for i in range(0, n - k + 1):
        sh = " ".join(words[i:i + k])
        if max_chars is None or len(sh) <= max_chars:
            shingles.append(sh)
    return shingles

model_name = "vinai/phobert-base"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False)
phobert = AutoModel.from_pretrained(model_name, trust_remote_code=True)
try: 
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    phobert.to(device)
    print(f"Model đang chạy trên thiết bị: {device}")
except Exception as e:
    print(f"Cảnh báo: Không thể chuyển model sang GPU: {e}")
    phobert.to("cpu")

csv_path = "training_input/question.csv"
df = pd.read_csv(csv_path)

for idx, row in df.iterrows():
    question = str(row["Question"]).strip()
    options = [str(row["A"]), str(row["B"]), str(row["C"]), str(row["D"])]
    labels = ["A", "B", "C", "D"]
    
    if not question:
        continue

    # Tạo embedding tổng cho câu hỏi nếu cần để tìm document (giữ nguyên logic hiện tại)
    question_embedding = get_embedding(question, phobert, tokenizer, max_len=512)
    if question_embedding is None:
        continue # Bỏ qua câu hỏi rỗng
        
    # Truy vấn DB (không thay đổi)
    cur.execute("""SELECT document FROM dbvector1 
                 Order by embedding  <-> %s :: vector asc
                 LIMIT 1;""", (question_embedding.squeeze().detach().cpu().numpy().tolist(),))
    results = cur.fetchall()
    if not results:
        print("Không tìm thấy document phù hợp trong DB.")
        continue
    x = results[0]
    document_name = x[0]
    print(f"\n Câu hỏi: {question}")

    # Đọc và chuẩn hóa tài liệu
    md_path = os.path.join("training_output", document_name, "main.md")
    if not os.path.exists(md_path):
        print(f"Không tìm thấy file: {md_path}. Bỏ qua.")
        continue
    
    with open(md_path, "r", encoding="utf-8") as f:
        doc_text = f.read()

    processed_text = re.sub(r'\s+', ' ', doc_text.strip())  # giữ khoảng trắng đơn cho tách từ
    doc_chunks = []
    MAX_CHARS = 300 # Giữ 300 ký tự cho chunk tài liệu
    # Chia tài liệu thành các chunk liên tiếp (giữ nguyên logic trước)
    for i in range(0, len(processed_text), MAX_CHARS):
        chunk = processed_text[i:i + MAX_CHARS]
        doc_chunks.append(chunk)

    # Tạo embedding cho từng chunk tài liệu
    chunk_embeddings = []
    for chunk in doc_chunks:
        emb = get_embedding(chunk, phobert, tokenizer, max_len=300)
        if emb is not None:
            chunk_embeddings.append(emb)
    if not chunk_embeddings:
        print(f"Không tìm thấy chunk hợp lệ trong tài liệu {document_name}. Bỏ qua.")
        continue
    chunk_embeddings = torch.cat(chunk_embeddings, dim=0)  # [n_chunks, hidden_size]

    # --- Bây giờ: shingle câu hỏi theo từ, kết hợp với mỗi lựa chọn và tìm khoảng cách nhỏ nhất ---
    question_shingles = k_shingles(question, k=10, max_chars=300)
    if not question_shingles:
        question_shingles = [question]  # fallback

    distances = []
    for i, opt in enumerate(options):
        # Với mỗi lựa chọn, tính min distance trên tất cả các shingle của câu hỏi
        min_dist_for_option = float('inf')
        for sh in question_shingles:
            qa_text = f"{sh} {opt}".strip()
            qa_emb = get_embedding(qa_text, phobert, tokenizer, max_len=300)
            if qa_emb is None:
                continue
            # Tính khoảng cách Euclid tới tất cả chunk và lấy min
            dists = euclidean_distance(qa_emb, chunk_embeddings)
            min_d = dists.min().item()
            if min_d < min_dist_for_option:
                min_dist_for_option = min_d
        if min_dist_for_option == float('inf'):
            min_dist_for_option = 1e9
        distances.append(min_dist_for_option)
        print(f"  {labels[i]}. {opt}  →  min_distance_over_shingles = {min_dist_for_option:.4f}")

    # Chọn đáp án có khoảng cách nhỏ nhất (gần nhất)
    best_idx = int(torch.argmin(torch.tensor(distances)).item())
    print(f"Đáp án gợi ý: {labels[best_idx]} - {options[best_idx]}")
    print(document_name)
# ...existing code...
# Out:
# Model đang chạy trên thiết bị: cuda
#
#  Câu hỏi: Trong mô hình nhà thông minh, IoT chủ yếu đóng vai trò gì?
#   A. Lưu trữ dữ liệu trên máy chủ  →  min_distance_over_shingles = 7.2856
#   B. Kết nối Internet và quản lý thiết bị từ xa  →  min_distance_over_shingles = 7.1428
#   C. Cung cấp dịch vụ phân tích dữ liệu lớn  →  min_distance_over_shingles = 7.8296
#   D. Thay thế hoàn toàn điện toán đám mây  →  min_distance_over_shingles = 7.3177
# Đáp án gợi ý: B - Kết nối Internet và quản lý thiết bị từ xa
# Public001
#
#  Câu hỏi: Năm 2010, công nghệ nào thường được sử dụng trong kiểm soát ra vào ngôi nhà thông minh?
#   A. Bluetooth Low Energy  →  min_distance_over_shingles = 8.8424
#   B. RFID và nhận dạng khuôn mặt/vân tay  →  min_distance_over_shingles = 8.3491
#   C. Zigbee  →  min_distance_over_shingles = 8.7251
#   D. Blockchain  →  min_distance_over_shingles = 8.5748
# Đáp án gợi ý: B - RFID và nhận dạng khuôn mặt/vân tay
# Public001
#
#  Câu hỏi: Bộ cảm biến trong nhà thông minh thực hiện chức năng gì và bộ truyền động có vai trò gì?
#   A. Bộ cảm biến hiển thị dữ liệu, bộ truyền động thu thập dữ liệu  →  min_distance_over_shingles = 7.3773
#   B. Bộ cảm biến lưu trữ dữ liệu, bộ truyền động hiển thị dữ liệu  →  min_distance_over_shingles = 7.3553
#   C. Bộ cảm biến thu thập dữ liệu, bộ truyền động thực hiện lệnh từ máy chủ hoặc thiết bị điều khiển  →  min_distance_over_shingles = 7.3824
#   D. Bộ cảm biến điều khiển thiết bị, bộ truyền động lưu trữ dữ liệu  →  min_distance_over_shingles = 7.4381
# Đáp án gợi ý: B - Bộ cảm biến lưu trữ dữ liệu, bộ truyền động hiển thị dữ liệu
# Public019
#
#  Câu hỏi: Nội dung chính của bài báo nghiên cứu Public_001 về IoT trong xây dựng nhà thông minh là gì?
#   A. Giới thiệu các ứng dụng cụ thể của điện toán đám mây  →  min_distance_over_shingles = 7.9352
#   B. Phân tích lợi ích và chi phí triển khai hệ thống cảm biến  →  min_distance_over_shingles = 8.1669
#   C. Phân loại và đánh giá nghiên cứu IoT ứng dụng nhà thông minh trong 10 năm qua  →  min_distance_over_shingles = 8.8124
#   D. Trình bày chi tiết về công nghệ vi mạch trong IoT  →  min_distance_over_shingles = 7.9869
# Đáp án gợi ý: A - Giới thiệu các ứng dụng cụ thể của điện toán đám mây
# Public072
#
#  Câu hỏi: Dựa vào thông tin trong tài liệu Public_001, hãy tính số bài báo trung bình mỗi lớp trong nghiên cứu được đề cập.
#   A. 45-50  →  min_distance_over_shingles = 9.2586
#   B. 55-60  →  min_distance_over_shingles = 9.3098
#   C. 70-80  →  min_distance_over_shingles = 9.2537
#   D. 90-100  →  min_distance_over_shingles = 8.7725
# Đáp án gợi ý: D - 90-100
# Public072
#
#  Câu hỏi: Theo tài liệu Public_002, học phần Bảo mật Web trang bị kiến thức về bộ rủi ro phổ biến nào?
#   A. OWASP Top 10  →  min_distance_over_shingles = 7.7071
#   B. IEEE 802.11  →  min_distance_over_shingles = 8.1862
#   C. ISO/IEC 27001  →  min_distance_over_shingles = 7.8610
#   D. NIST Cybersecurity Framework  →  min_distance_over_shingles = 7.8876
# Đáp án gợi ý: A - OWASP Top 10
# Public019
#
#  Câu hỏi: Dựa trên tài liệu Public_002, mô tả học phần Cơ sở dữ liệu nâng cao, hãy liệt kê các loại CSDL không được đề cập trong nội dung học phần này.
#   A. CSDL NoSQL  →  min_distance_over_shingles = 7.9032
#   B. CSDL hướng đối tượng  →  min_distance_over_shingles = 7.3943
#   C. CSDL bán cấu trúc XML  →  min_distance_over_shingles = 7.4152
#   D. CSDL quan hệ truyền thống  →  min_distance_over_shingles = 7.3793
# Đáp án gợi ý: D - CSDL quan hệ truyền thống
# Public019
#
#  Câu hỏi: Nêu chi tiết nội dung đào tạo về bảo mật web và bảo mật cơ sở dữ liệu trong tài liệu Public_002.
#   A. OWASP Top 10 / CSDL NoSQL  →  min_distance_over_shingles = 9.8914
#   B. IEEE 802.11 / CSDL hướng đối tượng  →  min_distance_over_shingles = 9.3149
#   C. DSA / CSDL bán cấu trúc XML  →  min_distance_over_shingles = 8.9198
#   D. Toán cao cấp / CSDL quan hệ truyền thống  →  min_distance_over_shingles = 8.2556
# Đáp án gợi ý: D - Toán cao cấp / CSDL quan hệ truyền thống
# Public033
#
#  Câu hỏi: Nhóm môn học trong tài liệu Public_002 tập trung cung cấp cho sinh viên kiến thức tổng quan về lĩnh vực nào?
#   A. Cơ khí – Điện tử  →  min_distance_over_shingles = 8.3672
#   B. Công nghệ thông tin (CSDL, mạng, bảo mật, dữ liệu lớn, IoT, học máy)  →  min_distance_over_shingles = 6.1950
#   C. Kinh tế – Quản lý  →  min_distance_over_shingles = 8.4865
#   D. Ngôn ngữ học  →  min_distance_over_shingles = 7.8732
# Đáp án gợi ý: B - Công nghệ thông tin (CSDL, mạng, bảo mật, dữ liệu lớn, IoT, học máy)
# Public001
#
#  Câu hỏi: Trong tài liệu Public_002, đối với đoạn liệt kê các học phần từ số 47 đến 81, nếu các học phần này được trải đều trên 7 trang, trung bình mỗi trang mô tả bao nhiêu học phần?
#   A. 5  →  min_distance_over_shingles = 7.6728
#   B. 6  →  min_distance_over_shingles = 7.8099
#   C. 7  →  min_distance_over_shingles = 7.7957
#   D. 8  →  min_distance_over_shingles = 7.7239
# Đáp án gợi ý: A - 5
# Public019
#
#  Câu hỏi: Điểm BLEU được dùng để đánh giá chất lượng bản dịch trong tài liệu Public_003 là gì?
#   A. Một thuật toán dịch máy  →  min_distance_over_shingles = 9.1121
#   B. Một loại dữ liệu song ngữ  →  min_distance_over_shingles = 8.5775
#   C. Một phương pháp đánh giá tự động chất lượng dịch máy  →  min_distance_over_shingles = 8.7527
#   D. Một hệ dịch mã nguồn mở  →  min_distance_over_shingles = 8.8248
# Đáp án gợi ý: B - Một loại dữ liệu song ngữ
# Public031
#
#  Câu hỏi: Công cụ nào được nhóm tác giả của tài liệu Public_003 sử dụng để huấn luyện các hệ dịch nơ ron?
#   A. Moses  →  min_distance_over_shingles = 8.4507
#   B. OpenNMT  →  min_distance_over_shingles = 8.4526
#   C. TensorFlow  →  min_distance_over_shingles = 8.4118
#   D. Fairseq  →  min_distance_over_shingles = 8.2120
# Đáp án gợi ý: D - Fairseq
# Public001
#
#  Câu hỏi: Điểm BLEU và công cụ huấn luyện hệ dịch nơ ron trong nghiên cứu này là gì?
#   A. Một thuật toán dịch máy / Moses  →  min_distance_over_shingles = 8.1672
#   B. Một loại dữ liệu song ngữ / OpenNMT  →  min_distance_over_shingles = 8.0894
#   C. Một phương pháp đánh giá tự động chất lượng dịch máy / TensorFlow  →  min_distance_over_shingles = 7.8661
#   D. Một hệ dịch mã nguồn mở / Fairseq  →  min_distance_over_shingles = 8.5650
# Đáp án gợi ý: C - Một phương pháp đánh giá tự động chất lượng dịch máy / TensorFlow
# Public001
#
#  Câu hỏi: Nội dung chính của tài liệu Public_003 là gì?
#   A. So sánh dịch máy thống kê và dịch máy ví dụ  →  min_distance_over_shingles = 8.8324
#   B. Đề xuất phương pháp thích ứng miền mới cho dịch máy nơ ron Anh – Việt, tận dụng dữ liệu đơn ngữ ngoài miền để cải thiện chất lượng dịch  →  min_distance_over_shingles = 8.6000
#   C. Phân tích dữ liệu song ngữ trong lĩnh vực pháp lý  →  min_distance_over_shingles = 8.5989
#   D. Trình bày lý thuyết về RNN hai chiều  →  min_distance_over_shingles = 8.8818
# Đáp án gợi ý: C - Phân tích dữ liệu song ngữ trong lĩnh vực pháp lý
# Public031
#
#  Câu hỏi: Theo kết quả thử nghiệm, hệ dịch Adapt_System cải thiện bao nhiêu điểm BLEU so với Baseline_G trong miền pháp lý?
#   A. 0.84  →  min_distance_over_shingles = 7.8509
#   B. 1.37  →  min_distance_over_shingles = 7.9658
#   C. 1.5  →  min_distance_over_shingles = 8.2526
#   D. 2.21  →  min_distance_over_shingles = 8.0537
# Đáp án gợi ý: A - 0.84
# Public019
#
#  Câu hỏi: Công nghệ in bê tông 3D được thực hiện theo quy trình nào?
#   A. Gia công cắt gọt vật liệu  →  min_distance_over_shingles = 8.5490
#   B. Đúc bê tông trong ván khuôn  →  min_distance_over_shingles = 8.7731
#   C. Sản xuất bồi đắp bằng cách chồng lớp vật liệu từ mô hình CAD  →  min_distance_over_shingles = 9.0024
#   D. Ép nén bê tông truyền thống  →  min_distance_over_shingles = 8.6997
# Đáp án gợi ý: A - Gia công cắt gọt vật liệu
# Public013
#
#  Câu hỏi: Công nghệ nào được phát triển tại Đại học Loughborough (Anh)?
#   A. Contour Crafting  →  min_distance_over_shingles = 9.0609
#   B. Concrete Printing  →  min_distance_over_shingles = 9.3020
#   C. D-Shape  →  min_distance_over_shingles = 9.4679
#   D. Emerging Objects  →  min_distance_over_shingles = 9.3431
# Đáp án gợi ý: A - Contour Crafting
# Public072
#
#  Câu hỏi: Công nghệ in bê tông 3D nào vừa cho phép kiểm soát tốt cấu trúc sản phẩm, vừa sử dụng bê tông cốt liệu sợi tổng hợp cường độ cao?
#   A. Contour Crafting  →  min_distance_over_shingles = 9.5939
#   B. Concrete Printing  →  min_distance_over_shingles = 9.3684
#   C. Concrete On-Site 3D Printing  →  min_distance_over_shingles = 9.3965
#   D. FDM  →  min_distance_over_shingles = 9.1177
# Đáp án gợi ý: D - FDM
# Public030
#
#  Câu hỏi: Nội dung chính của bài báo Public_004 là gì?
#   A. Trình bày ứng dụng in 3D trong y tế  →  min_distance_over_shingles = 8.3840
#   B. Giới thiệu, phân tích ưu nhược điểm các công nghệ in bê tông 3D trong xây dựng, so sánh tính khả thi áp dụng ở Việt Nam  →  min_distance_over_shingles = 7.5710
#   C. Mô tả chi tiết công thức chế tạo bê tông UHPC  →  min_distance_over_shingles = 8.2594
#   D. Giới thiệu công nghệ CAD trong xây dựng  →  min_distance_over_shingles = 8.6267
# Đáp án gợi ý: B - Giới thiệu, phân tích ưu nhược điểm các công nghệ in bê tông 3D trong xây dựng, so sánh tính khả thi áp dụng ở Việt Nam
# Public095
#
#  Câu hỏi: Trong tài liệu, ưu điểm của công nghệ Contour Crafting so với Concrete Printing là gì?
#   A. Độ mịn bề mặt sản phẩm tốt hơn  →  min_distance_over_shingles = 8.1791
#   B. Khả năng chịu lực cao hơn  →  min_distance_over_shingles = 8.0947
#   C. Chi phí rẻ hơn  →  min_distance_over_shingles = 7.9539
#   D. Quy mô in lớn hơn  →  min_distance_over_shingles = 7.6617
# Đáp án gợi ý: D - Quy mô in lớn hơn
# Public001
#
#  Câu hỏi: OCR là viết tắt của gì trong bài báo này?
#   A. Optical Character Recognition  →  min_distance_over_shingles = 9.0053
#   B. Optical Code Reader  →  min_distance_over_shingles = 9.1048
#   C. Optical Computing Resource  →  min_distance_over_shingles = 8.6823
#   D. Optical Capture Recognition  →  min_distance_over_shingles = 9.1371
# Đáp án gợi ý: C - Optical Computing Resource
# Public001
#
#  Câu hỏi: Giải pháp thử nghiệm tại Học viện Ngân hàng được lựa chọn là gì, theo tài liệu Public_005?
#   A. Viettel OCR  →  min_distance_over_shingles = 9.0139
#   B. FPT.AI Reader  →  min_distance_over_shingles = 9.0847
#   C. Google Vision AI  →  min_distance_over_shingles = 8.9509
#   D. Tesseract  →  min_distance_over_shingles = 8.5997
# Đáp án gợi ý: D - Tesseract
# Public055
#
#  Câu hỏi: Công nghệ nào vừa cho phép máy tính tự động nhận biết ký tự trên hình ảnh, vừa có khả năng đọc hiểu dữ liệu chữ viết tay và chữ in?
#   A. OCR  →  min_distance_over_shingles = 8.2698
#   B. ICR  →  min_distance_over_shingles = 8.3269
#   C. Faster R-CNN  →  min_distance_over_shingles = 8.0100
#   D. TransformerOCR  →  min_distance_over_shingles = 8.4751
# Đáp án gợi ý: C - Faster R-CNN
# Public013
#
#  Câu hỏi: Nội dung chính của bài báo là gì?
#   A. Đánh giá chuyển đổi số tại ngân hàng thương mại  →  min_distance_over_shingles = 8.0819
#   B. Giới thiệu công nghệ OCR và thử nghiệm FPT.AI Reader cho số hóa tài liệu tại Học viện Ngân hàng  →  min_distance_over_shingles = 7.5443
#   C. Xây dựng hệ thống ERP cho giáo dục  →  min_distance_over_shingles = 8.0591
#   D. Nghiên cứu ứng dụng AI trong tài chính  →  min_distance_over_shingles = 7.7652
# Đáp án gợi ý: B - Giới thiệu công nghệ OCR và thử nghiệm FPT.AI Reader cho số hóa tài liệu tại Học viện Ngân hàng
# Public001
#
#  Câu hỏi: Theo tài liệu Public_005, tỷ lệ sai số theo đơn vị từ của FPT.AI Reader trong thử nghiệm là bao nhiêu?
#   A. 0.16  →  min_distance_over_shingles = 8.2242
#   B. 0.2  →  min_distance_over_shingles = 8.3222
#   C. 0.27  →  min_distance_over_shingles = 8.2256
#   D. 0.5  →  min_distance_over_shingles = 8.2918
# Đáp án gợi ý: A - 0.16
# Public019
#
#  Câu hỏi: Theo tài liệu Public_006, các nhiệm vụ và quyền hạn của các thiết chế quản trị đại học ở Việt Nam được quy định trong luật nào?
#   A. Luật Giáo dục 2015  →  min_distance_over_shingles = 8.7758
#   B. Luật Giáo dục đại học sửa đổi số 34/2018  →  min_distance_over_shingles = 8.3974
#   C. Luật Công nghệ thông tin 2016  →  min_distance_over_shingles = 8.3224
#   D. Luật Khoa học và Công nghệ 2013  →  min_distance_over_shingles = 8.5971
# Đáp án gợi ý: C - Luật Công nghệ thông tin 2016
# Public001
#
#  Câu hỏi: Theo tài liệu Public_006, cơ quan nào có thẩm quyền cao nhất trong trường đại học?
#   A. Hội đồng trường  →  min_distance_over_shingles = 9.1519
#   B. Ban giám hiệu  →  min_distance_over_shingles = 9.2289
#   C. Bộ Giáo dục và Đào tạo  →  min_distance_over_shingles = 9.3275
#   D. Hiệu trưởng  →  min_distance_over_shingles = 9.1662
# Đáp án gợi ý: A - Hội đồng trường
# Public033
#
#  Câu hỏi: Làm thế nào để ứng dụng công nghệ số trong quản trị đại học có thể bao quát toàn bộ hoạt động của nhà trường kịp thời và hỗ trợ ra quyết sách quản lý, điều hành hiệu quả?
#   A. Quản lý sinh viên  →  min_distance_over_shingles = 7.9978
#   B. Quản trị đại học số  →  min_distance_over_shingles = 7.9506
#   C. Quản lý cơ sở vật chất  →  min_distance_over_shingles = 7.7239
#   D. Quản lý tuyển sinh  →  min_distance_over_shingles = 7.8065
# Đáp án gợi ý: C - Quản lý cơ sở vật chất
# Public019
#
#  Câu hỏi: Nội dung chính của bài báo Public_006 là gì?
#   A. Trình bày ứng dụng CNTT trong giảng dạy trực tuyến  →  min_distance_over_shingles = 8.6043
#   B. Phân tích thực trạng và đề xuất giải pháp ứng dụng công nghệ số trong công tác quản trị đại học ở Việt Nam, hướng tới đại học số  →  min_distance_over_shingles = 7.5433
#   C. Tổng quan về cách mạng công nghiệp 4.0  →  min_distance_over_shingles = 8.3735
#   D. Nghiên cứu vai trò của AI trong giáo dục  →  min_distance_over_shingles = 8.6882
# Đáp án gợi ý: B - Phân tích thực trạng và đề xuất giải pháp ứng dụng công nghệ số trong công tác quản trị đại học ở Việt Nam, hướng tới đại học số
# Public095
#
#  Câu hỏi: Theo số liệu trong tài liệu, đến nay ngành giáo dục đã số hóa dữ liệu của khoảng bao nhiêu giáo viên và học sinh?
#   A. 0,5 triệu giáo viên, 10 triệu học sinh  →  min_distance_over_shingles = 8.3782
#   B. 0,8 triệu giáo viên, 15 triệu học sinh  →  min_distance_over_shingles = 8.4464
#   C. 1,0 triệu giáo viên, 20 triệu học sinh  →  min_distance_over_shingles = 8.0307
#   D. 1,4 triệu giáo viên, 23 triệu học sinh  →  min_distance_over_shingles = 8.3384
# Đáp án gợi ý: C - 1,0 triệu giáo viên, 20 triệu học sinh
# Public017
#
#  Câu hỏi: ISO 15189:2022 áp dụng cho đối tượng nào?
#   A. Các công ty công nghệ thông tin  →  min_distance_over_shingles = 8.5946
#   B. Phòng xét nghiệm y tế  →  min_distance_over_shingles = 8.6101
#   C. Bệnh viện tư nhân  →  min_distance_over_shingles = 8.9870
#   D. Nhà sản xuất thiết bị y tế  →  min_distance_over_shingles = 8.6377
# Đáp án gợi ý: A - Các công ty công nghệ thông tin
# Public033
#
#  Câu hỏi: Theo tiêu chuẩn trong tài liệu Public_007, “khiếu nại” được định nghĩa như thế nào?
#   A. Ý kiến góp ý tích cực về hoạt động xét nghiệm  →  min_distance_over_shingles = 8.4569
#   B. Thắc mắc của cơ quan quản lý  →  min_distance_over_shingles = 8.1695
#   C. Sự không hài lòng của cá nhân/tổ chức liên quan đến hoạt động hoặc kết quả xét nghiệm, nơi dự kiến có phản hồi  →  min_distance_over_shingles = 8.1102
#   D. Báo cáo sự cố thiết bị  →  min_distance_over_shingles = 8.1525
# Đáp án gợi ý: C - Sự không hài lòng của cá nhân/tổ chức liên quan đến hoạt động hoặc kết quả xét nghiệm, nơi dự kiến có phản hồi
# Public022
#
#  Câu hỏi: Trong các tiêu chuẩn ISO/IEC liên quan đến đo lường và đánh giá sự phù hợp, tiêu chuẩn nào cung cấp từ vựng quốc tế về đo lường và định nghĩa thuật ngữ độ chệch?
#   A. ISO/IEC 17025  →  min_distance_over_shingles = 8.9990
#   B. ISO/IEC Guide 99  →  min_distance_over_shingles = 9.2367
#   C. ISO/IEC 17000  →  min_distance_over_shingles = 8.9759
#   D. ISO 18113-1  →  min_distance_over_shingles = 9.6306
# Đáp án gợi ý: C - ISO/IEC 17000
# Public030
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn ISO 15189:2022 là gì?
#   A. Quy định các yêu cầu về quản lý tài chính của bệnh viện  →  min_distance_over_shingles = 7.6816
#   B. Đưa ra yêu cầu về chất lượng và năng lực đối với phòng xét nghiệm y tế, bao gồm hệ thống quản lý, quy trình xét nghiệm và đánh giá công nhận  →  min_distance_over_shingles = 6.7644
#   C. Chỉ áp dụng cho thử nghiệm lâm sàng thuốc  →  min_distance_over_shingles = 8.1251
#   D. Hướng dẫn thiết kế thiết bị y tế  →  min_distance_over_shingles = 7.8662
# Đáp án gợi ý: B - Đưa ra yêu cầu về chất lượng và năng lực đối với phòng xét nghiệm y tế, bao gồm hệ thống quản lý, quy trình xét nghiệm và đánh giá công nhận
# Public001
#
#  Câu hỏi: Theo Public_007, “khoảng tham chiếu sinh học” thường được định nghĩa ở mức bao nhiêu phần trăm giá trị tập trung?
#   A. 0.95  →  min_distance_over_shingles = 7.6732
#   B. 0.5  →  min_distance_over_shingles = 7.6882
#   C. 0.9  →  min_distance_over_shingles = 7.6227
#   D. 0.99  →  min_distance_over_shingles = 7.7660
# Đáp án gợi ý: C - 0.9
# Public022
#
#  Câu hỏi: Giám đốc phòng xét nghiệm theo ISO 15189:2022 có thể ủy quyền nhiệm vụ cho ai?
#   A. Bất kỳ cá nhân bên ngoài nào  →  min_distance_over_shingles = 8.6492
#   B. Nhân viên có trình độ và năng lực, được lập thành văn bản ủy quyền  →  min_distance_over_shingles = 7.5554
#   C. Chỉ ban giám hiệu bệnh viện  →  min_distance_over_shingles = 8.9282
#   D. Các cơ quan quản lý  →  min_distance_over_shingles = 8.3188
# Đáp án gợi ý: B - Nhân viên có trình độ và năng lực, được lập thành văn bản ủy quyền
# Public001
#
#  Câu hỏi: ISO 15189:2022 yêu cầu thiết lập và theo dõi những chỉ số chất lượng nào?
#   A. Tỷ lệ bác sĩ tham gia hội chẩn  →  min_distance_over_shingles = 7.9773
#   B. Số lượng bệnh nhân nhập viện  →  min_distance_over_shingles = 8.0432
#   C. Số lượng mẫu bị từ chối, số lỗi khi nhận mẫu, số báo cáo kết quả sửa, tỷ lệ trả kết quả đúng hạn  →  min_distance_over_shingles = 6.6440
#   D. Tỷ lệ nhân viên tham gia đào tạo  →  min_distance_over_shingles = 8.1339
# Đáp án gợi ý: C - Số lượng mẫu bị từ chối, số lỗi khi nhận mẫu, số báo cáo kết quả sửa, tỷ lệ trả kết quả đúng hạn
# Public001
#
#  Câu hỏi: Theo tài liệu Public_008, các yêu cầu đúng khi lựa chọn, vận hành và bảo dưỡng thiết bị phòng xét nghiệm là gì?
#   A. Thiết bị phải được vận hành bởi nhân viên đào tạo, được ủy quyền, có năng lực; được bảo trì theo hướng dẫn nhà sản xuất; có biện pháp ngăn điều chỉnh ngoài ý muốn; và thiết bị bị lỗi phải được dán nhãn “không hoạt động” cho đến khi xác minh chính xác  →  min_distance_over_shingles = 5.9615
#   B. Thiết bị chỉ cần được vận hành theo hướng dẫn nhà sản xuất, không cần đào tạo hay dán nhãn khi lỗi  →  min_distance_over_shingles = 7.2047
#   C. Thiết bị không cần bảo trì nếu không ảnh hưởng kết quả xét nghiệm  →  min_distance_over_shingles = 6.9976
#   D. Nhân viên có thể điều chỉnh thiết bị bất cứ lúc nào nếu cần để đẩy nhanh công việc  →  min_distance_over_shingles = 6.8274
# Đáp án gợi ý: A - Thiết bị phải được vận hành bởi nhân viên đào tạo, được ủy quyền, có năng lực; được bảo trì theo hướng dẫn nhà sản xuất; có biện pháp ngăn điều chỉnh ngoài ý muốn; và thiết bị bị lỗi phải được dán nhãn “không hoạt động” cho đến khi xác minh chính xác
# Public001
#
#  Câu hỏi: Nội dung chính của phần tiêu chuẩn trong tài liệu là gì?
#   A. Quy định quy trình khám chữa bệnh cho bệnh nhân  →  min_distance_over_shingles = 9.2475
#   B. Đưa ra yêu cầu về cơ cấu, quản trị, nhân lực, cơ sở vật chất, thiết bị, thuốc thử và quá trình xét nghiệm trong phòng xét nghiệm y tế  →  min_distance_over_shingles = 8.9865
#   C. Mô tả chi tiết hệ thống tài chính của bệnh viện  →  min_distance_over_shingles = 8.6743
#   D. Hướng dẫn xây dựng nhà máy y tế  →  min_distance_over_shingles = 8.9982
# Đáp án gợi ý: C - Mô tả chi tiết hệ thống tài chính của bệnh viện
# Public031
#
#  Câu hỏi: Nếu phòng xét nghiệm có 500 mẫu xét nghiệm trong tháng, trong đó có 25 mẫu bị từ chối, tỷ lệ từ chối mẫu là bao nhiêu?
#   A. 0.05  →  min_distance_over_shingles = 8.0371
#   B. 0.025  →  min_distance_over_shingles = 8.0562
#   C. 0.1  →  min_distance_over_shingles = 8.0976
#   D. 0.075  →  min_distance_over_shingles = 8.1104
# Đáp án gợi ý: A - 0.05
# Public022
#
#  Câu hỏi: Học phần Những nguyên lý cơ bản của Chủ nghĩa Mác – Lênin thuộc khối kiến thức nào?
#   A. Giáo dục đại cương  →  min_distance_over_shingles = 8.7938
#   B. Tin học cơ sở  →  min_distance_over_shingles = 8.2930
#   C. Công nghệ phần mềm  →  min_distance_over_shingles = 8.3391
#   D. Hệ thống thông tin  →  min_distance_over_shingles = 8.3643
# Đáp án gợi ý: B - Tin học cơ sở
# Public013
#
#  Câu hỏi: Học phần Nhập môn ngành CNTT trang bị cho sinh viên những kỹ năng nào ngoài kiến thức chuyên ngành?
#   A. Kỹ năng nghiên cứu khoa học nâng cao  →  min_distance_over_shingles = 7.1993
#   B. Kỹ năng quản lý dự án phức tạp  →  min_distance_over_shingles = 6.9877
#   C. Kỹ năng mềm như làm việc nhóm, thuyết trình, tìm kiếm thông tin, phương pháp học đại học  →  min_distance_over_shingles = 6.9224
#   D. Kỹ năng phân tích tài chính  →  min_distance_over_shingles = 7.0894
# Đáp án gợi ý: C - Kỹ năng mềm như làm việc nhóm, thuyết trình, tìm kiếm thông tin, phương pháp học đại học
# Public013
#
#  Câu hỏi: Học phần nào vừa giúp sinh viên năm nhất làm quen với môi trường đại học và kiến thức cơ bản ngành CNTT, vừa rèn luyện các kỹ năng mềm và chuẩn mực đạo đức cần thiết để trở thành kỹ sư công nghệ thông tin?
#   A. Toán 1  →  min_distance_over_shingles = 8.7724
#   B. Toán 2  →  min_distance_over_shingles = 8.8463
#   C. Nhập môn ngành CNTT  →  min_distance_over_shingles = 8.3747
#   D. Đại số và cấu trúc đại số  →  min_distance_over_shingles = 8.0905
# Đáp án gợi ý: D - Đại số và cấu trúc đại số
# Public001
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu lịch sử phát triển ngành CNTT  →  min_distance_over_shingles = 7.7088
#   B. Mô tả vắn tắt nội dung và khối lượng các học phần bắt buộc, cơ sở và chuyên ngành trong chương trình đào tạo CNTT  →  min_distance_over_shingles = 7.5905
#   C. Phân tích xu hướng việc làm CNTT  →  min_distance_over_shingles = 7.8991
#   D. Đề xuất cải tiến phương pháp giảng dạy CNTT  →  min_distance_over_shingles = 7.5454
# Đáp án gợi ý: D - Đề xuất cải tiến phương pháp giảng dạy CNTT
# Public001
#
#  Câu hỏi: Theo quy định tại tài liệu Public_009, nếu một học phần có cấu trúc 3(2:1:6) thì số tiết lý thuyết, thực hành và tự học lần lượt là bao nhiêu?
#   A. 3 LT, 3 TH, 6 tự học  →  min_distance_over_shingles = 7.7914
#   B. 2 LT, 2 TH, 4 tự học  →  min_distance_over_shingles = 7.6883
#   C. 2 LT, 1 TH, 6 tự học  →  min_distance_over_shingles = 7.8391
#   D. 3 LT, 0 TH, 6 tự học  →  min_distance_over_shingles = 7.6482
# Đáp án gợi ý: D - 3 LT, 0 TH, 6 tự học
# Public019
#
#  Câu hỏi: Theo tiêu chuẩn ISO 15189:2022, việc lưu giữ hồ sơ phòng xét nghiệm nhằm mục đích chính nào?
#   A. Đảm bảo nhân viên phòng xét nghiệm có đủ kỹ năng  →  min_distance_over_shingles = 8.1909
#   B. Giảm chi phí vận hành  →  min_distance_over_shingles = 7.3465
#   C. Truy xuất được kết quả xét nghiệm trong khoảng thời gian cần thiết hoặc theo quy định  →  min_distance_over_shingles = 7.2354
#   D. Đình chỉ hoạt động của phòng xét nghiệm  →  min_distance_over_shingles = 7.7628
# Đáp án gợi ý: C - Truy xuất được kết quả xét nghiệm trong khoảng thời gian cần thiết hoặc theo quy định
# Public022
#
#  Câu hỏi: Khi xảy ra sự không phù hợp, hành động đầu tiên mà phòng xét nghiệm phải thực hiện theo ISO 15189:2022 là gì?
#   A. Kiểm soát và khắc phục sự không phù hợp  →  min_distance_over_shingles = 7.3629
#   B. Đình chỉ hoạt động của phòng xét nghiệm vô thời hạn  →  min_distance_over_shingles = 7.7372
#   C. Giảm chi phí vận hành  →  min_distance_over_shingles = 7.4668
#   D. Miễn trừ trách nhiệm cho nhân viên gây lỗi  →  min_distance_over_shingles = 7.2434
# Đáp án gợi ý: D - Miễn trừ trách nhiệm cho nhân viên gây lỗi
# Public001
#
#  Câu hỏi: Theo hướng dẫn về kiểm soát hồ sơ, phòng xét nghiệm phải đảm bảo điều gì khi sửa đổi hồ sơ?
#   A. Các sửa đổi phải có khả năng truy nguyên đến phiên bản trước hoặc các quan sát ban đầu, bao gồm ngày, giờ, nội dung thay đổi và nhân viên thực hiện  →  min_distance_over_shingles = 9.0956
#   B. Chỉ cần lưu trữ phiên bản mới của hồ sơ, không cần lưu dữ liệu gốc  →  min_distance_over_shingles = 9.5367
#   C. Chỉ cần lưu ngày và giờ của phiên bản mới, không cần thông tin về thay đổi  →  min_distance_over_shingles = 9.4032
#   D. Không cần lưu hồ sơ nếu chỉ là sửa đổi nhỏ  →  min_distance_over_shingles = 9.8672
# Đáp án gợi ý: A - Các sửa đổi phải có khả năng truy nguyên đến phiên bản trước hoặc các quan sát ban đầu, bao gồm ngày, giờ, nội dung thay đổi và nhân viên thực hiện
# Public031
#
#  Câu hỏi: Nội dung chính của phần 8 trong tiêu chuẩn ISO 15189:2022 là gì?
#   A. Yêu cầu về cơ sở vật chất và thiết bị  →  min_distance_over_shingles = 7.6134
#   B. Quy định về kỹ thuật xét nghiệm  →  min_distance_over_shingles = 7.7174
#   C. Yêu cầu hệ thống quản lý, bao gồm tài liệu, hồ sơ, kiểm soát rủi ro, cải tiến, đánh giá và xem xét  →  min_distance_over_shingles = 6.7722
#   D. Quy định về đạo đức nghề nghiệp của nhân viên phòng xét nghiệm  →  min_distance_over_shingles = 7.6352
# Đáp án gợi ý: C - Yêu cầu hệ thống quản lý, bao gồm tài liệu, hồ sơ, kiểm soát rủi ro, cải tiến, đánh giá và xem xét
# Public001
#
#  Câu hỏi: Theo tài liệu Public_010, nếu một phòng xét nghiệm thiết lập cấu trúc quản lý 5 mục tiêu và mỗi mục tiêu yêu cầu số hành động cải tiến tối thiểu theo quy định của tài liệu, tổng số hành động tối thiểu là bao nhiêu?
#   A. 5  →  min_distance_over_shingles = 7.9514
#   B. 10  →  min_distance_over_shingles = 8.0768
#   C. 15  →  min_distance_over_shingles = 8.0666
#   D. 20  →  min_distance_over_shingles = 7.6402
# Đáp án gợi ý: D - 20
# Public019
#
#  Câu hỏi: Mạng GAN (Global Area Network) là gì?
#   A. Mạng cục bộ trong phạm vi nhỏ  →  min_distance_over_shingles = 7.6921
#   B. Mạng diện rộng trong một quốc gia  →  min_distance_over_shingles = 7.5382
#   C. Mạng toàn cầu, kết hợp nhiều mạng con, ví dụ Internet  →  min_distance_over_shingles = 7.5118
#   D. Mạng kết nối 2–3 máy tính  →  min_distance_over_shingles = 7.6587
# Đáp án gợi ý: C - Mạng toàn cầu, kết hợp nhiều mạng con, ví dụ Internet
# Public001
#
#  Câu hỏi: Thành phần nào có chức năng giao tiếp giữa máy tính và đường truyền trong mạng máy tính?
#   A. Bộ định tuyến (Router)  →  min_distance_over_shingles = 7.0415
#   B. Vỉ mạng (Network Interface Card – NIC)  →  min_distance_over_shingles = 7.2628
#   C. Thiết bị đầu cuối (Terminal)  →  min_distance_over_shingles = 7.3262
#   D. Phần mềm ứng dụng  →  min_distance_over_shingles = 7.6577
# Đáp án gợi ý: A - Bộ định tuyến (Router)
# Public001
#
#  Câu hỏi: Mạng máy tính được phân loại theo những tiêu chí nào và Internet ban đầu ra đời từ mục đích gì?
#   A. Mạng được phân loại theo quan hệ giữa các máy và theo quy mô địa lý; Internet ban đầu ra đời từ mục đích quân sự của Bộ Quốc phòng Mỹ  →  min_distance_over_shingles = 7.7249
#   B. Mạng được phân loại theo tốc độ và dung lượng; Internet ban đầu ra đời để phục vụ thương mại điện tử  →  min_distance_over_shingles = 7.1319
#   C. Mạng được phân loại theo số lượng người dùng và chi phí; Internet ban đầu ra đời để phục vụ cho các công ty công nghệ  →  min_distance_over_shingles = 7.9743
#   D. Mạng được phân loại theo loại đường truyền và phần mềm; Internet ban đầu ra đời để phục vụ giáo dục phổ thôngComplete  →  min_distance_over_shingles = 7.2936
# Đáp án gợi ý: B - Mạng được phân loại theo tốc độ và dung lượng; Internet ban đầu ra đời để phục vụ thương mại điện tử
# Public001
#
#  Câu hỏi: Nội dung chính của tài liệu Public_011 là gì?
#   A. Giới thiệu lịch sử Internet toàn cầu  →  min_distance_over_shingles = 9.2352
#   B. Trình bày khái niệm, lịch sử phát triển, phân loại, thành phần, kiến trúc mạng máy tính và Internet  →  min_distance_over_shingles = 8.2293
#   C. Hướng dẫn cài đặt phần mềm mạng  →  min_distance_over_shingles = 8.6485
#   D. Phân tích mô hình OSI chi tiết  →  min_distance_over_shingles = 8.4638
# Đáp án gợi ý: B - Trình bày khái niệm, lịch sử phát triển, phân loại, thành phần, kiến trúc mạng máy tính và Internet
# Public031
#
#  Câu hỏi: Với một mạng kết nối 200 máy tính và có bán kính hoạt động 500m trong một tòa nhà, phân loại mạng chính xác nhất của nó là gì?
#   A. LAN (Local Area Network)  →  min_distance_over_shingles = 9.0468
#   B. WAN (Wide Area Network)  →  min_distance_over_shingles = 8.9534
#   C. GAN (Global Area Network)  →  min_distance_over_shingles = 8.9314
#   D. MAN (Metropolitan Area Network)  →  min_distance_over_shingles = 9.1457
# Đáp án gợi ý: C - GAN (Global Area Network)
# Public030
#
#  Câu hỏi: Hệ điều hành có nhiệm vụ gì?
#   A. Chỉ lưu trữ dữ liệu cho máy tính  →  min_distance_over_shingles = 8.2887
#   B. Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình và cung cấp dịch vụ cho người dùng  →  min_distance_over_shingles = 6.9034
#   C. Tạo ra phần cứng mới  →  min_distance_over_shingles = 7.7803
#   D. Truyền dữ liệu qua mạng  →  min_distance_over_shingles = 7.8491
# Đáp án gợi ý: B - Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình và cung cấp dịch vụ cho người dùng
# Public001
#
#  Câu hỏi: Theo tài liệu, ký hiệu đại diện * trong tên tệp có ý nghĩa gì?
#   A. Đại diện cho một ký tự bất kỳ  →  min_distance_over_shingles = 8.0762
#   B. Đại diện cho số bất kỳ  →  min_distance_over_shingles = 8.0482
#   C. Đại diện cho một chuỗi ký tự bất kỳ  →  min_distance_over_shingles = 7.9696
#   D. Đại diện cho phần mở rộng bắt buộc  →  min_distance_over_shingles = 8.1360
# Đáp án gợi ý: C - Đại diện cho một chuỗi ký tự bất kỳ
# Public019
#
#  Câu hỏi: Hệ điều hành có những nhiệm vụ chính nào và phiên bản Windows nào cho phép đặt tên tệp dài tới 255 ký tự?
#   A. Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình, giao tiếp với người dùng; Windows 95  →  min_distance_over_shingles = 6.7006
#   B. Chỉ quản lý bộ nhớ và CPU; Windows 3.0 AUTOEXEC.BAT  →  min_distance_over_shingles = 7.7281
#   C. Chỉ khởi động máy và tắt máy; Windows NT 4.0  →  min_distance_over_shingles = 7.8258
#   D. Quản lý thiết bị ngoại vi nhưng không quản lý tệp; Windows XP  →  min_distance_over_shingles = 7.9142
# Đáp án gợi ý: A - Quản lý tài nguyên, điều khiển thiết bị, quản lý chương trình, giao tiếp với người dùng; Windows 95
# Public019
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu lịch sử phát triển phần cứng  →  min_distance_over_shingles = 7.3581
#   B. Trình bày khái niệm, quản lý tệp, hệ lệnh, hệ điều hành Windows (từ MS-DOS, Windows 95 đến Windows XP)  →  min_distance_over_shingles = 6.7317
#   C. Hướng dẫn cài đặt phần mềm diệt virus  →  min_distance_over_shingles = 7.7394
#   D. Phân tích mô hình mạng OSI  →  min_distance_over_shingles = 7.4608
# Đáp án gợi ý: B - Trình bày khái niệm, quản lý tệp, hệ lệnh, hệ điều hành Windows (từ MS-DOS, Windows 95 đến Windows XP)
# Public001
#
#  Câu hỏi: Nếu Windows XP quản lý cho phép đặt tên tập tin dài tối đa 255 ký tự, còn MS-DOS chỉ cho phép tối đa 8 ký tự, thì Windows XP dài hơn bao nhiêu ký tự?
#   A. 120 ký tự  →  min_distance_over_shingles = 8.1710
#   B. 200 ký tự  →  min_distance_over_shingles = 7.9448
#   C. 247 ký tự  →  min_distance_over_shingles = 8.4152
#   D. 300 ký tự  →  min_distance_over_shingles = 8.2295
# Đáp án gợi ý: B - 200 ký tự
# Public001
#
#  Câu hỏi: Thế hệ máy tính điện tử nào sử dụng bóng đèn điện tử chân không?
#   A. Thế hệ 1 (1950–1958)  →  min_distance_over_shingles = 8.3760
#   B. Thế hệ 2 (1958–1964)  →  min_distance_over_shingles = 8.1695
#   C. Thế hệ 3 (1965–1974)  →  min_distance_over_shingles = 8.2942
#   D. Thế hệ 4 (1974–nay)  →  min_distance_over_shingles = 8.1211
# Đáp án gợi ý: D - Thế hệ 4 (1974–nay)
# Public001
#
#  Câu hỏi: Thuật ngữ “Tin học” (Informatics) lần đầu tiên được đề xuất bởi ai?
#   A. Philippe Dreyfus  →  min_distance_over_shingles = 8.3479
#   B. Karl Steinbuch  →  min_distance_over_shingles = 8.2141
#   C. Walter F. Bauer  →  min_distance_over_shingles = 8.2535
#   D. Alan Turing  →  min_distance_over_shingles = 8.3706
# Đáp án gợi ý: B - Karl Steinbuch
# Public001
#
#  Câu hỏi: Thông tin khác dữ liệu ở điểm nào và quá trình xử lý thông tin theo máy tính gồm những bước nào?
#   A. Thông tin có ý nghĩa, dữ liệu là sự kiện thô; xử lý gồm Input – Process – Output  →  min_distance_over_shingles = 6.9824
#   B. Thông tin và dữ liệu giống nhau; xử lý chỉ có Output  →  min_distance_over_shingles = 7.7518
#   C. Dữ liệu có ý nghĩa, thông tin không có; xử lý chỉ có Input  →  min_distance_over_shingles = 7.6012
#   D. Thông tin chỉ là dữ liệu lưu trữ; xử lý không cần qua các bước  →  min_distance_over_shingles = 8.8123
# Đáp án gợi ý: A - Thông tin có ý nghĩa, dữ liệu là sự kiện thô; xử lý gồm Input – Process – Output
# Public013
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Trình bày chi tiết về mạng máy tính  →  min_distance_over_shingles = 7.6781
#   B. Giới thiệu các khái niệm cơ bản về dữ liệu, thông tin, tri thức; lịch sử phát triển máy tính; khái niệm tin học, CNTT và ICT  →  min_distance_over_shingles = 7.0087
#   C. Hướng dẫn cài đặt phần mềm  →  min_distance_over_shingles = 8.1107
#   D. Phân tích chi tiết hệ điều hành Windows  →  min_distance_over_shingles = 7.0714
# Đáp án gợi ý: B - Giới thiệu các khái niệm cơ bản về dữ liệu, thông tin, tri thức; lịch sử phát triển máy tính; khái niệm tin học, CNTT và ICT
# Public001
#
#  Câu hỏi: Nếu một máy tính thế hệ 2 có tốc độ trung bình 50.000 phép tính/giây, thì nó nhanh gấp bao nhiêu lần so với máy thế hệ 1 tốc độ trung bình 1.000 phép tính/giây?
#   A. 25 lần  →  min_distance_over_shingles = 8.2963
#   B. 30 lần  →  min_distance_over_shingles = 8.2975
#   C. 50 lần  →  min_distance_over_shingles = 8.4352
#   D. 100 lần  →  min_distance_over_shingles = 8.4142
# Đáp án gợi ý: A - 25 lần
# Public031
#
#  Câu hỏi: Bit là viết tắt của từ gì?
#   A. Binary digiT  →  min_distance_over_shingles = 9.3267
#   B. Basic information type  →  min_distance_over_shingles = 9.5406
#   C. Binary integration tool  →  min_distance_over_shingles = 9.1384
#   D. Base information token  →  min_distance_over_shingles = 9.5595
# Đáp án gợi ý: C - Binary integration tool
# Public025
#
#  Câu hỏi: Trong hệ đếm thập lục phân, ký tự “F” biểu diễn giá trị thập phân nào?
#   A. 12  →  min_distance_over_shingles = 7.7643
#   B. 14  →  min_distance_over_shingles = 7.6652
#   C. 15  →  min_distance_over_shingles = 7.6433
#   D. 16  →  min_distance_over_shingles = 7.6432
# Đáp án gợi ý: D - 16
# Public058
#
#  Câu hỏi: Trong máy tính, mọi dữ liệu được biểu diễn dưới dạng gì và đơn vị thông tin nhỏ nhất là gì?
#   A. Dưới dạng chữ cái; đơn vị nhỏ nhất là byte  →  min_distance_over_shingles = 7.2816
#   B. Dưới dạng nhị phân (chuỗi bit); đơn vị nhỏ nhất là bit  →  min_distance_over_shingles = 7.4243
#   C. Dưới dạng số thập phân; đơn vị nhỏ nhất là ký tự  →  min_distance_over_shingles = 7.0487
#   D. Dưới dạng tín hiệu tương tự; đơn vị nhỏ nhất là từ  →  min_distance_over_shingles = 7.0784
# Đáp án gợi ý: C - Dưới dạng số thập phân; đơn vị nhỏ nhất là ký tự
# Public001
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Giới thiệu mạng máy tính  →  min_distance_over_shingles = 8.1284
#   B. Trình bày biểu diễn dữ liệu trong máy tính: các hệ đếm, số nguyên, số thực, dữ liệu ký tự, số hóa tín hiệu và tính toán số học  →  min_distance_over_shingles = 6.2927
#   C. Giới thiệu hệ điều hành Windows  →  min_distance_over_shingles = 7.2600
#   D. Hướng dẫn lập trình Pascal  →  min_distance_over_shingles = 8.0485
# Đáp án gợi ý: B - Trình bày biểu diễn dữ liệu trong máy tính: các hệ đếm, số nguyên, số thực, dữ liệu ký tự, số hóa tín hiệu và tính toán số học
# Public001
#
#  Câu hỏi: Nếu dùng 8 bit để biểu diễn số nguyên không dấu, giá trị lớn nhất có thể biểu diễn là bao nhiêu?
#   A. 128  →  min_distance_over_shingles = 8.5352
#   B. 254  →  min_distance_over_shingles = 8.3238
#   C. 255  →  min_distance_over_shingles = 8.2350
#   D. 256  →  min_distance_over_shingles = 8.2148
# Đáp án gợi ý: D - 256
# Public001
#
#  Câu hỏi: Khối nào trong CPU có nhiệm vụ thực hiện các phép tính số học và logic?
#   A. Khối điều khiển (CU)  →  min_distance_over_shingles = 8.3331
#   B. Khối số học và logic (ALU)  →  min_distance_over_shingles = 8.2003
#   C. Tập thanh ghi  →  min_distance_over_shingles = 8.7474
#   D. Bộ nhớ ngoài  →  min_distance_over_shingles = 8.5401
# Đáp án gợi ý: B - Khối số học và logic (ALU)
# Public005
#
#  Câu hỏi: Bộ nhớ nào lưu trữ chương trình hệ thống và không bị mất dữ liệu khi tắt máy?
#   A. ROM  →  min_distance_over_shingles = 9.3526
#   B. RAM  →  min_distance_over_shingles = 8.7465
#   C. Cache  →  min_distance_over_shingles = 8.7510
#   D. Thanh ghi  →  min_distance_over_shingles = 8.5009
# Đáp án gợi ý: D - Thanh ghi
# Public001
#
#  Câu hỏi: CPU gồm những bộ phận chính nào và bộ nhớ chính của máy tính được chia thành những loại nào?
#   A. Khối điều khiển, bộ nhớ ngoài, bàn phím; chỉ RAM  →  min_distance_over_shingles = 7.6944
#   B. Khối điều khiển, khối tính toán số học – logic, các thanh ghi; ROM và RAM  →  min_distance_over_shingles = 8.4706
#   C. ALU, ổ đĩa cứng, USB; chỉ ROM  →  min_distance_over_shingles = 8.0895
#   D. Bo mạch chủ, cache, màn hình; DVD và CD  →  min_distance_over_shingles = 7.9127
# Đáp án gợi ý: A - Khối điều khiển, bộ nhớ ngoài, bàn phím; chỉ RAM
# Public008
#
#  Câu hỏi: Nội dung chính của tài liệu là gì?
#   A. Trình bày chi tiết lịch sử phát triển máy tính  →  min_distance_over_shingles = 7.4969
#   B. Giới thiệu cấu trúc và chức năng CPU, các loại bộ nhớ, thiết bị vào-ra và hệ thống bus trong máy tính  →  min_distance_over_shingles = 6.5581
#   C. Hướng dẫn cài đặt phần mềm hệ thống  →  min_distance_over_shingles = 7.9647
#   D. Phân tích hệ điều hành Windows  →  min_distance_over_shingles = 7.2065
# Đáp án gợi ý: B - Giới thiệu cấu trúc và chức năng CPU, các loại bộ nhớ, thiết bị vào-ra và hệ thống bus trong máy tính
# Public001
#
#  Câu hỏi: Nếu một CPU có 36 bit địa chỉ, dung lượng tối đa của bộ nhớ chính mà nó quản lý được là bao nhiêu?
#   A. 64 MB  →  min_distance_over_shingles = 8.1473
#   B. 64 KB  →  min_distance_over_shingles = 8.0655
#   C. 64 GB  →  min_distance_over_shingles = 8.1297
#   D. 64 TB  →  min_distance_over_shingles = 8.4952
# Đáp án gợi ý: B - 64 KB
# Public001
#
#  Câu hỏi: Tiêu chuẩn TCVN 9395:2012 áp dụng cho loại cọc nào?
#   A. Cọc đóng bê tông cốt thép có đường kính nhỏ hơn 60 cm  →  min_distance_over_shingles = 7.9013
#   B. Cọc khoan nhồi bê tông cốt thép có đường kính ≥ 60 cm (trừ công trình địa chất đặc biệt)  →  min_distance_over_shingles = 7.3459
#   C. Cọc thép ống nhồi bê tông  →  min_distance_over_shingles = 7.5591
#   D. Tất cả các loại cọc dùng trong xây dựng  →  min_distance_over_shingles = 7.6523
# Đáp án gợi ý: B - Cọc khoan nhồi bê tông cốt thép có đường kính ≥ 60 cm (trừ công trình địa chất đặc biệt)
# Public022
#
#  Câu hỏi: Dung dịch khoan bentonite có vai trò chính gì trong thi công cọc khoan nhồi?
#   A. Giữ ổn định thành hố khoan, ngăn sụt lở và đưa mùn khoan ra ngoài  →  min_distance_over_shingles = 8.7170
#   B. Tăng khả năng chịu lực của bê tông  →  min_distance_over_shingles = 9.0143
#   C. Làm phụ gia thay thế xi măng  →  min_distance_over_shingles = 9.0713
#   D. Giảm độ nhớt của bê tông  →  min_distance_over_shingles = 8.9250
# Đáp án gợi ý: A - Giữ ổn định thành hố khoan, ngăn sụt lở và đưa mùn khoan ra ngoài
# Public030
#
#  Câu hỏi: Theo TCVN 9395:2012, tiêu chuẩn này áp dụng cho loại cọc nào và từ đường kính bao nhiêu trở lên?
#   A. Cọc ép, từ 20 cm  →  min_distance_over_shingles = 8.1908
#   B. Cọc khoan nhồi, từ 30 cm  →  min_distance_over_shingles = 8.0696
#   C. Cọc thép, từ 25 cm  →  min_distance_over_shingles = 8.1175
#   D. Cọc gỗ, từ 40 cm  →  min_distance_over_shingles = 8.7969
# Đáp án gợi ý: B - Cọc khoan nhồi, từ 30 cm
# Public001
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn TCVN 9395:2012 là gì?
#   A. Quy định thiết kế kết cấu móng  →  min_distance_over_shingles = 7.6313
#   B. Hướng dẫn phương pháp thí nghiệm tải trọng cọc  →  min_distance_over_shingles = 7.5929
#   C. Quy định về thi công, kiểm tra chất lượng, nghiệm thu và an toàn lao động trong xây dựng cọc khoan nhồi  →  min_distance_over_shingles = 7.1669
#   D. Chỉ quy định về yêu cầu an toàn trong công tác khoan  →  min_distance_over_shingles = 7.9916
# Đáp án gợi ý: C - Quy định về thi công, kiểm tra chất lượng, nghiệm thu và an toàn lao động trong xây dựng cọc khoan nhồi
# Public001
#
#  Câu hỏi: Nếu trong quá trình khoan, cao độ dung dịch khoan phải luôn cao hơn mực nước ngầm ít nhất 1,5 m, giả sử mực nước ngầm ở -10 m thì cao độ dung dịch khoan tối thiểu phải đạt bao nhiêu?
#   A. -11,5 m  →  min_distance_over_shingles = 8.6747
#   B. -8,5 m  →  min_distance_over_shingles = 8.5659
#   C. -6,0 m  →  min_distance_over_shingles = 8.5868
#   D. -5,0 m  →  min_distance_over_shingles = 8.6015
# Đáp án gợi ý: B - -8,5 m
# Public030
#
#  Câu hỏi: Theo TCVN 5574:2018, tính toán kết cấu bê tông và bê tông cốt thép cần được thực hiện dựa trên những trạng thái giới hạn nào?
#   A. Chỉ trạng thái giới hạn thứ nhất  →  min_distance_over_shingles = 7.3398
#   B. Trạng thái giới hạn thứ nhất và trạng thái giới hạn thứ hai  →  min_distance_over_shingles = 7.8638
#   C. Chỉ trạng thái giới hạn thứ hai  →  min_distance_over_shingles = 7.4728
#   D. Không yêu cầu xét trạng thái giới hạn  →  min_distance_over_shingles = 7.7873
# Đáp án gợi ý: A - Chỉ trạng thái giới hạn thứ nhất
# Public005
#
#  Câu hỏi: Các loại bê tông nào được phép sử dụng khi thiết kế kết cấu theo TCVN 5574:2018?
#   A. Bê tông nặng  →  min_distance_over_shingles = 9.2142
#   B. Bê tông hạt nhỏ  →  min_distance_over_shingles = 9.3806
#   C. Bê tông nhẹ, bê tông tổ ong  →  min_distance_over_shingles = 9.6204
#   D. Bê tông tự ứng suất  →  min_distance_over_shingles = 9.2225
# Đáp án gợi ý: A - Bê tông nặng
# Public003
#
#  Câu hỏi: Theo TCVN 9379:2012, tính toán kết cấu bê tông và bê tông cốt thép cần được thực hiện theo những trạng thái giới hạn nào và phải đảm bảo điều gì trong suốt thời hạn sử dụng công trình?
#   A. Trạng thái giới hạn thứ nhất và thứ hai; đảm bảo độ tin cậy của công trình  →  min_distance_over_shingles = 7.0394
#   B. Chỉ trạng thái giới hạn thứ nhất; đảm bảo hình thành vết nứt nhỏ  →  min_distance_over_shingles = 7.3339
#   C. Trạng thái giới hạn thứ hai và tải trọng tiêu chuẩn; đảm bảo không có biến dạng  →  min_distance_over_shingles = 7.3476
#   D. Trạng thái giới hạn về biến dạng; đảm bảo không xuất hiện ứng suất trước  →  min_distance_over_shingles = 7.4733
# Đáp án gợi ý: A - Trạng thái giới hạn thứ nhất và thứ hai; đảm bảo độ tin cậy của công trình
# Public001
#
#  Câu hỏi: Nội dung chính của tiêu chuẩn TCVN 5574:2018 là gì?
#   A. Quy định về phương pháp thí nghiệm vật liệu bê tông  →  min_distance_over_shingles = 8.7461
#   B. Nguyên tắc thiết kế, tính toán độ bền, ổn định, biến dạng, nứt và quy định về vật liệu cho kết cấu bê tông, bê tông cốt thép  →  min_distance_over_shingles = 8.8472
#   C. Chỉ quy định về cấu kiện bê tông dự ứng lực  →  min_distance_over_shingles = 9.3582
#   D. Hướng dẫn thi công và nghiệm thu công trình bê tông  →  min_distance_over_shingles = 9.0046
# Đáp án gợi ý: A - Quy định về phương pháp thí nghiệm vật liệu bê tông
# Public077
#
#  Câu hỏi: Nếu một dầm bê tông cốt thép có nhịp 6 m, theo TCVN 5574:2018 độ võng tối đa cho phép là 1/150 nhịp, giá trị võng lớn nhất cho phép là bao nhiêu?
#   A. 20 mm  →  min_distance_over_shingles = 7.7789
#   B. 30 mm  →  min_distance_over_shingles = 7.8862
#   C. 40 mm  →  min_distance_over_shingles = 7.9051
#   D. 50 mm  →  min_distance_over_shingles = 7.8394
# Đáp án gợi ý: A - 20 mm
# Public017
#
#  Câu hỏi: Tiêu chuẩn TCVN 5574:2018 áp dụng cho những loại bê tông nào?
#   A. Bê tông nặng  →  min_distance_over_shingles = 9.0047
#   B. Bê tông hạt nhỏ  →  min_distance_over_shingles = 9.0230
#   C. Bê tông nhẹ, bê tông tổ ong  →  min_distance_over_shingles = 8.1438
#   D. Bê tông tự ứng suất  →  min_distance_over_shingles = 8.6294
# Đáp án gợi ý: C - Bê tông nhẹ, bê tông tổ ong
# Public001
#
#  Câu hỏi: Tiêu chuẩn TCVN 5574:2018 không áp dụng để thiết kế loại kết cấu nào sau đây?
#   A. Kết cấu nhà và công trình chịu nhiệt độ từ -70°C đến +50°C  →  min_distance_over_shingles = 7.4058
#   B. Kết cấu bê tông cốt thép nhà dân dụng thông thường  →  min_distance_over_shingles = 7.5017
#   C. Kết cấu liên hợp thép – bê tông, bê tông cốt sợi, công trình thủy công, cầu…  →  min_distance_over_shingles = 7.4906
#   D. Các công trình không xâm thực thông thường  →  min_distance_over_shingles = 7.7071
# Đáp án gợi ý: A - Kết cấu nhà và công trình chịu nhiệt độ từ -70°C đến +50°C
# Public022
#
#  Câu hỏi: Theo TCVN 9379:2012, tính toán kết cấu bê tông và bê tông cốt thép cần được tiến hành theo những trạng thái giới hạn nào và phải đảm bảo điều gì trong suốt thời hạn sử dụng công trình?
#   A. Trạng thái giới hạn thứ nhất và thứ hai; đảm bảo độ tin cậy của công trình  →  min_distance_over_shingles = 7.2670
#   B. Chỉ trạng thái giới hạn thứ nhất; đảm bảo không xuất hiện vết nứt  →  min_distance_over_shingles = 7.2213
#   C. Trạng thái giới hạn thứ hai; đảm bảo công trình không có biến dạng  →  min_distance_over_shingles = 7.6417
#   D. Trạng thái giới hạn ổn định vị trí; đảm bảo không trượt, không lật  →  min_distance_over_shingles = 7.3928
# Đáp án gợi ý: B - Chỉ trạng thái giới hạn thứ nhất; đảm bảo không xuất hiện vết nứt
# Public001
#
#  Câu hỏi: Nội dung chính của phần yêu cầu chung đối với kết cấu bê tông và bê tông cốt thép trong TCVN 5574:2018 là gì?
#   A. Hướng dẫn chi tiết về phương pháp thí nghiệm cường độ bê tông  →  min_distance_over_shingles = 7.7412
#   B. Quy định các yêu cầu về an toàn, điều kiện sử dụng, độ bền lâu, yêu cầu cấu tạo và tính toán  →  min_distance_over_shingles = 6.9450
#   C. Chỉ quy định về cốt thép dự ứng lực  →  min_distance_over_shingles = 8.2426
#   D. Các yêu cầu bảo trì công trình sau khi hoàn thành  →  min_distance_over_shingles = 7.5964
# Đáp án gợi ý: B - Quy định các yêu cầu về an toàn, điều kiện sử dụng, độ bền lâu, yêu cầu cấu tạo và tính toán
# Public001
#
#  Câu hỏi: Nếu một cấu kiện bê tông làm việc trong môi trường xâm thực, theo TCVN 5574:2018, cần đảm bảo thêm yêu cầu gì ngoài an toàn và sử dụng bình thường?
#   A. Không cần bổ sung yêu cầu nào  →  min_distance_over_shingles = 7.1869
#   B. Giảm kích thước tiết diện để tiết kiệm vật liệu  →  min_distance_over_shingles = 6.4688
#   C. Yêu cầu về độ bền lâu và bảo vệ chống xâm thực  →  min_distance_over_shingles = 7.1583
#   D. Chỉ cần tăng cường số lượng cốt thép  →  min_distance_over_shingles = 7.1556
# Đáp án gợi ý: B - Giảm kích thước tiết diện để tiết kiệm vật liệu
# Public019
#
#  Câu hỏi: Hệ thống chống sét theo TCVN 9385:2012 bao gồm mấy phần chính?
#   A. 2  →  min_distance_over_shingles = 9.1355
#   B. 3  →  min_distance_over_shingles = 9.1417
#   C. 4  →  min_distance_over_shingles = 8.9655
#   D. 5  →  min_distance_over_shingles = 8.8243
# Đáp án gợi ý: D - 5
# Public019
#
#  Câu hỏi: Bộ phận nào trong hệ thống chống sét có nhiệm vụ thu sét trực tiếp?
#   A. Hệ thống thu sét (kim thu sét, dây dẫn trên mái…)  →  min_distance_over_shingles = 7.5550
#   B. Hệ thống nối đất  →  min_distance_over_shingles = 8.5175
#   C. Hệ thống dây dẫn sét  →  min_distance_over_shingles = 8.5236
#   D. Hệ thống cân bằng điện thế  →  min_distance_over_shingles = 8.5801
# Đáp án gợi ý: A - Hệ thống thu sét (kim thu sét, dây dẫn trên mái…)
# Public019
#
#  Câu hỏi: Quốc gia nào là nước đầu tiên công bố Kế hoạch chiến lược trí tuệ nhân tạo quốc gia và vào năm nào?
#   A. Trung Quốc, năm 2017  →  min_distance_over_shingles = 8.4767
#   B. Mỹ, năm 2016  →  min_distance_over_shingles = 8.0876
#   C. Pháp, năm 2018  →  min_distance_over_shingles = 8.7546
#   D. Nhật Bản, năm 2019  →  min_distance_over_shingles = 8.3736
# Đáp án gợi ý: B - Mỹ, năm 2016
# Public018
#
#  Câu hỏi: Nội dung chính của TCVN 9385:2012 là gì?
#   A. Quy định về tính toán tải trọng gió  →  min_distance_over_shingles = 8.6892
#   B. Quy định thiết kế, thi công, kiểm tra, bảo trì hệ thống chống sét cho công trình  →  min_distance_over_shingles = 8.9701
#   C. Chỉ hướng dẫn cách lắp đặt kim thu sét  →  min_distance_over_shingles = 8.7553
#   D. Hướng dẫn vận hành thiết bị điện cao thế  →  min_distance_over_shingles = 8.7539
# Đáp án gợi ý: A - Quy định về tính toán tải trọng gió
# Public031
#
#  Câu hỏi: Một công trình cao 30 m cần bảo vệ chống sét trực tiếp. Theo bán kính bảo vệ của kim thu sét (r = 1,5h), bán kính bảo vệ tối đa là bao nhiêu?
#   A. 30 m  →  min_distance_over_shingles = 8.2760
#   B. 40 m  →  min_distance_over_shingles = 8.4317
#   C. 45 m  →  min_distance_over_shingles = 8.4323
#   D. 45 m  →  min_distance_over_shingles = 8.4323
# Đáp án gợi ý: A - 30 m
# Public030
#
#  Câu hỏi: Chiều dày màng khô của lớp phủ chống cháy được xác định bằng cách nào?
#   A. Quan sát trực quan sau khi phủ  →  min_distance_over_shingles = 7.7207
#   B. Đo trực tiếp trên mẫu thử nghiệm bằng dụng cụ cảm ứng điện từ hoặc dòng điện xoáy  →  min_distance_over_shingles = 8.3707
#   C. Dùng cân xác định khối lượng riêng  →  min_distance_over_shingles = 7.5961
#   D. So sánh với mẫu chuẩn  →  min_distance_over_shingles = 8.1554
# ...
# Đáp án gợi ý: A - 0 và 127
# Public001
#
#  Câu hỏi: Phép tích chập (convolution) gồm ba yếu tố chính là kernel và hai thành phần nào?
#   A. Strike và patting  →  min_distance_over_shingles = 8.3522
#   B. Stride và padding  →  min_distance_over_shingles = 8.2341
#   C. Strike và padding  →  min_distance_over_shingles = 8.3116
#   D. Stride và patting  →  min_distance_over_shingles = 8.2358
# Đáp án gợi ý: B - Stride và padding
# Public030
#
#  Câu hỏi: Sử dụng công thức quy đổi RGB sang ảnh xám (p = 0.299 * r + 0.587 * g + 0.114 * b, làm tròn tới hàng đơn vị) được đề cập trong tài liệu Public_043, hãy xác định giá trị pixel ảnh xám ứng với pixel ảnh RGB (100, 10, 1).
#   A. 36  →  min_distance_over_shingles = 8.4125
#   B. 35  →  min_distance_over_shingles = 8.3709
#   C. 37  →  min_distance_over_shingles = 8.3492
#   D. 34  →  min_distance_over_shingles = 8.3830
# Đáp án gợi ý: C - 37
# Public019
#
#  Câu hỏi: Đâu là vấn đề trong xử lý ảnh mà CNN giải quyết tốt hơn so với các mạng nơ-ron truyền thống?
#   A. Lưu trữ tham số  →  min_distance_over_shingles = 8.2027
#   B. Xử lý dữ liệu hai chiều  →  min_distance_over_shingles = 8.1107
#   C. Thời gian tính toán  →  min_distance_over_shingles = 8.1495
#   D. Cả ba vấn đề đã nêu  →  min_distance_over_shingles = 8.7240
# Đáp án gợi ý: B - Xử lý dữ liệu hai chiều
# Public013
#
#  Câu hỏi: Pooling layer được thiết kế để?
#   A. Giảm kích thước dữ liệu, bất luận mất mát thông tin  →  min_distance_over_shingles = 7.8040
#   B. Giảm chiều nhưng vẫn giữ lại thông tin  →  min_distance_over_shingles = 7.7157
#   C. Tăng kích thước dữ liệu  →  min_distance_over_shingles = 8.4406
#   D. Sinh ra giá trị trung gian dựa trên một vùng của dữ liệu  →  min_distance_over_shingles = 8.3043
# Đáp án gợi ý: B - Giảm chiều nhưng vẫn giữ lại thông tin
# Public017
#
#  Câu hỏi: Pooling layer của VGG16 có kích thước ra sao và hàm pool là?
#   A. 2 x 2, avg  →  min_distance_over_shingles = 8.5234
#   B. 3 x 3, max  →  min_distance_over_shingles = 8.7317
#   C. 2 x 2, max  →  min_distance_over_shingles = 8.8999
#   D. 3 x 3, avg  →  min_distance_over_shingles = 8.4999
# Đáp án gợi ý: D - 3 x 3, avg
# Public001
#
#  Câu hỏi: Tổng quát một CNN sẽ gồm hai phần chính nào sau đây?
#   A. Các lớp tích chập và các lớp truyền thống  →  min_distance_over_shingles = 8.3688
#   B. Các kernel tích chập và hàm pool  →  min_distance_over_shingles = 8.6669
#   C. Các lớp tích chập giảm kích thước và các lớp tích chập tăng kích thước  →  min_distance_over_shingles = 8.2103
#   D. Các thông số padding và stride  →  min_distance_over_shingles = 8.6153
# Đáp án gợi ý: C - Các lớp tích chập giảm kích thước và các lớp tích chập tăng kích thước
# Public013
#
#  Câu hỏi: Kết quả average pooling của hình vuông gồm 4 giá trị 15, 20, 30, 45 là?
#   A. 30  →  min_distance_over_shingles = 9.1334
#   B. 27.5  →  min_distance_over_shingles = 9.1926
#   C. 25  →  min_distance_over_shingles = 9.0716
#   D. 32.5  →  min_distance_over_shingles = 9.0244
# Đáp án gợi ý: D - 32.5
# Public001
#
#  Câu hỏi: Theo tài liệu Public_045, điểm chung của Transfer learning và data augmentation là gì?
#   A. Tận dụng mô hình có sẵn  →  min_distance_over_shingles = 7.8520
#   B. Áp dụng cho tình trạng khan hiếm dữ liệu  →  min_distance_over_shingles = 7.6990
#   C. Chi phí đắt đỏ  →  min_distance_over_shingles = 8.7309
#   D. Không có điểm chung, là hai phương án độc lập rời rạc  →  min_distance_over_shingles = 9.0532
# Đáp án gợi ý: B - Áp dụng cho tình trạng khan hiếm dữ liệu
# Public072
#
#  Câu hỏi: Theo tài liệu Public_045, đâu không phải là một hình thức data augmentation cho ảnh?
#   A. Cắt và phóng to (crop and resize)  →  min_distance_over_shingles = 8.2784
#   B. Lật ảnh (flip)  →  min_distance_over_shingles = 8.2593
#   C. Xoay ảnh (rotate)  →  min_distance_over_shingles = 8.0080
#   D. Chuyển ảnh xám  →  min_distance_over_shingles = 8.1600
# Đáp án gợi ý: C - Xoay ảnh (rotate)
# Public001
#
#  Câu hỏi: Theo tài liệu Public_045, khi tiến hành phân lớp với nhiều hơn hai lớp, có bao nhiêu chiến lược tiếp cận? Hình thức của chúng là gì?
#   A. Hai. Một model phân M lớp và M model phân biệt từng lớp  →  min_distance_over_shingles = 8.4869
#   B. Một. Một model phân M lớp  →  min_distance_over_shingles = 8.2100
#   C. Một. M model phân biệt từng lớp  →  min_distance_over_shingles = 8.5238
#   D. Không thể tiến hành  →  min_distance_over_shingles = 8.3370
# Đáp án gợi ý: B - Một. Một model phân M lớp
# Public033
#
#  Câu hỏi: Trường hợp nào sau đây được đề xuất sử dụng Finetuning hơn là Feature extractor?
# I. Dữ liệu lớn, khác dữ liệu pretrain
# II. Dữ liệu nhỏ, khác dữ liệu pretrain
# III. Dữ liệu nhỏ, giống dữ liệu pretrain
# IV. Dữ liệu lớn, giống dữ liệu pretrain
#   A. I  →  min_distance_over_shingles = 8.6469
#   B. II và III  →  min_distance_over_shingles = 9.1230
#   C. I và IV  →  min_distance_over_shingles = 9.1655
#   D. IV  →  min_distance_over_shingles = 8.8344
# Đáp án gợi ý: A - I
# Public033
#
#  Câu hỏi: Theo tài liệu Public_045, đâu không phải là khẳng định đúng giữa Finetuning và Feature extractor?
#   A. Finetuning hiệu quả thấp hơn feature extractor  →  min_distance_over_shingles = 9.4217
#   B. Finetuning chỉ phù hợp khi có bộ dữ liệu đủ lớn  →  min_distance_over_shingles = 9.4066
#   C. Feature extractor phù hợp khi dữ liệu thích nghi tương đối giống với dữ liệu của mô hình pretrained  →  min_distance_over_shingles = 8.9686
#   D. Finetuning cần nhiều tài nguyên để tiến hành hơn so với feature extractor  →  min_distance_over_shingles = 9.2558
# Đáp án gợi ý: C - Feature extractor phù hợp khi dữ liệu thích nghi tương đối giống với dữ liệu của mô hình pretrained
# Public072
#
#  Câu hỏi: Lợi ích chính của vectorization là gì
#   A. Tiết kiệm thời gian  →  min_distance_over_shingles = 9.5384
#   B. Tiết kiệm bộ nhớ  →  min_distance_over_shingles = 9.6319
#   C. Giảm overfitting  →  min_distance_over_shingles = 10.3694
#   D. Giảm underfitting  →  min_distance_over_shingles = 10.5313
# Đáp án gợi ý: A - Tiết kiệm thời gian
# Public039
#
#  Câu hỏi: Theo tài liệu Public_046, giá trị p trong dropout thể hiện điều gì?
#   A. Tỉ lệ giữ node của layer  →  min_distance_over_shingles = 7.7167
#   B. Xác suất giữ một layer  →  min_distance_over_shingles = 7.8805
#   C. Tỉ lệ bỏ node của layer  →  min_distance_over_shingles = 7.7220
#   D. Xác suất bỏ một layer  →  min_distance_over_shingles = 8.1696
# Đáp án gợi ý: A - Tỉ lệ giữ node của layer
# Public001
#
#  Câu hỏi: Theo tài liệu Public_046, khái niệm tiếng Việt cho bias và variance là gì?
#   A. Phương sai, độ lệch chuẩn  →  min_distance_over_shingles = 8.3023
#   B. Độ lệch, độ lệch chuẩn  →  min_distance_over_shingles = 8.4469
#   C. Độ lệch, phương sai  →  min_distance_over_shingles = 8.2306
#   D. Độ lệch chuẩn, phương sai  →  min_distance_over_shingles = 8.2701
# Đáp án gợi ý: C - Độ lệch, phương sai
# Public031
#
#  Câu hỏi: Đâu là mục tiêu chính của các phương pháp trong tài liệu Public_046?
#   A. Tăng thời gian chạy  →  min_distance_over_shingles = 8.9501
#   B. Tránh các hiện tượng như overfitting và underfitting  →  min_distance_over_shingles = 9.3555
#   C. Tăng khả năng khái quát hóa của mô hình  →  min_distance_over_shingles = 8.9588
#   D. Cả ba mục tiêu  →  min_distance_over_shingles = 9.4047
# Đáp án gợi ý: A - Tăng thời gian chạy
# Public031
#
#  Câu hỏi: Một thuật toán gradient descent lấy ra 32 dữ liệu điểm mỗi lần tính đạo hàm thì thuộc loại gradient descent nào?
#   A. Batch GD  →  min_distance_over_shingles = 8.0419
#   B. Mini-batch GD  →  min_distance_over_shingles = 8.3204
#   C. Stochastic GD  →  min_distance_over_shingles = 8.3838
#   D. Không phải loại GD nào nêu trên  →  min_distance_over_shingles = 8.9589
# Đáp án gợi ý: A - Batch GD
# Public001
#
#  Câu hỏi: Input của bài toán object detection là?
#   A. Âm thanh  →  min_distance_over_shingles = 8.5216
#   B. Hình ảnh  →  min_distance_over_shingles = 8.0610
#   C. Văn bản  →  min_distance_over_shingles = 8.5501
#   D. Hỗn hợp  →  min_distance_over_shingles = 8.9329
# Đáp án gợi ý: B - Hình ảnh
# Public001
#
#  Câu hỏi: Vấn đề chính của R-CNN là?
#   A. Thời gian infer lâu  →  min_distance_over_shingles = 8.1514
#   B. Thời gian train lâu  →  min_distance_over_shingles = 8.3641
#   C. Cả hai vấn đề đã nêu  →  min_distance_over_shingles = 8.2797
#   D. Không phải hai vấn đề đã nêu  →  min_distance_over_shingles = 8.5279
# Đáp án gợi ý: A - Thời gian infer lâu
# Public001
#
#  Câu hỏi: IoU phụ thuộc vào hai toán tử tập hợp nào và công thức là gì?
#   A. Intersection và Union. I/U  →  min_distance_over_shingles = 7.8404
#   B. Intersection và Negation. I/(I + N)  →  min_distance_over_shingles = 7.6271
#   C. Negation và Union. (U + N)/N  →  min_distance_over_shingles = 7.7837
#   D. Intersection và Union. U/(U + I)  →  min_distance_over_shingles = 7.4521
# Đáp án gợi ý: D - Intersection và Union. U/(U + I)
# Public001
#
#  Câu hỏi: Các nguyên tắc cốt lõi và thành phần chính của các cách tiếp cận object detection là gì?
#   A. Hồi quy  →  min_distance_over_shingles = 8.1676
#   B. Region proposal  →  min_distance_over_shingles = 8.5378
#   C. Phân cụm  →  min_distance_over_shingles = 7.8814
#   D. Phân lớp  →  min_distance_over_shingles = 7.7815
# Đáp án gợi ý: D - Phân lớp
# Public001
#
#  Câu hỏi: Trong ROI pooling, để tạo ra output có kích thước 4x4, mỗi vùng quan tâm (ROI) được chia thành bao nhiêu phân vùng con để thực hiện pooling?
#   A. 1  →  min_distance_over_shingles = 8.2583
#   B. 2  →  min_distance_over_shingles = 8.2068
#   C. 3  →  min_distance_over_shingles = 8.2074
#   D. 4  →  min_distance_over_shingles = 8.3448
# Đáp án gợi ý: B - 2
# Public001
#
#  Câu hỏi: Bộ dữ liệu được sử dụng trong tài liệu Public_048 có bao nhiêu ảnh?
#   A. 1750  →  min_distance_over_shingles = 8.5290
#   B. 1024  →  min_distance_over_shingles = 8.6899
#   C. 2048  →  min_distance_over_shingles = 8.8321
#   D. 3500  →  min_distance_over_shingles = 9.0048
# Đáp án gợi ý: A - 1750
# Public001
#
#  Câu hỏi: Mô hình được sử dụng để huấn luyện trong tài liệu Public_048 là gì?
#   A. YOLOv5  →  min_distance_over_shingles = 8.8902
#   B. YOLOv4  →  min_distance_over_shingles = 8.9458
#   C. YOLO-TinyV5  →  min_distance_over_shingles = 9.1178
#   D. YOLO-Tinyv4  →  min_distance_over_shingles = 9.0930
# Đáp án gợi ý: A - YOLOv5
# Public031
#
#  Câu hỏi: Trong tài liệu Public_048, có bao nhiêu phương pháp tăng cường dữ liệu đã được dùng và gồm những thao tác nào?
#   A. Hai. Thu nhỏ, phóng to  →  min_distance_over_shingles = 8.7062
#   B. Ba. Thu phóng, tăng sáng, xoay  →  min_distance_over_shingles = 7.8640
#   C. Hai. Thêm nhiễu, tăng sáng  →  min_distance_over_shingles = 8.9780
#   D. Một. Lật  →  min_distance_over_shingles = 8.4720
# Đáp án gợi ý: B - Ba. Thu phóng, tăng sáng, xoay
# Public001
#
#  Câu hỏi: Cách tiếp cận đã nêu trong tài liệu Public_048 có tiến hành đọc biển số hay không?
#   A. Không  →  min_distance_over_shingles = 9.7114
#   B. Có  →  min_distance_over_shingles = 9.0930
#   C. nan  →  min_distance_over_shingles = 8.7177
#   D. nan  →  min_distance_over_shingles = 8.7177
# Đáp án gợi ý: C - nan
# Public001
#
#  Câu hỏi: Phân loại của bài toán được mô tả trong tài liệu Public_048 là gì?
#   A. Image segmentation  →  min_distance_over_shingles = 9.5335
#   B. Object segmentation  →  min_distance_over_shingles = 8.6759
#   C. Object detection  →  min_distance_over_shingles = 8.6697
#   D. Image classification  →  min_distance_over_shingles = 8.9867
# Đáp án gợi ý: C - Object detection
# Public010
#
#  Câu hỏi: Theo tài liệu Public_049, khái niệm được dùng để đại diện tập xác định của một biến là gì?
#   A. Kiểu dữ liệu  →  min_distance_over_shingles = 8.6245
#   B. Tên dữ liệu  →  min_distance_over_shingles = 8.6071
#   C. Loại dữ liệu  →  min_distance_over_shingles = 8.6374
#   D. Lớp dữ liệu  →  min_distance_over_shingles = 8.5004
# Đáp án gợi ý: D - Lớp dữ liệu
# Public031
#
#  Câu hỏi: Theo tài liệu Public_049, thành phần nào không thuộc phạm vi quản lý của biến?
#   A. Kiểu dữ liệu  →  min_distance_over_shingles = 7.5991
#   B. Tên biến  →  min_distance_over_shingles = 8.1258
#   C. Giá trị biến  →  min_distance_over_shingles = 7.3756
#   D. Địa chỉ lưu biến  →  min_distance_over_shingles = 7.7859
# Đáp án gợi ý: C - Giá trị biến
# Public017
#
#  Câu hỏi: Tên kiểu dữ liệu của ký tự ASCII và ký tự Unicode lần lượt là?
#   A. char và wchar  →  min_distance_over_shingles = 8.1714
#   B. char_t và wchar_t  →  min_distance_over_shingles = 8.7809
#   C. char và wchar_t  →  min_distance_over_shingles = 8.2926
#   D. char_t và wchar  →  min_distance_over_shingles = 8.8102
# Đáp án gợi ý: A - char và wchar
# Public001
#
#  Câu hỏi: Đâu không phải khẳng định đúng về các đặc tính của thuật toán được đề cập trong tài liệu Public_049?
#   A. Thuật toán phải rõ ràng, không nhập nhằng  →  min_distance_over_shingles = 8.1377
#   B. Thuật toán không được chạy vô hạn  →  min_distance_over_shingles = 8.7947
#   C. Thuật toán phải được thiết kế đặc thù, chuyên sâu thay vì tổng quát  →  min_distance_over_shingles = 8.2056
#   D. Thuật toán nên dễ hiểu, dễ cài đặt  →  min_distance_over_shingles = 7.9152
# Đáp án gợi ý: D - Thuật toán nên dễ hiểu, dễ cài đặt
# Public001
#
#  Câu hỏi: Phương trình toán học 3x + 4y + 5z = 6 có mấy biến?
#   A. Ba  →  min_distance_over_shingles = 8.4163
#   B. Hai  →  min_distance_over_shingles = 8.7405
#   C. Một  →  min_distance_over_shingles = 8.3885
#   D. Bốn  →  min_distance_over_shingles = 8.8667
# Đáp án gợi ý: C - Một
# Public006
#
#  Câu hỏi: Dựa vào tài liệu Public_050, từ nào điền vào chỗ trống sau: nếu hàm số f(x) bị ... bởi hằng số C nhân với g(x), ta nói f(x) có độ phức tạp O(g(x))?
#   A. Chặn dưới   →  min_distance_over_shingles = 8.4051
#   B. Chặn trên  →  min_distance_over_shingles = 8.6306
#   C. Chặn trên và dưới  →  min_distance_over_shingles = 8.6653
#   D. Lớn hơn  →  min_distance_over_shingles = 7.8293
# Đáp án gợi ý: D - Lớn hơn
# Public019
#
#  Câu hỏi: Theo nguyên tắc tổng, f1(x) + f2(x) có độ phức tạp là?
#   A. O(max(g1(x), g2(x))  →  min_distance_over_shingles = 6.9905
#   B. O(min(g1(x), g2(x))  →  min_distance_over_shingles = 7.1202
#   C. O(g1(x) + g2(x))  →  min_distance_over_shingles = 6.9555
#   D. O(|g1(x) - g2(x)|)  →  min_distance_over_shingles = 6.9906
# Đáp án gợi ý: C - O(g1(x) + g2(x))
# Public030
#
#  Câu hỏi: Độ phức tạp tuyến tính và giai thừa lần lượt có ký hiệu là?
#   A. O(1) và O(n)  →  min_distance_over_shingles = 8.6300
#   B. O(logn) và O(n!)  →  min_distance_over_shingles = 8.6244
#   C. O(n) và O(n!)  →  min_distance_over_shingles = 8.8857
#   D. O(1) và O(logn)  →  min_distance_over_shingles = 8.4874
# Đáp án gợi ý: D - O(1) và O(logn)
# Public013
#
#  Câu hỏi: Theo tài liệu Public_050, bước đầu tiên của quá trình tiếp cận bài toán là gì?
#   A. Tìm cấu trúc dữ liệu phù hợp  →  min_distance_over_shingles = 8.5799
#   B. Lựa chọn thuật toán  →  min_distance_over_shingles = 8.8436
#   C. Xác định yêu cầu bài toán   →  min_distance_over_shingles = 8.5663
#   D. Xác định ngôn ngữ và trình dịch  →  min_distance_over_shingles = 8.9311
# Đáp án gợi ý: C - Xác định yêu cầu bài toán
# Public033
#
#  Câu hỏi: Hai thuật toán được tiến hành kế tiếp nhau lần lượt có độ phức tạp O(n) và O(n^2). Độ phức tạp của chương trình là?
#   A. O(n)  →  min_distance_over_shingles = 8.0456
#   B. O(n^2)  →  min_distance_over_shingles = 8.0980
#   C. O(n^2 + n)  →  min_distance_over_shingles = 7.8821
#   D. O(n x n^2)  →  min_distance_over_shingles = 7.8887
# Đáp án gợi ý: C - O(n^2 + n)
# Public031
#
#  Câu hỏi: Dựa trên tài liệu Public_051, khái niệm nào không thuộc về thuật toán sinh?
#   A. Cấu hình khởi đầu  →  min_distance_over_shingles = 8.1699
#   B. Cấu hình kết thúc  →  min_distance_over_shingles = 8.1056
#   C. Thuật toán chuyển cấu hình tất định  →  min_distance_over_shingles = 8.1798
#   D. Cấu hình tối ưu  →  min_distance_over_shingles = 7.6324
# Đáp án gợi ý: D - Cấu hình tối ưu
# Public019
#
#  Câu hỏi: Nội dung của tài liệu Public_051 không bao gồm bài toán nào?
#   A. Bài toán liệt kê  →  min_distance_over_shingles = 8.6371
#   B. Bài toán đếm  →  min_distance_over_shingles = 8.5243
#   C. Bài toán tồn tại  →  min_distance_over_shingles = 8.3187
#   D. Bài toán đặc thù  →  min_distance_over_shingles = 8.3029
# Đáp án gợi ý: D - Bài toán đặc thù
# Public001
#
#  Câu hỏi: Số hoán vị của N phần tử phân biệt là bao nhiêu và giá trị tương ứng khi N = 3 là?
#   A. N!, 6  →  min_distance_over_shingles = 8.2324
#   B. N^N, 27  →  min_distance_over_shingles = 8.4180

# %%
cur.close()
conn.close()

# %%
conn.rollback()
